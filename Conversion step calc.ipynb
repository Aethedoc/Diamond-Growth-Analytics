# %%
#Quick disclaimer to this model:
    #It has the same setup as "Diamond Growth", however missing the H2 and added the "Dip" to each set. 
    #Technically 1 Dataset function can calculate BOTH BARE AND CONVERTED. The second dataset function is left for cross 
    #comparison for Control to Actual Data set. 
    #Hence the "Comparison" function only works for that function specifcally. There is a function at the base of "DataSet_1"
    #that will calculate the difference between the bare and converted micelles from one set only. "Compare_DataSet_1()"
    
    #SECOND DataSet function is for final sample, where we only look at two micelles.

# %%
import numpy as np
import scipy as sci
from scipy.fftpack import fft
from matplotlib.axis import Axis
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
import pandas as pd
from scipy.interpolate import UnivariateSpline
import sys
np.set_printoptions(threshold=sys.maxsize) #Shows all values in array.
import operator
from operator import add
import functools
import math

#FULL = BARE 
#ATM = CONVERTED
DataSet_1_FULL_RIDGE_ZX = [] #Lists for Z-data (X-axis)
DataSet_1_ATM_RIDGE_ZX = []
DataSet_1_FULL_MID_ZX = []
DataSet_1_ATM_MID_ZX = []
DataSet_1_FULL_DIP_ZX = []
DataSet_1_ATM_DIP_ZX = []
DataSet_1_FULL_RIDGE_ZY = [] #Lists for Z-data (Y-axis)
DataSet_1_ATM_RIDGE_ZY = []
DataSet_1_FULL_MID_ZY = []
DataSet_1_ATM_MID_ZY = []
DataSet_1_FULL_DIP_ZY = []
DataSet_1_ATM_DIP_ZY = []
DataSet_1_FULL_BASE = [] #Lists for Base Area (X*Y)
DataSet_1_ATM_BASE = [] 
DataSet_1_FULL_VOL_RIDGE_X = [] #Lists for Volume using X-axis Ridge
DataSet_1_ATM_VOL_RIDGE_X = []
DataSet_1_FULL_VOL_RIDGE_Y = [] #Lists for Volume using Y-axis Ridge
DataSet_1_ATM_VOL_RIDGE_Y = []
DataSet_1_FULL_VOL_MID_X = [] #Lists for Volume using X-axis Mid
DataSet_1_ATM_VOL_MID_X = []
DataSet_1_FULL_VOL_MID_Y = [] #Lists for Volume using Y-axis Mid
DataSet_1_ATM_VOL_MID_Y = []
DataSet_1_FULL_VOL_DIP_X = [] #Lists for Volumes using X-axis Dip
DataSet_1_ATM_VOL_DIP_X = []
DataSet_1_FULL_VOL_DIP_Y = [] #Lists for Volumes using Y-axis Dip
DataSet_1_ATM_VOL_DIP_Y = []



#Copy file directory into pandas reader to remote access. ALSO replace "\" with "/". KEEP ENCODING.

def DataSet_1():
#====================================================DATA IMPORT====================================================
    Data_1P_1 = pd.read_csv("C:\\Users\\Harry\\OneDrive\\Documents\\University of bristol\\AFM Images\\Python - Micelle topography data\\Remote Data\\Controls\\Bare Micelles\\6.csv",encoding = 'ISO-8859-1') #BARE
    Data_1P_2 = pd.read_csv("C:\\Users\\Harry\\OneDrive\\Documents\\University of bristol\\AFM Images\\Python - Micelle topography data\\Remote Data\\Controls\\Bare Micelles\\10.csv",encoding = 'ISO-8859-1')
    Data_1P_3 = pd.read_csv("C:\\Users\\Harry\\OneDrive\\Documents\\University of bristol\\AFM Images\\Python - Micelle topography data\\Remote Data\\Controls\\Bare Micelles\\11.csv",encoding = 'ISO-8859-1')
    Data_1P_4 = pd.read_csv("C:\\Users\\Harry\\OneDrive\\Documents\\University of bristol\\AFM Images\\Python - Micelle topography data\\Remote Data\\Controls\\Bare Micelles\\22.csv",encoding = 'ISO-8859-1')
    Data_1P_5 = pd.read_csv("C:\\Users\\Harry\\OneDrive\\Documents\\University of bristol\\AFM Images\\Python - Micelle topography data\\Remote Data\\Controls\\Bare Micelles\\33.csv",encoding = 'ISO-8859-1')
    Data_1P_6 = pd.read_csv("C:\\Users\\Harry\\OneDrive\\Documents\\University of bristol\\AFM Images\\Python - Micelle topography data\\Remote Data\\Controls\\Bare Micelles\\38.csv",encoding = 'ISO-8859-1')

    Data_5P_1 = pd.read_csv("C:\\Users\\Harry\\OneDrive\\Documents\\University of bristol\\AFM Images\\Python - Micelle topography data\\Remote Data\\Controls\\Converted Micelles\\1D.csv",encoding = 'ISO-8859-1') #CONVERTED
    Data_5P_2 = pd.read_csv("C:\\Users\\Harry\\OneDrive\\Documents\\University of bristol\\AFM Images\\Python - Micelle topography data\\Remote Data\\Controls\\Converted Micelles\\3D.csv",encoding = 'ISO-8859-1')
    Data_5P_3 = pd.read_csv("C:\\Users\\Harry\\OneDrive\\Documents\\University of bristol\\AFM Images\\Python - Micelle topography data\\Remote Data\\Controls\\Converted Micelles\\4D.csv",encoding = 'ISO-8859-1')
    Data_5P_4 = pd.read_csv("C:\\Users\\Harry\\OneDrive\\Documents\\University of bristol\\AFM Images\\Python - Micelle topography data\\Remote Data\\Controls\\Converted Micelles\\6D.csv",encoding = 'ISO-8859-1')
    Data_5P_5 = pd.read_csv("C:\\Users\\Harry\\OneDrive\\Documents\\University of bristol\\AFM Images\\Python - Micelle topography data\\Remote Data\\Controls\\Converted Micelles\\11D.csv",encoding = 'ISO-8859-1')
    Data_5P_6 = pd.read_csv("C:\\Users\\Harry\\OneDrive\\Documents\\University of bristol\\AFM Images\\Python - Micelle topography data\\Remote Data\\Controls\\Converted Micelles\\18D.csv",encoding = 'ISO-8859-1')
    
#---------------------------------------------------X-Axis------------------------------------------------------
    Data_X1P_1 = (Data_1P_1['X-axis']*(10**3)) #FULL growth
    Data_X1P_2 = (Data_1P_2['X-axis']*(10**3))
    Data_X1P_3 = (Data_1P_3['X-axis']*(10**3))
    Data_X1P_4 = (Data_1P_4['X-axis']*(10**3))
    Data_X1P_5 = (Data_1P_5['X-axis']*(10**3))
    Data_X1P_6 = (Data_1P_6['X-axis']*(10**3))

    Data_X5P_1 = (Data_5P_1['X-axis']*(10**3)) #ATM growth
    Data_X5P_2 = (Data_5P_2['X-axis']*(10**3))
    Data_X5P_3 = (Data_5P_3['X-axis']*(10**3))
    Data_X5P_4 = (Data_5P_4['X-axis']*(10**3))
    Data_X5P_5 = (Data_5P_5['X-axis']*(10**3))
    Data_X5P_6 = (Data_5P_6['X-axis']*(10**3))
    
#---------------------------------------------------Y-Axis------------------------------------------------------
    Data_Y1P_1 = (Data_1P_1['Y-axis']*(10**3)) #FULL growth
    Data_Y1P_2 = (Data_1P_2['Y-axis']*(10**3))
    Data_Y1P_3 = (Data_1P_3['Y-axis']*(10**3))
    Data_Y1P_4 = (Data_1P_4['Y-axis']*(10**3))
    Data_Y1P_5 = (Data_1P_5['Y-axis']*(10**3))
    Data_Y1P_6 = (Data_1P_6['Y-axis']*(10**3))

    Data_Y5P_1 = (Data_5P_1['Y-axis']*(10**3)) #ATM growth
    Data_Y5P_2 = (Data_5P_2['Y-axis']*(10**3))
    Data_Y5P_3 = (Data_5P_3['Y-axis']*(10**3))
    Data_Y5P_4 = (Data_5P_4['Y-axis']*(10**3))
    Data_Y5P_5 = (Data_5P_5['Y-axis']*(10**3))
    Data_Y5P_6 = (Data_5P_6['Y-axis']*(10**3))
    

#---------------------------------------------------Ridge X------------------------------------------------------
    Data_L_RidgeX1P_1 = list(map (add,Data_1P_1['L-Ridge1'], Data_1P_1['L-Ridge2'] )) #Averaging Ridges' across individual micelles
    Data_L_RidgeX1P_2 = list(map (add,Data_1P_2['L-Ridge1'], Data_1P_2['L-Ridge2'] )) #FULL growth
    Data_L_RidgeX1P_3 = list(map (add,Data_1P_3['L-Ridge1'], Data_1P_3['L-Ridge2'] ))
    Data_L_RidgeX1P_4 = list(map (add,Data_1P_4['L-Ridge1'], Data_1P_4['L-Ridge2'] ))
    Data_L_RidgeX1P_5 = list(map (add,Data_1P_5['L-Ridge1'], Data_1P_5['L-Ridge2'] ))
    Data_L_RidgeX1P_6 = list(map (add,Data_1P_6['L-Ridge1'], Data_1P_6['L-Ridge2'] ))

    Data_L_RidgeX5P_1 = list(map (add,Data_5P_1['L-Ridge1'], Data_5P_1['L-Ridge2'] )) #ATM growth
    Data_L_RidgeX5P_2 = list(map (add,Data_5P_2['L-Ridge1'], Data_5P_2['L-Ridge2'] )) 
    Data_L_RidgeX5P_3 = list(map (add,Data_5P_3['L-Ridge1'], Data_5P_3['L-Ridge2'] ))
    Data_L_RidgeX5P_4 = list(map (add,Data_5P_4['L-Ridge1'], Data_5P_4['L-Ridge2'] ))
    Data_L_RidgeX5P_5 = list(map (add,Data_5P_5['L-Ridge1'], Data_5P_5['L-Ridge2'] ))
    Data_L_RidgeX5P_6 = list(map (add,Data_5P_6['L-Ridge1'], Data_5P_6['L-Ridge2'] ))

#---------------------------------------------------Ridge Y------------------------------------------------------
    Data_L_RidgeY1P_1 = list(map (add,Data_1P_1['W-Ridge1'], Data_1P_1['W-Ridge2'] )) #Averaging Ridges' across individual micelles
    Data_L_RidgeY1P_2 = list(map (add,Data_1P_2['W-Ridge1'], Data_1P_2['W-Ridge2'] )) #FULL growth
    Data_L_RidgeY1P_3 = list(map (add,Data_1P_3['W-Ridge1'], Data_1P_3['W-Ridge2'] ))
    Data_L_RidgeY1P_4 = list(map (add,Data_1P_4['W-Ridge1'], Data_1P_4['W-Ridge2'] ))
    Data_L_RidgeY1P_5 = list(map (add,Data_1P_5['W-Ridge1'], Data_1P_5['W-Ridge2'] ))
    Data_L_RidgeY1P_6 = list(map (add,Data_1P_6['W-Ridge1'], Data_1P_6['W-Ridge2'] ))

    Data_L_RidgeY5P_1 = list(map (add,Data_5P_1['W-Ridge1'], Data_5P_1['W-Ridge2'] )) #ATM growth
    Data_L_RidgeY5P_2 = list(map (add,Data_5P_2['W-Ridge1'], Data_5P_2['W-Ridge2'] )) 
    Data_L_RidgeY5P_3 = list(map (add,Data_5P_3['W-Ridge1'], Data_5P_3['W-Ridge2'] ))
    Data_L_RidgeY5P_4 = list(map (add,Data_5P_4['W-Ridge1'], Data_5P_4['W-Ridge2'] ))
    Data_L_RidgeY5P_5 = list(map (add,Data_5P_5['W-Ridge1'], Data_5P_5['W-Ridge2'] ))
    Data_L_RidgeY5P_6 = list(map (add,Data_5P_6['W-Ridge1'], Data_5P_6['W-Ridge2'] ))
    
#---------------------------------------------------MIDDLE X------------------------------------------------------
    Data_L_MidX1P_1 = Data_1P_1['L-Middle'] #FULL growth
    Data_L_MidX1P_2 = Data_1P_2['L-Middle']
    Data_L_MidX1P_3 = Data_1P_3['L-Middle']
    Data_L_MidX1P_4 = Data_1P_4['L-Middle']
    Data_L_MidX1P_5 = Data_1P_5['L-Middle']
    Data_L_MidX1P_6 = Data_1P_6['L-Middle']

    Data_L_MidX5P_1 = Data_5P_1['L-Middle'] #ATM growth
    Data_L_MidX5P_2 = Data_5P_2['L-Middle']
    Data_L_MidX5P_3 = Data_5P_3['L-Middle']
    Data_L_MidX5P_4 = Data_5P_4['L-Middle']
    Data_L_MidX5P_5 = Data_5P_5['L-Middle']
    Data_L_MidX5P_6 = Data_5P_6['L-Middle']

#---------------------------------------------------MIDDLE Y------------------------------------------------------
    Data_L_MidY1P_1 = Data_1P_1['W-Middle'] #FULL growth
    Data_L_MidY1P_2 = Data_1P_2['W-Middle']
    Data_L_MidY1P_3 = Data_1P_3['W-Middle']
    Data_L_MidY1P_4 = Data_1P_4['W-Middle']
    Data_L_MidY1P_5 = Data_1P_5['W-Middle']
    Data_L_MidY1P_6 = Data_1P_6['W-Middle']

    Data_L_MidY5P_1 = Data_5P_1['W-Middle'] #ATM growth
    Data_L_MidY5P_2 = Data_5P_2['W-Middle']
    Data_L_MidY5P_3 = Data_5P_3['W-Middle']
    Data_L_MidY5P_4 = Data_5P_4['W-Middle']
    Data_L_MidY5P_5 = Data_5P_5['W-Middle']
    Data_L_MidY5P_6 = Data_5P_6['W-Middle']

#-----------------------------------------------------DIP X-------------------------------------------------------
    Data_L_DipX1P_1 = list(map (add,Data_1P_1['L-Dip1'], Data_1P_1['L-Dip2'] )) #Averaging Ridges' across individual micelles
    Data_L_DipX1P_2 = list(map (add,Data_1P_2['L-Dip1'], Data_1P_2['L-Dip2'] )) #FULL growth
    Data_L_DipX1P_3 = list(map (add,Data_1P_3['L-Dip1'], Data_1P_3['L-Dip2'] ))
    Data_L_DipX1P_4 = list(map (add,Data_1P_4['L-Dip1'], Data_1P_4['L-Dip2'] ))
    Data_L_DipX1P_5 = list(map (add,Data_1P_5['L-Dip1'], Data_1P_5['L-Dip2'] ))
    Data_L_DipX1P_6 = list(map (add,Data_1P_6['L-Dip1'], Data_1P_6['L-Dip2'] ))

    Data_L_DipX5P_1 = list(map (add,Data_5P_1['L-Dip1'], Data_5P_1['L-Dip2'] )) #ATM growth
    Data_L_DipX5P_2 = list(map (add,Data_5P_2['L-Dip1'], Data_5P_2['L-Dip2'] )) 
    Data_L_DipX5P_3 = list(map (add,Data_5P_3['L-Dip1'], Data_5P_3['L-Dip2'] ))
    Data_L_DipX5P_4 = list(map (add,Data_5P_4['L-Dip1'], Data_5P_4['L-Dip2'] ))
    Data_L_DipX5P_5 = list(map (add,Data_5P_5['L-Dip1'], Data_5P_5['L-Dip2'] ))
    Data_L_DipX5P_6 = list(map (add,Data_5P_6['L-Dip1'], Data_5P_6['L-Dip2'] ))
    
#-----------------------------------------------------DIP Y-------------------------------------------------------
    Data_L_DipY1P_1 = list(map (add,Data_1P_1['W-Dip1'], Data_1P_1['W-Dip2'] )) #Averaging Ridges' across individual micelles
    Data_L_DipY1P_2 = list(map (add,Data_1P_2['W-Dip1'], Data_1P_2['W-Dip2'] )) #FULL growth
    Data_L_DipY1P_3 = list(map (add,Data_1P_3['W-Dip1'], Data_1P_3['W-Dip2'] ))
    Data_L_DipY1P_4 = list(map (add,Data_1P_4['W-Dip1'], Data_1P_4['W-Dip2'] ))
    Data_L_DipY1P_5 = list(map (add,Data_1P_5['W-Dip1'], Data_1P_5['W-Dip2'] ))
    Data_L_DipY1P_6 = list(map (add,Data_1P_6['W-Dip1'], Data_1P_6['W-Dip2'] ))

    Data_L_DipY5P_1 = list(map (add,Data_5P_1['W-Dip1'], Data_5P_1['W-Dip2'] )) #ATM growth
    Data_L_DipY5P_2 = list(map (add,Data_5P_2['W-Dip1'], Data_5P_2['W-Dip2'] )) 
    Data_L_DipY5P_3 = list(map (add,Data_5P_3['W-Dip1'], Data_5P_3['W-Dip2'] ))
    Data_L_DipY5P_4 = list(map (add,Data_5P_4['W-Dip1'], Data_5P_4['W-Dip2'] ))
    Data_L_DipY5P_5 = list(map (add,Data_5P_5['W-Dip1'], Data_5P_5['W-Dip2'] ))
    Data_L_DipY5P_6 = list(map (add,Data_5P_6['W-Dip1'], Data_5P_6['W-Dip2'] ))
    
#------------------------------------------------------ZERO DATA X------------------------------------------------------
#------------------------------------------------------BARE MICELLE------------------------------------------------------
#--------------------------------- RIDGE ---------------------------------
    Av_Data_L_RidgeX1P_1 = [] 
    Zero_Data_L_RidgeX1P_1 = [] 
    Av_Data_L_RidgeX1P_2 = []
    Zero_Data_L_RidgeX1P_2 = []
    Av_Data_L_RidgeX1P_3 = []
    Zero_Data_L_RidgeX1P_3 = []
    Av_Data_L_RidgeX1P_4 = []
    Zero_Data_L_RidgeX1P_4 = []
    Av_Data_L_RidgeX1P_5 = []
    Zero_Data_L_RidgeX1P_5 = []
    Av_Data_L_RidgeX1P_6 = []
    Zero_Data_L_RidgeX1P_6 = []

    for x in Data_L_RidgeX1P_1: #~
        a = x/2
        Av_Data_L_RidgeX1P_1.append(float(a))
    for x in Av_Data_L_RidgeX1P_1:
        a = x - ((abs(Av_Data_L_RidgeX1P_1[-1])-abs(Av_Data_L_RidgeX1P_1[0]))/2)
        Zero_Data_L_RidgeX1P_1.append(float(a))
    for x in Data_L_RidgeX1P_2: #~
        a = x/2
        Av_Data_L_RidgeX1P_2.append(float(a))
    for x in Av_Data_L_RidgeX1P_2:
        a = x - ((abs(Av_Data_L_RidgeX1P_2[-1])-abs(Av_Data_L_RidgeX1P_2[0]))/2)
        Zero_Data_L_RidgeX1P_2.append(float(a))
    for x in Data_L_RidgeX1P_3: #~
        a = x/2
        Av_Data_L_RidgeX1P_3.append(float(a))
    for x in Av_Data_L_RidgeX1P_3:
        a = x - ((abs(Av_Data_L_RidgeX1P_3[-1])-abs(Av_Data_L_RidgeX1P_3[0]))/2)
        Zero_Data_L_RidgeX1P_3.append(float(a))
    for x in Data_L_RidgeX1P_4: #~
        a = x/2
        Av_Data_L_RidgeX1P_4.append(float(a))
    for x in Av_Data_L_RidgeX1P_4:
        a = x - ((abs(Av_Data_L_RidgeX1P_4[-1])-abs(Av_Data_L_RidgeX1P_4[0]))/2)
        Zero_Data_L_RidgeX1P_4.append(float(a))
    for x in Data_L_RidgeX1P_5: #~
        a = x/2
        Av_Data_L_RidgeX1P_5.append(float(a))
    for x in Av_Data_L_RidgeX1P_5:
        a = x - ((abs(Av_Data_L_RidgeX1P_5[-1])-abs(Av_Data_L_RidgeX1P_5[0]))/2)
        Zero_Data_L_RidgeX1P_5.append(float(a))
    for x in Data_L_RidgeX1P_6: #~
        a = x/2
        Av_Data_L_RidgeX1P_6.append(float(a))
    for x in Av_Data_L_RidgeX1P_6:
        a = x - ((abs(Av_Data_L_RidgeX1P_6[-1])-abs(Av_Data_L_RidgeX1P_6[0]))/2)
        Zero_Data_L_RidgeX1P_6.append(float(a)) 

#--------------------------------- MID ---------------------------------
    Av_Data_L_MidX1P_1 = [] 
    Zero_Data_L_MidX1P_1 = [] 
    Av_Data_L_MidX1P_2 = []
    Zero_Data_L_MidX1P_2 = []
    Av_Data_L_MidX1P_3 = []
    Zero_Data_L_MidX1P_3 = []
    Av_Data_L_MidX1P_4 = []
    Zero_Data_L_MidX1P_4 = []
    Av_Data_L_MidX1P_5 = []
    Zero_Data_L_MidX1P_5 = []
    Av_Data_L_MidX1P_6 = []
    Zero_Data_L_MidX1P_6 = []

    for x in Data_L_MidX1P_1: #~
        a = x/2
        Av_Data_L_MidX1P_1.append(float(a))
    for x in Av_Data_L_MidX1P_1:
        a = x - ((abs(Av_Data_L_MidX1P_1[-1])-abs(Av_Data_L_MidX1P_1[0]))/2)
        Zero_Data_L_MidX1P_1.append(float(a))
    for x in Data_L_MidX1P_2: #~
        a = x/2
        Av_Data_L_MidX1P_2.append(float(a))
    for x in Av_Data_L_MidX1P_2:
        a = x - ((abs(Av_Data_L_MidX1P_2[-1])-abs(Av_Data_L_MidX1P_2[0]))/2)
        Zero_Data_L_MidX1P_2.append(float(a))
    for x in Data_L_MidX1P_3: #~
        a = x/2
        Av_Data_L_MidX1P_3.append(float(a))
    for x in Av_Data_L_MidX1P_3:
        a = x - ((abs(Av_Data_L_MidX1P_3[-1])-abs(Av_Data_L_MidX1P_3[0]))/2)
        Zero_Data_L_MidX1P_3.append(float(a))
    for x in Data_L_MidX1P_4: #~
        a = x/2
        Av_Data_L_MidX1P_4.append(float(a))
    for x in Av_Data_L_MidX1P_4:
        a = x - ((abs(Av_Data_L_MidX1P_4[-1])-abs(Av_Data_L_MidX1P_4[0]))/2)
        Zero_Data_L_MidX1P_4.append(float(a))
    for x in Data_L_MidX1P_5: #~
        a = x/2
        Av_Data_L_MidX1P_5.append(float(a))
    for x in Av_Data_L_MidX1P_5:
        a = x - ((abs(Av_Data_L_MidX1P_5[-1])-abs(Av_Data_L_MidX1P_5[0]))/2)
        Zero_Data_L_MidX1P_5.append(float(a))
    for x in Data_L_MidX1P_6: #~
        a = x/2
        Av_Data_L_MidX1P_6.append(float(a))
    for x in Av_Data_L_MidX1P_6:
        a = x - ((abs(Av_Data_L_MidX1P_6[-1])-abs(Av_Data_L_MidX1P_6[0]))/2)
        Zero_Data_L_MidX1P_6.append(float(a)) 
        
#--------------------------------- DIP ---------------------------------
    Av_Data_L_DipX1P_1 = [] 
    Zero_Data_L_DipX1P_1 = [] 
    Av_Data_L_DipX1P_2 = []
    Zero_Data_L_DipX1P_2 = []
    Av_Data_L_DipX1P_3 = []
    Zero_Data_L_DipX1P_3 = []
    Av_Data_L_DipX1P_4 = []
    Zero_Data_L_DipX1P_4 = []
    Av_Data_L_DipX1P_5 = []
    Zero_Data_L_DipX1P_5 = []
    Av_Data_L_DipX1P_6 = []
    Zero_Data_L_DipX1P_6 = []

    for x in Data_L_DipX1P_1: #~
        a = x/2
        Av_Data_L_DipX1P_1.append(float(a))
    for x in Av_Data_L_DipX1P_1:
        a = x - ((abs(Av_Data_L_DipX1P_1[-1])-abs(Av_Data_L_DipX1P_1[0]))/2)
        Zero_Data_L_DipX1P_1.append(float(a))
    for x in Data_L_DipX1P_2: #~
        a = x/2
        Av_Data_L_DipX1P_2.append(float(a))
    for x in Av_Data_L_DipX1P_2:
        a = x - ((abs(Av_Data_L_DipX1P_2[-1])-abs(Av_Data_L_DipX1P_2[0]))/2)
        Zero_Data_L_DipX1P_2.append(float(a))
    for x in Data_L_DipX1P_3: #~
        a = x/2
        Av_Data_L_DipX1P_3.append(float(a))
    for x in Av_Data_L_DipX1P_3:
        a = x - ((abs(Av_Data_L_DipX1P_3[-1])-abs(Av_Data_L_DipX1P_3[0]))/2)
        Zero_Data_L_DipX1P_3.append(float(a))
    for x in Data_L_DipX1P_4: #~
        a = x/2
        Av_Data_L_DipX1P_4.append(float(a))
    for x in Av_Data_L_DipX1P_4:
        a = x - ((abs(Av_Data_L_DipX1P_4[-1])-abs(Av_Data_L_DipX1P_4[0]))/2)
        Zero_Data_L_DipX1P_4.append(float(a))
    for x in Data_L_DipX1P_5: #~
        a = x/2
        Av_Data_L_DipX1P_5.append(float(a))
    for x in Av_Data_L_DipX1P_5:
        a = x - ((abs(Av_Data_L_DipX1P_5[-1])-abs(Av_Data_L_DipX1P_5[0]))/2)
        Zero_Data_L_DipX1P_5.append(float(a))
    for x in Data_L_DipX1P_6: #~
        a = x/2
        Av_Data_L_DipX1P_6.append(float(a))
    for x in Av_Data_L_DipX1P_6:
        a = x - ((abs(Av_Data_L_DipX1P_6[-1])-abs(Av_Data_L_DipX1P_6[0]))/2)
        Zero_Data_L_DipX1P_6.append(float(a)) 
        
#------------------------------------------------------CONVERTED------------------------------------------------------
#--------------------------------- RIDGE ---------------------------------
    Av_Data_L_RidgeX5P_1 = [] 
    Zero_Data_L_RidgeX5P_1 = [] 
    Av_Data_L_RidgeX5P_2 = []
    Zero_Data_L_RidgeX5P_2 = []
    Av_Data_L_RidgeX5P_3 = []
    Zero_Data_L_RidgeX5P_3 = []
    Av_Data_L_RidgeX5P_4 = []
    Zero_Data_L_RidgeX5P_4 = []
    Av_Data_L_RidgeX5P_5 = []
    Zero_Data_L_RidgeX5P_5 = []
    Av_Data_L_RidgeX5P_6 = []
    Zero_Data_L_RidgeX5P_6 = []

    for x in Data_L_RidgeX5P_1: #~
        a = x/2
        Av_Data_L_RidgeX5P_1.append(float(a))
    for x in Av_Data_L_RidgeX5P_1:
        a = x - ((abs(Av_Data_L_RidgeX5P_1[-1])-abs(Av_Data_L_RidgeX5P_1[0]))/2)
        Zero_Data_L_RidgeX5P_1.append(float(a))
    for x in Data_L_RidgeX5P_2: #~
        a = x/2
        Av_Data_L_RidgeX5P_2.append(float(a))
    for x in Av_Data_L_RidgeX5P_2:
        a = x - ((abs(Av_Data_L_RidgeX5P_2[-1])-abs(Av_Data_L_RidgeX5P_2[0]))/2)
        Zero_Data_L_RidgeX5P_2.append(float(a))
    for x in Data_L_RidgeX5P_3: #~
        a = x/2
        Av_Data_L_RidgeX5P_3.append(float(a))
    for x in Av_Data_L_RidgeX5P_3:
        a = x - ((abs(Av_Data_L_RidgeX5P_3[-1])-abs(Av_Data_L_RidgeX5P_3[0]))/2)
        Zero_Data_L_RidgeX5P_3.append(float(a))
    for x in Data_L_RidgeX5P_4: #~
        a = x/2
        Av_Data_L_RidgeX5P_4.append(float(a))
    for x in Av_Data_L_RidgeX5P_4:
        a = x - ((abs(Av_Data_L_RidgeX5P_4[-1])-abs(Av_Data_L_RidgeX5P_4[0]))/2)
        Zero_Data_L_RidgeX5P_4.append(float(a))
    for x in Data_L_RidgeX5P_5: #~
        a = x/2
        Av_Data_L_RidgeX5P_5.append(float(a))
    for x in Av_Data_L_RidgeX5P_5:
        a = x - ((abs(Av_Data_L_RidgeX5P_5[-1])-abs(Av_Data_L_RidgeX5P_5[0]))/2)
        Zero_Data_L_RidgeX5P_5.append(float(a))
    for x in Data_L_RidgeX5P_6: #~
        a = x/2
        Av_Data_L_RidgeX5P_6.append(float(a))
    for x in Av_Data_L_RidgeX5P_6:
        a = x - ((abs(Av_Data_L_RidgeX5P_6[-1])-abs(Av_Data_L_RidgeX5P_6[0]))/2)
        Zero_Data_L_RidgeX5P_6.append(float(a)) 

#--------------------------------- MID ---------------------------------
    Av_Data_L_MidX5P_1 = [] 
    Zero_Data_L_MidX5P_1 = [] 
    Av_Data_L_MidX5P_2 = []
    Zero_Data_L_MidX5P_2 = []
    Av_Data_L_MidX5P_3 = []
    Zero_Data_L_MidX5P_3 = []
    Av_Data_L_MidX5P_4 = []
    Zero_Data_L_MidX5P_4 = []
    Av_Data_L_MidX5P_5 = []
    Zero_Data_L_MidX5P_5 = []
    Av_Data_L_MidX5P_6 = []
    Zero_Data_L_MidX5P_6 = []

    for x in Data_L_MidX5P_1: #~
        a = x/2
        Av_Data_L_MidX5P_1.append(float(a))
    for x in Av_Data_L_MidX5P_1:
        a = x - ((abs(Av_Data_L_MidX5P_1[-1])-abs(Av_Data_L_MidX5P_1[0]))/2)
        Zero_Data_L_MidX5P_1.append(float(a))
    for x in Data_L_MidX5P_2: #~
        a = x/2
        Av_Data_L_MidX5P_2.append(float(a))
    for x in Av_Data_L_MidX5P_2:
        a = x - ((abs(Av_Data_L_MidX5P_2[-1])-abs(Av_Data_L_MidX5P_2[0]))/2)
        Zero_Data_L_MidX5P_2.append(float(a))
    for x in Data_L_MidX5P_3: #~
        a = x/2
        Av_Data_L_MidX5P_3.append(float(a))
    for x in Av_Data_L_MidX5P_3:
        a = x - ((abs(Av_Data_L_MidX5P_3[-1])-abs(Av_Data_L_MidX5P_3[0]))/2)
        Zero_Data_L_MidX5P_3.append(float(a))
    for x in Data_L_MidX5P_4: #~
        a = x/2
        Av_Data_L_MidX5P_4.append(float(a))
    for x in Av_Data_L_MidX5P_4:
        a = x - ((abs(Av_Data_L_MidX5P_4[-1])-abs(Av_Data_L_MidX5P_4[0]))/2)
        Zero_Data_L_MidX5P_4.append(float(a))
    for x in Data_L_MidX5P_5: #~
        a = x/2
        Av_Data_L_MidX5P_5.append(float(a))
    for x in Av_Data_L_MidX5P_5:
        a = x - ((abs(Av_Data_L_MidX5P_5[-1])-abs(Av_Data_L_MidX5P_5[0]))/2)
        Zero_Data_L_MidX5P_5.append(float(a))
    for x in Data_L_MidX5P_6: #~
        a = x/2
        Av_Data_L_MidX5P_6.append(float(a))
    for x in Av_Data_L_MidX5P_6:
        a = x - ((abs(Av_Data_L_MidX5P_6[-1])-abs(Av_Data_L_MidX5P_6[0]))/2)
        Zero_Data_L_MidX5P_6.append(float(a)) 
        
#--------------------------------- DIP ---------------------------------
    Av_Data_L_DipX5P_1 = [] 
    Zero_Data_L_DipX5P_1 = [] 
    Av_Data_L_DipX5P_2 = []
    Zero_Data_L_DipX5P_2 = []
    Av_Data_L_DipX5P_3 = []
    Zero_Data_L_DipX5P_3 = []
    Av_Data_L_DipX5P_4 = []
    Zero_Data_L_DipX5P_4 = []
    Av_Data_L_DipX5P_5 = []
    Zero_Data_L_DipX5P_5 = []
    Av_Data_L_DipX5P_6 = []
    Zero_Data_L_DipX5P_6 = []

    for x in Data_L_DipX5P_1: #~
        a = x/2
        Av_Data_L_DipX5P_1.append(float(a))
    for x in Av_Data_L_DipX5P_1:
        a = x - ((abs(Av_Data_L_DipX5P_1[-1])-abs(Av_Data_L_DipX5P_1[0]))/2)
        Zero_Data_L_DipX5P_1.append(float(a))
    for x in Data_L_DipX5P_2: #~
        a = x/2
        Av_Data_L_DipX5P_2.append(float(a))
    for x in Av_Data_L_DipX5P_2:
        a = x - ((abs(Av_Data_L_DipX5P_2[-1])-abs(Av_Data_L_DipX5P_2[0]))/2)
        Zero_Data_L_DipX5P_2.append(float(a))
    for x in Data_L_DipX5P_3: #~
        a = x/2
        Av_Data_L_DipX5P_3.append(float(a))
    for x in Av_Data_L_DipX5P_3:
        a = x - ((abs(Av_Data_L_DipX5P_3[-1])-abs(Av_Data_L_DipX5P_3[0]))/2)
        Zero_Data_L_DipX5P_3.append(float(a))
    for x in Data_L_DipX5P_4: #~
        a = x/2
        Av_Data_L_DipX5P_4.append(float(a))
    for x in Av_Data_L_DipX5P_4:
        a = x - ((abs(Av_Data_L_DipX5P_4[-1])-abs(Av_Data_L_DipX5P_4[0]))/2)
        Zero_Data_L_DipX5P_4.append(float(a))
    for x in Data_L_DipX5P_5: #~
        a = x/2
        Av_Data_L_DipX5P_5.append(float(a))
    for x in Av_Data_L_DipX5P_5:
        a = x - ((abs(Av_Data_L_DipX5P_5[-1])-abs(Av_Data_L_DipX5P_5[0]))/2)
        Zero_Data_L_DipX5P_5.append(float(a))
    for x in Data_L_DipX5P_6: #~
        a = x/2
        Av_Data_L_DipX5P_6.append(float(a))
    for x in Av_Data_L_DipX5P_6:
        a = x - ((abs(Av_Data_L_DipX5P_6[-1])-abs(Av_Data_L_DipX5P_6[0]))/2)
        Zero_Data_L_DipX5P_6.append(float(a)) 
        
#------------------------------------------------------ZERO DATA Y------------------------------------------------------
#------------------------------------------------------BARE MICELLE------------------------------------------------------
#--------------------------------- RIDGE ---------------------------------
    Av_Data_L_RidgeY1P_1 = [] 
    Zero_Data_L_RidgeY1P_1 = [] 
    Av_Data_L_RidgeY1P_2 = []
    Zero_Data_L_RidgeY1P_2 = []
    Av_Data_L_RidgeY1P_3 = []
    Zero_Data_L_RidgeY1P_3 = []
    Av_Data_L_RidgeY1P_4 = []
    Zero_Data_L_RidgeY1P_4 = []
    Av_Data_L_RidgeY1P_5 = []
    Zero_Data_L_RidgeY1P_5 = []
    Av_Data_L_RidgeY1P_6 = []
    Zero_Data_L_RidgeY1P_6 = []

    
    for x in Data_L_RidgeY1P_1: #~
        a = x/2
        Av_Data_L_RidgeY1P_1.append(float(a))
    Av_W_Ridge1P_1_NOT_NAN = [item for item in Av_Data_L_RidgeY1P_1 if not(math.isnan(item)) == True]  
    for x in Av_W_Ridge1P_1_NOT_NAN:
        a = x - ((abs(Av_W_Ridge1P_1_NOT_NAN[-1])-abs(Av_W_Ridge1P_1_NOT_NAN[0]))/2)
        Zero_Data_L_RidgeY1P_1.append(float(a))
    
    for x in Data_L_RidgeY1P_2: #~
        a = x/2
        Av_Data_L_RidgeY1P_2.append(float(a))
    Av_W_Ridge1P_2_NOT_NAN = [item for item in Av_Data_L_RidgeY1P_2 if not(math.isnan(item)) == True]  
    for x in Av_W_Ridge1P_2_NOT_NAN:
        a = x - ((abs(Av_W_Ridge1P_2_NOT_NAN[-1])-abs(Av_W_Ridge1P_2_NOT_NAN[0]))/2)
        Zero_Data_L_RidgeY1P_2.append(float(a))

    
    for x in Data_L_RidgeY1P_3: #~
        a = x/2
        Av_Data_L_RidgeY1P_3.append(float(a))
    Av_W_Ridge1P_3_NOT_NAN = [item for item in Av_Data_L_RidgeY1P_3 if not(math.isnan(item)) == True]  
    for x in Av_W_Ridge1P_3_NOT_NAN:
        a = x - ((abs(Av_W_Ridge1P_3_NOT_NAN[-1])-abs(Av_W_Ridge1P_3_NOT_NAN[0]))/2)
        Zero_Data_L_RidgeY1P_3.append(float(a))

    
    for x in Data_L_RidgeY1P_4: #~
        a = x/2
        Av_Data_L_RidgeY1P_4.append(float(a))
    Av_W_Ridge1P_4_NOT_NAN = [item for item in Av_Data_L_RidgeY1P_4 if not(math.isnan(item)) == True]  
    for x in Av_W_Ridge1P_4_NOT_NAN:
        a = x - ((abs(Av_W_Ridge1P_4_NOT_NAN[-1])-abs(Av_W_Ridge1P_4_NOT_NAN[0]))/2)
        Zero_Data_L_RidgeY1P_4.append(float(a))

    
    for x in Data_L_RidgeY1P_5: #~
        a = x/2
        Av_Data_L_RidgeY1P_5.append(float(a))
    Av_W_Ridge1P_5_NOT_NAN = [item for item in Av_Data_L_RidgeY1P_5 if not(math.isnan(item)) == True]  
    for x in Av_W_Ridge1P_5_NOT_NAN:
        a = x - ((abs(Av_W_Ridge1P_5_NOT_NAN[-1])-abs(Av_W_Ridge1P_5_NOT_NAN[0]))/2)
        Zero_Data_L_RidgeY1P_5.append(float(a))
    
    
    for x in Data_L_RidgeY1P_6: #~
        a = x/2
        Av_Data_L_RidgeY1P_6.append(float(a))
    Av_W_Ridge1P_6_NOT_NAN = [item for item in Av_Data_L_RidgeY1P_6 if not(math.isnan(item)) == True]  
    for x in Av_W_Ridge1P_6_NOT_NAN:
        a = x - ((abs(Av_W_Ridge1P_6_NOT_NAN[-1])-abs(Av_W_Ridge1P_6_NOT_NAN[0]))/2)
        Zero_Data_L_RidgeY1P_6.append(float(a)) 

#W_Ridge1P_1_NOT_NAN = [item for item in Zero_Data_L_RidgeY1P_1 if not(math.isnan(item)) == True] #Removing "nan" from W data.
#--------------------------------- MID ---------------------------------
    Av_Data_L_MidY1P_1 = [] 
    Zero_Data_L_MidY1P_1 = [] 
    Av_Data_L_MidY1P_2 = []
    Zero_Data_L_MidY1P_2 = []
    Av_Data_L_MidY1P_3 = []
    Zero_Data_L_MidY1P_3 = []
    Av_Data_L_MidY1P_4 = []
    Zero_Data_L_MidY1P_4 = []
    Av_Data_L_MidY1P_5 = []
    Zero_Data_L_MidY1P_5 = []
    Av_Data_L_MidY1P_6 = []
    Zero_Data_L_MidY1P_6 = []

    for x in Data_L_MidY1P_1: #~
        a = x/2
        Av_Data_L_MidY1P_1.append(float(a))
    Av_W_Mid1P_1_NOT_NAN = [item for item in Av_Data_L_MidY1P_1 if not(math.isnan(item)) == True]  
    for x in Av_W_Mid1P_1_NOT_NAN:
        a = x - ((abs(Av_W_Mid1P_1_NOT_NAN[-1])-abs(Av_W_Mid1P_1_NOT_NAN[0]))/2)
        Zero_Data_L_MidY1P_1.append(float(a))
        
    for x in Data_L_MidY1P_2: #~
        a = x/2
        Av_Data_L_MidY1P_2.append(float(a))
    Av_W_Mid1P_2_NOT_NAN = [item for item in Av_Data_L_MidY1P_2 if not(math.isnan(item)) == True]  
    for x in Av_W_Mid1P_2_NOT_NAN:
        a = x - ((abs(Av_W_Mid1P_2_NOT_NAN[-1])-abs(Av_W_Mid1P_2_NOT_NAN[0]))/2)
        Zero_Data_L_MidY1P_2.append(float(a))
        
    for x in Data_L_MidY1P_3: #~
        a = x/2
        Av_Data_L_MidY1P_3.append(float(a))
    Av_W_Mid1P_3_NOT_NAN = [item for item in Av_Data_L_MidY1P_3 if not(math.isnan(item)) == True]  
    for x in Av_W_Mid1P_3_NOT_NAN:
        a = x - ((abs(Av_W_Mid1P_3_NOT_NAN[-1])-abs(Av_W_Mid1P_3_NOT_NAN[0]))/2)
        Zero_Data_L_MidY1P_3.append(float(a))
    
    for x in Data_L_MidY1P_4: #~
        a = x/2
        Av_Data_L_MidY1P_4.append(float(a))
    Av_W_Mid1P_4_NOT_NAN = [item for item in Av_Data_L_MidY1P_4 if not(math.isnan(item)) == True]  
    for x in Av_W_Mid1P_4_NOT_NAN:
        a = x - ((abs(Av_W_Mid1P_4_NOT_NAN[-1])-abs(Av_W_Mid1P_4_NOT_NAN[0]))/2)
        Zero_Data_L_MidY1P_4.append(float(a))
        
    for x in Data_L_MidY1P_5: #~
        a = x/2
        Av_Data_L_MidY1P_5.append(float(a))
    Av_W_Mid1P_5_NOT_NAN = [item for item in Av_Data_L_MidY1P_5 if not(math.isnan(item)) == True]  
    for x in Av_W_Mid1P_5_NOT_NAN:
        a = x - ((abs(Av_W_Mid1P_5_NOT_NAN[-1])-abs(Av_W_Mid1P_5_NOT_NAN[0]))/2)
        Zero_Data_L_MidY1P_5.append(float(a))
    
    for x in Data_L_MidY1P_6: #~
        a = x/2
        Av_Data_L_MidY1P_6.append(float(a))
    Av_W_Mid1P_6_NOT_NAN = [item for item in Av_Data_L_MidY1P_6 if not(math.isnan(item)) == True]  
    for x in Av_W_Mid1P_6_NOT_NAN:
        a = x - ((abs(Av_W_Mid1P_6_NOT_NAN[-1])-abs(Av_W_Mid1P_6_NOT_NAN[0]))/2)
        Zero_Data_L_MidY1P_6.append(float(a)) 
        
#--------------------------------- DIP ---------------------------------
    Av_Data_L_DipY1P_1 = [] 
    Zero_Data_L_DipY1P_1 = [] 
    Av_Data_L_DipY1P_2 = []
    Zero_Data_L_DipY1P_2 = []
    Av_Data_L_DipY1P_3 = []
    Zero_Data_L_DipY1P_3 = []
    Av_Data_L_DipY1P_4 = []
    Zero_Data_L_DipY1P_4 = []
    Av_Data_L_DipY1P_5 = []
    Zero_Data_L_DipY1P_5 = []
    Av_Data_L_DipY1P_6 = []
    Zero_Data_L_DipY1P_6 = []

    for x in Data_L_DipY1P_1: #~
        a = x/2
        Av_Data_L_DipY1P_1.append(float(a))
    Av_W_Dip1P_1_NOT_NAN = [item for item in Av_Data_L_DipY1P_1 if not(math.isnan(item)) == True]  
    for x in Av_W_Dip1P_1_NOT_NAN:
        a = x - ((abs(Av_W_Dip1P_1_NOT_NAN[-1])-abs(Av_W_Dip1P_1_NOT_NAN[0]))/2)
        Zero_Data_L_DipY1P_1.append(float(a))
        
    for x in Data_L_DipY1P_2: #~
        a = x/2
        Av_Data_L_DipY1P_2.append(float(a))
    Av_W_Dip1P_2_NOT_NAN = [item for item in Av_Data_L_DipY1P_2 if not(math.isnan(item)) == True]  
    for x in Av_W_Dip1P_2_NOT_NAN:
        a = x - ((abs(Av_W_Dip1P_2_NOT_NAN[-1])-abs(Av_W_Dip1P_2_NOT_NAN[0]))/2)
        Zero_Data_L_DipY1P_2.append(float(a))
        
    for x in Data_L_DipY1P_3: #~
        a = x/2
        Av_Data_L_DipY1P_3.append(float(a))
    Av_W_Dip1P_3_NOT_NAN = [item for item in Av_Data_L_DipY1P_3 if not(math.isnan(item)) == True]  
    for x in Av_W_Dip1P_3_NOT_NAN:
        a = x - ((abs(Av_W_Dip1P_3_NOT_NAN[-1])-abs(Av_W_Dip1P_3_NOT_NAN[0]))/2)
        Zero_Data_L_DipY1P_3.append(float(a))
    
    for x in Data_L_DipY1P_4: #~
        a = x/2
        Av_Data_L_DipY1P_4.append(float(a))
    Av_W_Dip1P_4_NOT_NAN = [item for item in Av_Data_L_DipY1P_4 if not(math.isnan(item)) == True]  
    for x in Av_W_Dip1P_4_NOT_NAN:
        a = x - ((abs(Av_W_Dip1P_4_NOT_NAN[-1])-abs(Av_W_Dip1P_4_NOT_NAN[0]))/2)
        Zero_Data_L_DipY1P_4.append(float(a))
        
    for x in Data_L_DipY1P_5: #~
        a = x/2
        Av_Data_L_DipY1P_5.append(float(a))
    Av_W_Dip1P_5_NOT_NAN = [item for item in Av_Data_L_DipY1P_5 if not(math.isnan(item)) == True]  
    for x in Av_W_Dip1P_5_NOT_NAN:
        a = x - ((abs(Av_W_Dip1P_5_NOT_NAN[-1])-abs(Av_W_Dip1P_5_NOT_NAN[0]))/2)
        Zero_Data_L_DipY1P_5.append(float(a))
    
    for x in Data_L_DipY1P_6: #~
        a = x/2
        Av_Data_L_DipY1P_6.append(float(a))
    Av_W_Dip1P_6_NOT_NAN = [item for item in Av_Data_L_DipY1P_6 if not(math.isnan(item)) == True]  
    for x in Av_W_Dip1P_6_NOT_NAN:
        a = x - ((abs(Av_W_Dip1P_6_NOT_NAN[-1])-abs(Av_W_Dip1P_6_NOT_NAN[0]))/2)
        Zero_Data_L_DipY1P_6.append(float(a)) 
        
#------------------------------------------------------ATM cooling------------------------------------------------------
#--------------------------------- RIDGE ---------------------------------
    Av_Data_L_RidgeY5P_1 = [] 
    Zero_Data_L_RidgeY5P_1 = [] 
    Av_Data_L_RidgeY5P_2 = []
    Zero_Data_L_RidgeY5P_2 = []
    Av_Data_L_RidgeY5P_3 = []
    Zero_Data_L_RidgeY5P_3 = []
    Av_Data_L_RidgeY5P_4 = []
    Zero_Data_L_RidgeY5P_4 = []
    Av_Data_L_RidgeY5P_5 = []
    Zero_Data_L_RidgeY5P_5 = []
    Av_Data_L_RidgeY5P_6 = []
    Zero_Data_L_RidgeY5P_6 = []

    for x in Data_L_RidgeY5P_1: #~
        a = x/2
        Av_Data_L_RidgeY5P_1.append(float(a))
    Av_W_Ridge5P_1_NOT_NAN = [item for item in Av_Data_L_RidgeY5P_1 if not(math.isnan(item)) == True]
    for x in Av_W_Ridge5P_1_NOT_NAN:
        a = x - ((abs(Av_W_Ridge5P_1_NOT_NAN[-1])-abs(Av_W_Ridge5P_1_NOT_NAN[0]))/2)
        Zero_Data_L_RidgeY5P_1.append(float(a))

    for x in Data_L_RidgeY5P_2: #~
        a = x/2
        Av_Data_L_RidgeY5P_2.append(float(a))
    Av_W_Ridge5P_2_NOT_NAN = [item for item in Av_Data_L_RidgeY5P_2 if not(math.isnan(item)) == True]
    for x in Av_W_Ridge5P_2_NOT_NAN:
        a = x - ((abs(Av_W_Ridge5P_2_NOT_NAN[-1])-abs(Av_W_Ridge5P_2_NOT_NAN[0]))/2)
        Zero_Data_L_RidgeY5P_2.append(float(a))

    for x in Data_L_RidgeY5P_3: #~
        a = x/2
        Av_Data_L_RidgeY5P_3.append(float(a))
    Av_W_Ridge5P_3_NOT_NAN = [item for item in Av_Data_L_RidgeY5P_3 if not(math.isnan(item)) == True]
    for x in Av_W_Ridge5P_3_NOT_NAN:
        a = x - ((abs(Av_W_Ridge5P_3_NOT_NAN[-1])-abs(Av_W_Ridge5P_3_NOT_NAN[0]))/2)
        Zero_Data_L_RidgeY5P_3.append(float(a))

    for x in Data_L_RidgeY5P_4: #~
        a = x/2
        Av_Data_L_RidgeY5P_4.append(float(a))
    Av_W_Ridge5P_4_NOT_NAN = [item for item in Av_Data_L_RidgeY5P_4 if not(math.isnan(item)) == True]
    for x in Av_W_Ridge5P_4_NOT_NAN:
        a = x - ((abs(Av_W_Ridge5P_4_NOT_NAN[-1])-abs(Av_W_Ridge5P_4_NOT_NAN[0]))/2)
        Zero_Data_L_RidgeY5P_4.append(float(a))

    for x in Data_L_RidgeY5P_5: #~
        a = x/2
        Av_Data_L_RidgeY5P_5.append(float(a))
    Av_W_Ridge5P_5_NOT_NAN = [item for item in Av_Data_L_RidgeY5P_5 if not(math.isnan(item)) == True]
    for x in Av_W_Ridge5P_5_NOT_NAN:
        a = x - ((abs(Av_W_Ridge5P_5_NOT_NAN[-1])-abs(Av_W_Ridge5P_5_NOT_NAN[0]))/2)
        Zero_Data_L_RidgeY5P_5.append(float(a))

    for x in Data_L_RidgeY5P_6: #~
        a = x/2
        Av_Data_L_RidgeY5P_6.append(float(a))
    Av_W_Ridge5P_6_NOT_NAN = [item for item in Av_Data_L_RidgeY5P_6 if not(math.isnan(item)) == True]
    for x in Av_W_Ridge5P_6_NOT_NAN:
        a = x - ((abs(Av_W_Ridge5P_6_NOT_NAN[-1])-abs(Av_W_Ridge5P_6_NOT_NAN[0]))/2)
        Zero_Data_L_RidgeY5P_6.append(float(a)) 

#--------------------------------- MID ---------------------------------
    Av_Data_L_MidY5P_1 = [] 
    Zero_Data_L_MidY5P_1 = [] 
    Av_Data_L_MidY5P_2 = []
    Zero_Data_L_MidY5P_2 = []
    Av_Data_L_MidY5P_3 = []
    Zero_Data_L_MidY5P_3 = []
    Av_Data_L_MidY5P_4 = []
    Zero_Data_L_MidY5P_4 = []
    Av_Data_L_MidY5P_5 = []
    Zero_Data_L_MidY5P_5 = []
    Av_Data_L_MidY5P_6 = []
    Zero_Data_L_MidY5P_6 = []

    for x in Data_L_MidY5P_1: #~
        a = x/2
        Av_Data_L_MidY5P_1.append(float(a))
    Av_W_Mid5P_1_NOT_NAN = [item for item in Av_Data_L_MidY5P_1 if not(math.isnan(item)) == True]  
    for x in Av_W_Mid5P_1_NOT_NAN:
        a = x - ((abs(Av_W_Mid5P_1_NOT_NAN[-1])-abs(Av_W_Mid5P_1_NOT_NAN[0]))/2)
        Zero_Data_L_MidY5P_1.append(float(a))

    for x in Data_L_MidY5P_2: #~
        a = x/2
        Av_Data_L_MidY5P_2.append(float(a))
    Av_W_Mid5P_2_NOT_NAN = [item for item in Av_Data_L_MidY5P_2 if not(math.isnan(item)) == True]  
    for x in Av_W_Mid5P_2_NOT_NAN:
        a = x - ((abs(Av_W_Mid5P_2_NOT_NAN[-1])-abs(Av_W_Mid5P_2_NOT_NAN[0]))/2)
        Zero_Data_L_MidY5P_2.append(float(a))

    for x in Data_L_MidY5P_3: #~
        a = x/2
        Av_Data_L_MidY5P_3.append(float(a))
    Av_W_Mid5P_3_NOT_NAN = [item for item in Av_Data_L_MidY5P_3 if not(math.isnan(item)) == True]  
    for x in Av_W_Mid5P_3_NOT_NAN:
        a = x - ((abs(Av_W_Mid5P_3_NOT_NAN[-1])-abs(Av_W_Mid5P_3_NOT_NAN[0]))/2)
        Zero_Data_L_MidY5P_3.append(float(a))

    for x in Data_L_MidY5P_4: #~
        a = x/2
        Av_Data_L_MidY5P_4.append(float(a))
    Av_W_Mid5P_4_NOT_NAN = [item for item in Av_Data_L_MidY5P_4 if not(math.isnan(item)) == True]  
    for x in Av_W_Mid5P_4_NOT_NAN:
        a = x - ((abs(Av_W_Mid5P_4_NOT_NAN[-1])-abs(Av_W_Mid5P_4_NOT_NAN[0]))/2)
        Zero_Data_L_MidY5P_4.append(float(a))

    for x in Data_L_MidY5P_5: #~
        a = x/2
        Av_Data_L_MidY5P_5.append(float(a))
    Av_W_Mid5P_5_NOT_NAN = [item for item in Av_Data_L_MidY5P_5 if not(math.isnan(item)) == True]  
    for x in Av_W_Mid5P_5_NOT_NAN:
        a = x - ((abs(Av_W_Mid5P_5_NOT_NAN[-1])-abs(Av_W_Mid5P_5_NOT_NAN[0]))/2)
        Zero_Data_L_MidY5P_5.append(float(a))

    for x in Data_L_MidY5P_6: #~
        a = x/2
        Av_Data_L_MidY5P_6.append(float(a))
    Av_W_Mid5P_6_NOT_NAN = [item for item in Av_Data_L_MidY5P_6 if not(math.isnan(item)) == True]  
    for x in Av_W_Mid5P_6_NOT_NAN:
        a = x - ((abs(Av_W_Mid5P_6_NOT_NAN[-1])-abs(Av_W_Mid5P_6_NOT_NAN[0]))/2)
        Zero_Data_L_MidY5P_6.append(float(a)) 
    
#--------------------------------- DIP ---------------------------------
    Av_Data_L_DipY5P_1 = [] 
    Zero_Data_L_DipY5P_1 = [] 
    Av_Data_L_DipY5P_2 = []
    Zero_Data_L_DipY5P_2 = []
    Av_Data_L_DipY5P_3 = []
    Zero_Data_L_DipY5P_3 = []
    Av_Data_L_DipY5P_4 = []
    Zero_Data_L_DipY5P_4 = []
    Av_Data_L_DipY5P_5 = []
    Zero_Data_L_DipY5P_5 = []
    Av_Data_L_DipY5P_6 = []
    Zero_Data_L_DipY5P_6 = []

    for x in Data_L_DipY5P_1: #~
        a = x/2
        Av_Data_L_DipY5P_1.append(float(a))
    Av_W_Dip5P_1_NOT_NAN = [item for item in Av_Data_L_DipY5P_1 if not(math.isnan(item)) == True]  
    for x in Av_W_Dip5P_1_NOT_NAN:
        a = x - ((abs(Av_W_Dip5P_1_NOT_NAN[-1])-abs(Av_W_Dip5P_1_NOT_NAN[0]))/2)
        Zero_Data_L_DipY5P_1.append(float(a))

    for x in Data_L_DipY5P_2: #~
        a = x/2
        Av_Data_L_DipY5P_2.append(float(a))
    Av_W_Dip5P_2_NOT_NAN = [item for item in Av_Data_L_DipY5P_2 if not(math.isnan(item)) == True]  
    for x in Av_W_Dip5P_2_NOT_NAN:
        a = x - ((abs(Av_W_Dip5P_2_NOT_NAN[-1])-abs(Av_W_Dip5P_2_NOT_NAN[0]))/2)
        Zero_Data_L_DipY5P_2.append(float(a))

    for x in Data_L_DipY5P_3: #~
        a = x/2
        Av_Data_L_DipY5P_3.append(float(a))
    Av_W_Dip5P_3_NOT_NAN = [item for item in Av_Data_L_DipY5P_3 if not(math.isnan(item)) == True]  
    for x in Av_W_Dip5P_3_NOT_NAN:
        a = x - ((abs(Av_W_Dip5P_3_NOT_NAN[-1])-abs(Av_W_Dip5P_3_NOT_NAN[0]))/2)
        Zero_Data_L_DipY5P_3.append(float(a))

    for x in Data_L_DipY5P_4: #~
        a = x/2
        Av_Data_L_DipY5P_4.append(float(a))
    Av_W_Dip5P_4_NOT_NAN = [item for item in Av_Data_L_DipY5P_4 if not(math.isnan(item)) == True]  
    for x in Av_W_Dip5P_4_NOT_NAN:
        a = x - ((abs(Av_W_Dip5P_4_NOT_NAN[-1])-abs(Av_W_Dip5P_4_NOT_NAN[0]))/2)
        Zero_Data_L_DipY5P_4.append(float(a))

    for x in Data_L_DipY5P_5: #~
        a = x/2
        Av_Data_L_DipY5P_5.append(float(a))
    Av_W_Dip5P_5_NOT_NAN = [item for item in Av_Data_L_DipY5P_5 if not(math.isnan(item)) == True]  
    for x in Av_W_Dip5P_5_NOT_NAN:
        a = x - ((abs(Av_W_Dip5P_5_NOT_NAN[-1])-abs(Av_W_Dip5P_5_NOT_NAN[0]))/2)
        Zero_Data_L_DipY5P_5.append(float(a))

    for x in Data_L_DipY5P_6: #~
        a = x/2
        Av_Data_L_DipY5P_6.append(float(a))
    Av_W_Dip5P_6_NOT_NAN = [item for item in Av_Data_L_DipY5P_6 if not(math.isnan(item)) == True]  
    for x in Av_W_Dip5P_6_NOT_NAN:
        a = x - ((abs(Av_W_Dip5P_6_NOT_NAN[-1])-abs(Av_W_Dip5P_6_NOT_NAN[0]))/2)
        Zero_Data_L_DipY5P_6.append(float(a)) 
        
#------------------------------------------------------Cleaning X------------------------------------------------------
#Removing "noise" data (copy of X and Y to saturate length requirements)
#--------------------------------- Full Growth ---------------------------------
    X1P_1 = []                                       #Micelle 1
    Data_X_list1 = Data_X1P_1.values.tolist()
    def X1P_1_value(Data_X_list1):
        for i in (range(len(Data_X_list1)-1)):
            if Data_X_list1[i] != Data_X_list1[i+1]:
                X1P_1.append(Data_X_list1[i])
            if Data_X_list1[i] == Data_X_list1[i+1]:
                pass
    X1P_1_value(Data_X_list1)

    X1P_2 = []                                       #Micelle 2
    Data_X_list6 = Data_X1P_2.values.tolist()
    def X1P_2_value(Data_X_list6):
        for i in (range(len(Data_X_list6)-1)):
            if Data_X_list6[i] != Data_X_list6[i+1]:
                X1P_2.append(Data_X_list6[i])
            if Data_X_list6[i] == Data_X_list6[i+1]:
                pass
    X1P_2_value(Data_X_list6)

    X1P_3 = []                                       #Micelle 3
    Data_X_list10 = Data_X1P_3.values.tolist()
    def X1P_3_value(Data_X_list10):
        for i in (range(len(Data_X_list10)-1)):
            if Data_X_list10[i] != Data_X_list10[i+1]:
                X1P_3.append(Data_X_list10[i])
            if Data_X_list10[i] == Data_X_list10[i+1]:
                pass
    X1P_3_value(Data_X_list10)

    X1P_4 = []                                       #Micelle 4
    Data_X_list11 = Data_X1P_4.values.tolist()
    def X1P_4_value(Data_X_list11):
        for i in (range(len(Data_X_list11)-1)):
            if Data_X_list11[i] != Data_X_list11[i+1]:
                X1P_4.append(Data_X_list11[i])
            if Data_X_list11[i] == Data_X_list11[i+1]:
                pass
    X1P_4_value(Data_X_list11)

    X1P_5 = []                                       #Micelle 5
    Data_X_list22 = Data_X1P_5.values.tolist()
    def X1P_5_value(Data_X_list22):
        for i in (range(len(Data_X_list22)-1)):
            if Data_X_list22[i] != Data_X_list22[i+1]:
                X1P_5.append(Data_X_list22[i])
            if Data_X_list22[i] == Data_X_list22[i+1]:
                pass
    X1P_5_value(Data_X_list22)

    X1P_6 = []                                       #Micelle 6
    Data_X_list33 = Data_X1P_6.values.tolist()
    def X1P_6_value(Data_X_list33):
        for i in (range(len(Data_X_list33)-1)):
            if Data_X_list33[i] != Data_X_list33[i+1]:
                X1P_6.append(Data_X_list33[i])
            if Data_X_list33[i] == Data_X_list33[i+1]:
                pass
    X1P_6_value(Data_X_list33)

#--------------------------------- ATM cooling ---------------------------------
    X5P_1 = []                                       #Micelle 1
    Data_X_list1 = Data_X5P_1.values.tolist()
    def X5P_1_value(Data_X_list1):
        for i in (range(len(Data_X_list1)-1)):
            if Data_X_list1[i] != Data_X_list1[i+1]:
                X5P_1.append(Data_X_list1[i])
            if Data_X_list1[i] == Data_X_list1[i+1]:
                pass
    X5P_1_value(Data_X_list1)

    X5P_2 = []                                       #Micelle 2
    Data_X_list6 = Data_X5P_2.values.tolist()
    def X5P_2_value(Data_X_list6):
        for i in (range(len(Data_X_list6)-1)):
            if Data_X_list6[i] != Data_X_list6[i+1]:
                X5P_2.append(Data_X_list6[i])
            if Data_X_list6[i] == Data_X_list6[i+1]:
                pass
    X5P_2_value(Data_X_list6)

    X5P_3 = []                                       #Micelle 3
    Data_X_list10 = Data_X5P_3.values.tolist()
    def X5P_3_value(Data_X_list10):
        for i in (range(len(Data_X_list10)-1)):
            if Data_X_list10[i] != Data_X_list10[i+1]:
                X5P_3.append(Data_X_list10[i])
            if Data_X_list10[i] == Data_X_list10[i+1]:
                pass
    X5P_3_value(Data_X_list10)

    X5P_4 = []                                       #Micelle 4
    Data_X_list11 = Data_X5P_4.values.tolist()
    def X5P_4_value(Data_X_list11):
        for i in (range(len(Data_X_list11)-1)):
            if Data_X_list11[i] != Data_X_list11[i+1]:
                X5P_4.append(Data_X_list11[i])
            if Data_X_list11[i] == Data_X_list11[i+1]:
                pass
    X5P_4_value(Data_X_list11)

    X5P_5 = []                                       #Micelle 5
    Data_X_list22 = Data_X5P_5.values.tolist()
    def X5P_5_value(Data_X_list22):
        for i in (range(len(Data_X_list22)-1)):
            if Data_X_list22[i] != Data_X_list22[i+1]:
                X5P_5.append(Data_X_list22[i])
            if Data_X_list22[i] == Data_X_list22[i+1]:
                pass
    X5P_5_value(Data_X_list22)

    X5P_6 = []                                       #Micelle 6
    Data_X_list33 = Data_X5P_6.values.tolist()
    def X5P_6_value(Data_X_list33):
        for i in (range(len(Data_X_list33)-1)):
            if Data_X_list33[i] != Data_X_list33[i+1]:
                X5P_6.append(Data_X_list33[i])
            if Data_X_list33[i] == Data_X_list33[i+1]:
                pass
    X5P_6_value(Data_X_list33)

#------------------------------------------------------Cleaning Y------------------------------------------------------
#Removing "noise" data (copy of X and Y to saturate length requirements)
#--------------------------------- Full Growth ---------------------------------
    Y1P_1 = []                                       #Micelle 1
    Data_Y_list1 = Data_Y1P_1.values.tolist()
    def Y1P_1_value(Data_Y_list1):
        for i in (range(len(Data_Y_list1)-1)):
            if Data_Y_list1[i] != Data_Y_list1[i+1]:
                Y1P_1.append(Data_Y_list1[i])
            if Data_Y_list1[i] == Data_Y_list1[i+1]:
                pass
    Y1P_1_value(Data_Y_list1)
    
    Y1P_2 = []                                       #Micelle 2
    Data_Y_list6 = Data_Y1P_2.values.tolist()
    def Y1P_2_value(Data_Y_list6):
        for i in (range(len(Data_Y_list6)-1)):
            if Data_Y_list6[i] != Data_Y_list6[i+1]:
                Y1P_2.append(Data_Y_list6[i])
            if Data_Y_list6[i] == Data_Y_list6[i+1]:
                pass
    Y1P_2_value(Data_Y_list6)
    
    Y1P_3 = []                                       #Micelle 3
    Data_Y_list10 = Data_Y1P_3.values.tolist()
    def Y1P_3_value(Data_Y_list10):
        for i in (range(len(Data_Y_list10)-1)):
            if Data_Y_list10[i] != Data_Y_list10[i+1]:
                Y1P_3.append(Data_Y_list10[i])
            if Data_Y_list10[i] == Data_Y_list10[i+1]:
                pass
    Y1P_3_value(Data_Y_list10)
    
    Y1P_4 = []                                       #Micelle 4
    Data_Y_list11 = Data_Y1P_4.values.tolist()
    def Y1P_4_value(Data_Y_list11):
        for i in (range(len(Data_Y_list11)-1)):
            if Data_Y_list11[i] != Data_Y_list11[i+1]:
                Y1P_4.append(Data_Y_list11[i])
            if Data_Y_list11[i] == Data_Y_list11[i+1]:
                pass
    Y1P_4_value(Data_Y_list11)
    
    Y1P_5 = []                                       #Micelle 5
    Data_Y_list22 = Data_Y1P_5.values.tolist()
    def Y1P_5_value(Data_Y_list22):
        for i in (range(len(Data_Y_list22)-1)):
            if Data_Y_list22[i] != Data_Y_list22[i+1]:
                Y1P_5.append(Data_Y_list22[i])
            if Data_Y_list22[i] == Data_Y_list22[i+1]:
                pass
    Y1P_5_value(Data_Y_list22)
    
    Y1P_6 = []                                       #Micelle 6
    Data_Y_list33 = Data_Y1P_6.values.tolist()
    def Y1P_6_value(Data_Y_list33):
        for i in (range(len(Data_Y_list33)-1)):
            if Data_Y_list33[i] != Data_Y_list33[i+1]:
                Y1P_6.append(Data_Y_list33[i])
            if Data_Y_list33[i] == Data_Y_list33[i+1]:
                pass
    Y1P_6_value(Data_Y_list33)

#--------------------------------- ATM cooling ---------------------------------
    Y5P_1 = []                                       #Micelle 1
    Data_Y_list1 = Data_Y5P_1.values.tolist()
    def Y5P_1_value(Data_Y_list1):
        for i in (range(len(Data_Y_list1)-1)):
            if Data_Y_list1[i] != Data_Y_list1[i+1]:
                Y5P_1.append(Data_Y_list1[i])
            if Data_Y_list1[i] == Data_Y_list1[i+1]:
                pass
    Y5P_1_value(Data_Y_list1)
    
    Y5P_2 = []                                       #Micelle 2
    Data_Y_list6 = Data_Y5P_2.values.tolist()
    def Y5P_2_value(Data_Y_list6):
        for i in (range(len(Data_Y_list6)-1)):
            if Data_Y_list6[i] != Data_Y_list6[i+1]:
                Y5P_2.append(Data_Y_list6[i])
            if Data_Y_list6[i] == Data_Y_list6[i+1]:
                pass
    Y5P_2_value(Data_Y_list6)
    
    Y5P_3 = []                                       #Micelle 3
    Data_Y_list10 = Data_Y5P_3.values.tolist()
    def Y5P_3_value(Data_Y_list10):
        for i in (range(len(Data_Y_list10)-1)):
            if Data_Y_list10[i] != Data_Y_list10[i+1]:
                Y5P_3.append(Data_Y_list10[i])
            if Data_Y_list10[i] == Data_Y_list10[i+1]:
                pass
    Y5P_3_value(Data_Y_list10)
    
    Y5P_4 = []                                       #Micelle 4
    Data_Y_list11 = Data_Y5P_4.values.tolist()
    def Y5P_4_value(Data_Y_list11):
        for i in (range(len(Data_Y_list11)-1)):
            if Data_Y_list11[i] != Data_Y_list11[i+1]:
                Y5P_4.append(Data_Y_list11[i])
            if Data_Y_list11[i] == Data_Y_list11[i+1]:
                pass
    Y5P_4_value(Data_Y_list11)
    
    Y5P_5 = []                                       #Micelle 5
    Data_Y_list22 = Data_Y5P_5.values.tolist()
    def Y5P_5_value(Data_Y_list22):
        for i in (range(len(Data_Y_list22)-1)):
            if Data_Y_list22[i] != Data_Y_list22[i+1]:
                Y5P_5.append(Data_Y_list22[i])
            if Data_Y_list22[i] == Data_Y_list22[i+1]:
                pass
    Y5P_5_value(Data_Y_list22)
    
    Y5P_6 = []                                       #Micelle 6
    Data_Y_list33 = Data_Y5P_6.values.tolist()
    def Y5P_6_value(Data_Y_list33):
        for i in (range(len(Data_Y_list33)-1)):
            if Data_Y_list33[i] != Data_Y_list33[i+1]:
                Y5P_6.append(Data_Y_list33[i])
            if Data_Y_list33[i] == Data_Y_list33[i+1]:
                pass
    Y5P_6_value(Data_Y_list33)
    
    
    def Area_Volume_XDATA():
#------------------------------------------------------Average Z (X-DATA)------------------------------------------------------
        print("====================================================")
        print("Average height of 10-minute using L-Data:")
        print("====================================================")
#--------------------------------- Base ---------------------------------
    
        sum_Data_L_Ridge1P1_2 = list(map (add,Zero_Data_L_RidgeX1P_1[5:150], Zero_Data_L_RidgeX1P_2[5:150])) 
        sum_Data_L_Ridge1P3_4 = list(map (add,Zero_Data_L_RidgeX1P_3[5:150], Zero_Data_L_RidgeX1P_4[5:150]))
        sum_Data_L_Ridge1P5_6 = list(map (add,Zero_Data_L_RidgeX1P_5[5:150], Zero_Data_L_RidgeX1P_6[5:150]))
        sum_Data_L_Ridge1P1_2_3_4 = list(map (add,sum_Data_L_Ridge1P1_2, sum_Data_L_Ridge1P3_4[5:150]))
        SUMTOT_Data_L_Ridge1P = sum(list(map (add,sum_Data_L_Ridge1P1_2_3_4, sum_Data_L_Ridge1P5_6)))
        AVERAGE_Zero_Data_L_Ridge_1P= SUMTOT_Data_L_Ridge1P/(len(sum_Data_L_Ridge1P1_2*6)) #Data range * inputs (6)
        print("Full growth Average Height (Ridge):","    ",AVERAGE_Zero_Data_L_Ridge_1P,"nm")
    
        sum_Data_L_Middle1P1_2 = list(map (add,Zero_Data_L_MidX1P_1[5:150], Zero_Data_L_MidX1P_2[5:150]))
        sum_Data_L_Middle1P3_4= list(map (add,Zero_Data_L_MidX1P_3[5:150], Zero_Data_L_MidX1P_4[5:150]))
        sum_Data_L_Middle1P5_6 = list(map (add,Zero_Data_L_MidX1P_5[5:150], Zero_Data_L_MidX1P_6[5:150]))
        sum_Data_L_Middle1P1_2_3_4 = list(map (add,sum_Data_L_Middle1P1_2, sum_Data_L_Middle1P3_4[5:150]))
        SUMTOT_Data_L_Middle1P = sum(list(map (add,sum_Data_L_Middle1P1_2_3_4, sum_Data_L_Middle1P5_6)))
        AVERAGE_Zero_Data_L_Middle_1P= SUMTOT_Data_L_Middle1P/(len(sum_Data_L_Middle1P1_2*6)) #Data range * inputs (6)
        print("Full growth Average Height (Mid):","      ",AVERAGE_Zero_Data_L_Middle_1P,"nm")    
        
        sum_Data_L_Dip1P1_2 = list(map (add,Zero_Data_L_DipX1P_1[5:150], Zero_Data_L_DipX1P_2[5:150]))
        sum_Data_L_Dip1P3_4= list(map (add,Zero_Data_L_DipX1P_3[5:150], Zero_Data_L_DipX1P_4[5:150]))
        sum_Data_L_Dip1P5_6 = list(map (add,Zero_Data_L_DipX1P_5[5:150], Zero_Data_L_DipX1P_6[5:150]))
        sum_Data_L_Dip1P1_2_3_4 = list(map (add,sum_Data_L_Dip1P1_2, sum_Data_L_Dip1P3_4[5:150]))
        SUMTOT_Data_L_Dip1P = sum(list(map (add,sum_Data_L_Dip1P1_2_3_4, sum_Data_L_Dip1P5_6)))
        AVERAGE_Zero_Data_L_Dip_1P= SUMTOT_Data_L_Dip1P/(len(sum_Data_L_Dip1P1_2*6)) #Data range * inputs (6)
        print("Full growth Average Height (Dip):","      ",AVERAGE_Zero_Data_L_Dip_1P,"nm")    
        
        
    
#--------------------------------- Converted ---------------------------------

        sum_Data_L_Ridge5P1_2 = list(map (add,Zero_Data_L_RidgeX5P_1[5:150], Zero_Data_L_RidgeX5P_2[5:150])) 
        sum_Data_L_Ridge5P3_4 = list(map (add,Zero_Data_L_RidgeX5P_3[5:150], Zero_Data_L_RidgeX5P_4[5:150]))
        sum_Data_L_Ridge5P5_6 = list(map (add,Zero_Data_L_RidgeX5P_5[5:150], Zero_Data_L_RidgeX5P_6[5:150]))
        sum_Data_L_Ridge5P1_2_3_4 = list(map (add,sum_Data_L_Ridge5P1_2, sum_Data_L_Ridge5P3_4[5:150]))
        SUMTOT_Data_L_Ridge5P = sum(list(map (add,sum_Data_L_Ridge5P1_2_3_4, sum_Data_L_Ridge5P5_6)))
        AVERAGE_Zero_Data_L_Ridge_5P= SUMTOT_Data_L_Ridge5P/(len(sum_Data_L_Ridge5P1_2*6)) #Data range * inputs (6)
        print("ATM growth Average Height (Ridge):","     ",AVERAGE_Zero_Data_L_Ridge_5P,"nm")
    
        sum_Data_L_Middle5P1_2 = list(map (add,Zero_Data_L_MidX5P_1[5:150], Zero_Data_L_MidX5P_2[5:150]))
        sum_Data_L_Middle5P3_4= list(map (add,Zero_Data_L_MidX5P_3[5:150], Zero_Data_L_MidX5P_4[5:150]))
        sum_Data_L_Middle5P5_6 = list(map (add,Zero_Data_L_MidX5P_5[5:150], Zero_Data_L_MidX5P_6[5:150]))
        sum_Data_L_Middle5P1_2_3_4 = list(map (add,sum_Data_L_Middle5P1_2, sum_Data_L_Middle5P3_4[5:150]))
        SUMTOT_Data_L_Middle5P = sum(list(map (add,sum_Data_L_Middle5P1_2_3_4, sum_Data_L_Middle5P5_6)))
        AVERAGE_Zero_Data_L_Middle_5P= SUMTOT_Data_L_Middle5P/(len(sum_Data_L_Middle5P1_2*6)) #Data range * inputs (6)
        print("ATM growth Average Height (Mid):","       ",AVERAGE_Zero_Data_L_Middle_5P,"nm")
        
        sum_Data_L_Dip5P1_2 = list(map (add,Zero_Data_L_DipX5P_1[5:150], Zero_Data_L_DipX5P_2[5:150]))
        sum_Data_L_Dip5P3_4= list(map (add,Zero_Data_L_DipX5P_3[5:150], Zero_Data_L_DipX5P_4[5:150]))
        sum_Data_L_Dip5P5_6 = list(map (add,Zero_Data_L_DipX5P_5[5:150], Zero_Data_L_DipX5P_6[5:150]))
        sum_Data_L_Dip5P1_2_3_4 = list(map (add,sum_Data_L_Dip5P1_2, sum_Data_L_Dip5P3_4[5:150]))
        SUMTOT_Data_L_Dip5P = sum(list(map (add,sum_Data_L_Dip5P1_2_3_4, sum_Data_L_Dip5P5_6)))
        AVERAGE_Zero_Data_L_Dip_5P= SUMTOT_Data_L_Dip5P/(len(sum_Data_L_Dip5P1_2*6)) #Data range * inputs (6)
        print("ATM growth Average Height (Dip):","       ",AVERAGE_Zero_Data_L_Dip_5P,"nm")
        
        
        
        
#------------------------------------------------------Average Z (Y-DATA)------------------------------------------------------
        print("====================================================")
        print("Average height of 10-minute using W-Data:")
        print("====================================================")
#--------------------------------- Base  ---------------------------------
    
        sum_Data_W_Ridge1P1_2 = list(map (add,Zero_Data_L_RidgeY1P_1[5:40], Zero_Data_L_RidgeY1P_2[5:40])) 
        sum_Data_W_Ridge1P3_4 = list(map (add,Zero_Data_L_RidgeY1P_3[5:40], Zero_Data_L_RidgeY1P_4[5:40]))
        sum_Data_W_Ridge1P5_6 = list(map (add,Zero_Data_L_RidgeY1P_5[5:40], Zero_Data_L_RidgeY1P_6[5:40]))
        sum_Data_W_Ridge1P1_2_3_4 = list(map (add,sum_Data_W_Ridge1P1_2, sum_Data_W_Ridge1P3_4))
        SUMTOT_Data_W_Ridge1P = sum(list(map (add,sum_Data_W_Ridge1P1_2_3_4, sum_Data_W_Ridge1P5_6)))
        AVERAGE_Zero_Data_W_Ridge_1P= SUMTOT_Data_W_Ridge1P/(len(sum_Data_W_Ridge1P1_2*6)) #Data range * inputs (6)
        print("Full growth Average Height (Ridge):","    ",AVERAGE_Zero_Data_W_Ridge_1P,"nm")
    
        sum_Data_W_Middle1P1_2 = list(map (add,Zero_Data_L_MidY1P_1[5:40], Zero_Data_L_MidY1P_2[5:40]))
        sum_Data_W_Middle1P3_4= list(map (add,Zero_Data_L_MidY1P_3[5:40], Zero_Data_L_MidY1P_4[5:40]))
        sum_Data_W_Middle1P5_6 = list(map (add,Zero_Data_L_MidY1P_5[5:40], Zero_Data_L_MidY1P_6[5:40]))
        sum_Data_W_Middle1P1_2_3_4 = list(map (add,sum_Data_W_Middle1P1_2, sum_Data_W_Middle1P3_4))
        SUMTOT_Data_W_Middle1P = sum(list(map (add,sum_Data_W_Middle1P1_2_3_4, sum_Data_W_Middle1P5_6)))
        AVERAGE_Zero_Data_W_Middle_1P= SUMTOT_Data_W_Middle1P/(len(sum_Data_W_Middle1P1_2*6)) #Data range * inputs (6)
        print("Full growth Average Height (Mid):","      ",AVERAGE_Zero_Data_W_Middle_1P,"nm")    
        
        
        sum_Data_W_Dip1P1_2 = list(map (add,Zero_Data_L_DipY1P_1[5:40], Zero_Data_L_DipY1P_2[5:40]))
        sum_Data_W_Dip1P3_4= list(map (add,Zero_Data_L_DipY1P_3[5:40], Zero_Data_L_DipY1P_4[5:40]))
        sum_Data_W_Dip1P5_6 = list(map (add,Zero_Data_L_DipY1P_5[5:40], Zero_Data_L_DipY1P_6[5:40]))
        sum_Data_W_Dip1P1_2_3_4 = list(map (add,sum_Data_W_Dip1P1_2, sum_Data_W_Dip1P3_4))
        SUMTOT_Data_W_Dip1P = sum(list(map (add,sum_Data_W_Dip1P1_2_3_4, sum_Data_W_Dip1P5_6)))
        AVERAGE_Zero_Data_W_Dip_1P= SUMTOT_Data_W_Dip1P/(len(sum_Data_W_Dip1P1_2*6)) #Data range * inputs (6)
        print("Full growth Average Height (Dip):","      ",AVERAGE_Zero_Data_W_Dip_1P,"nm")    
        
        
    
#--------------------------------- Converted ---------------------------------

        sum_Data_W_Ridge5P1_2 = list(map (add,Zero_Data_L_RidgeY5P_1[5:40], Zero_Data_L_RidgeY5P_2[5:40])) 
        sum_Data_W_Ridge5P3_4 = list(map (add,Zero_Data_L_RidgeY5P_3[5:40], Zero_Data_L_RidgeY5P_4[5:40]))
        sum_Data_W_Ridge5P5_6 = list(map (add,Zero_Data_L_RidgeY5P_5[5:40], Zero_Data_L_RidgeY5P_6[5:40]))
        sum_Data_W_Ridge5P1_2_3_4 = list(map (add,sum_Data_W_Ridge5P1_2, sum_Data_W_Ridge5P3_4))
        SUMTOT_Data_W_Ridge5P = sum(list(map (add,sum_Data_W_Ridge5P1_2_3_4, sum_Data_W_Ridge5P5_6)))
        AVERAGE_Zero_Data_W_Ridge_5P= SUMTOT_Data_W_Ridge5P/(len(sum_Data_W_Ridge5P1_2*6)) #Data range * inputs (6)
        print("ATM growth Average Height (Ridge):","     ",AVERAGE_Zero_Data_W_Ridge_5P,"nm")
    
        sum_Data_W_Middle5P1_2 = list(map (add,Zero_Data_L_MidY5P_1[5:40], Zero_Data_L_MidY5P_2[5:40]))
        sum_Data_W_Middle5P3_4= list(map (add,Zero_Data_L_MidY5P_3[5:40], Zero_Data_L_MidY5P_4[5:40]))
        sum_Data_W_Middle5P5_6 = list(map (add,Zero_Data_L_MidY5P_5[5:40], Zero_Data_L_MidY5P_6[5:40]))
        sum_Data_W_Middle5P1_2_3_4 = list(map (add,sum_Data_W_Middle5P1_2, sum_Data_W_Middle5P3_4))
        SUMTOT_Data_W_Middle5P = sum(list(map (add,sum_Data_W_Middle5P1_2_3_4, sum_Data_W_Middle5P5_6)))
        AVERAGE_Zero_Data_W_Middle_5P= SUMTOT_Data_W_Middle5P/(len(sum_Data_W_Middle5P1_2*6)) #Data range * inputs (6)
        print("ATM growth Average Height (Mid):","       ",AVERAGE_Zero_Data_W_Middle_5P,"nm")  
        
        
        sum_Data_W_Dip5P1_2 = list(map (add,Zero_Data_L_DipY5P_1[5:40], Zero_Data_L_DipY5P_2[5:40]))
        sum_Data_W_Dip5P3_4= list(map (add,Zero_Data_L_DipY5P_3[5:40], Zero_Data_L_DipY5P_4[5:40]))
        sum_Data_W_Dip5P5_6 = list(map (add,Zero_Data_L_DipY5P_5[5:40], Zero_Data_L_DipY5P_6[5:40]))
        sum_Data_W_Dip5P1_2_3_4 = list(map (add,sum_Data_W_Dip5P1_2, sum_Data_W_Dip5P3_4))
        SUMTOT_Data_W_Dip5P = sum(list(map (add,sum_Data_W_Dip5P1_2_3_4, sum_Data_W_Dip5P5_6)))
        AVERAGE_Zero_Data_W_Dip_5P= SUMTOT_Data_W_Dip5P/(len(sum_Data_W_Dip5P1_2*6)) #Data range * inputs (6)
        print("Full growth Average Height (Dip):","      ",AVERAGE_Zero_Data_W_Dip_5P,"nm") 
        
#------------------------------------------------------Base Area (X*Y)------------------------------------------------------
        print("====================================================")
        print("Average base area of 10-minute growth:")
        print("====================================================")
#Removing "nan" from list and then minusing MAX X/Y from MIN X/Y from same list to give X and Y distance for each micelle.
#--------------------------------- Base ---------------------------------

        Y1P_1_NOT_NAN = [item for item in Y1P_1 if not(math.isnan(item)) == True]
        BaseArea_XY_1P1 = X1P_1[-1]*Y1P_1_NOT_NAN[-1]
        #print(BaseArea_XY_1)
        Y1P_2_NOT_NAN = [item for item in Y1P_2 if not(math.isnan(item)) == True]
        BaseArea_XY_1P2 = X1P_2[-1]*Y1P_2_NOT_NAN[-1]
        Y1P_3_NOT_NAN = [item for item in Y1P_3 if not(math.isnan(item)) == True]
        BaseArea_XY_1P3 = X1P_3[-1]*Y1P_3_NOT_NAN[-1]
        Y1P_4_NOT_NAN = [item for item in Y1P_4 if not(math.isnan(item)) == True]
        BaseArea_XY_1P4 = X1P_4[-1]*Y1P_4_NOT_NAN[-1]
        Y1P_5_NOT_NAN = [item for item in Y1P_5 if not(math.isnan(item)) == True]
        BaseArea_XY_1P5 = X1P_5[-1]*Y1P_5_NOT_NAN[-1]
        Y1P_6_NOT_NAN = [item for item in Y1P_6 if not(math.isnan(item)) == True]
        BaseArea_XY_1P6 = X1P_6[-1]*Y1P_6_NOT_NAN[-1]
        AVERAGE_BaseArea_XY_1P = ((BaseArea_XY_1P1+BaseArea_XY_1P2+BaseArea_XY_1P3+BaseArea_XY_1P4+BaseArea_XY_1P5+BaseArea_XY_1P6)/6)*(10**-9)
        print("Full growth Average base area (XY):","    ",AVERAGE_BaseArea_XY_1P,"nm^2")
    
#--------------------------------- Converted ---------------------------------

        Y5P_1_NOT_NAN = [item for item in Y5P_1 if not(math.isnan(item)) == True]
        BaseArea_XY_5P1 = X5P_1[-1]*Y5P_1_NOT_NAN[-1]
        #print(BaseArea_XY_1)
        Y5P_2_NOT_NAN = [item for item in Y5P_2 if not(math.isnan(item)) == True]
        BaseArea_XY_5P2 = X5P_2[-1]*Y5P_2_NOT_NAN[-1]
        Y5P_3_NOT_NAN = [item for item in Y5P_3 if not(math.isnan(item)) == True]
        BaseArea_XY_5P3 = X5P_3[-1]*Y5P_3_NOT_NAN[-1]
        Y5P_4_NOT_NAN = [item for item in Y5P_4 if not(math.isnan(item)) == True]
        BaseArea_XY_5P4 = X5P_4[-1]*Y5P_4_NOT_NAN[-1]
        Y5P_5_NOT_NAN = [item for item in Y5P_5 if not(math.isnan(item)) == True]
        BaseArea_XY_5P5 = X5P_5[-1]*Y5P_5_NOT_NAN[-1]
        Y5P_6_NOT_NAN = [item for item in Y5P_6 if not(math.isnan(item)) == True]
        BaseArea_XY_5P6 = X5P_6[-1]*Y5P_6_NOT_NAN[-1]
        AVERAGE_BaseArea_XY_5P = ((BaseArea_XY_5P1+BaseArea_XY_5P2+BaseArea_XY_5P3+BaseArea_XY_5P4+BaseArea_XY_5P5+BaseArea_XY_5P6)/6)*(10**-9)
        print("ATM growth Average base area (XY):","     ",AVERAGE_BaseArea_XY_5P,"nm^2")
        
#------------------------------------------------------Volume (X*Y)*Z L-Ridge -------------------------------------------------
        print("====================================================")
        print("Average volume of 10-minute growth using L-Ridge:")
        print("====================================================")
#--------------------------------- Base ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height.
        One_Pulse_Volume_LR = AVERAGE_BaseArea_XY_1P*AVERAGE_Zero_Data_L_Ridge_1P #"LR" = Length Ridge
        print("Full growth Average volume (Ridge):","    ",One_Pulse_Volume_LR,"nm^3")
#--------------------------------- Converted ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height. 
        Five_Pulse_Volume_LR= AVERAGE_BaseArea_XY_5P*AVERAGE_Zero_Data_L_Ridge_5P
        print("ATM growth Average volume (Ridge):","     ",Five_Pulse_Volume_LR,"nm^3")
        
#------------------------------------------------------Volume (X*Y)*Z W-Ridge--------------------------------------------------
        print("====================================================")
        print("Average volume of 10-minute growth using W-Ridge:")
        print("====================================================")
#--------------------------------- Base ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height.
        One_Pulse_Volume_WR = AVERAGE_BaseArea_XY_1P*AVERAGE_Zero_Data_W_Ridge_1P #"WR" - Width Ridge
        print("Full growth Average volume (Ridge):","    ",One_Pulse_Volume_WR,"nm^3")
#--------------------------------- Converted ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height. 
        Five_Pulse_Volume_WR= AVERAGE_BaseArea_XY_5P*AVERAGE_Zero_Data_W_Ridge_5P
        print("ATM growth Average volume (Ridge):","     ",Five_Pulse_Volume_WR,"nm^3")
        
#------------------------------------------------------Volume (X*Y)*Z L-Mid----------------------------------------------------
        print("====================================================")
        print("Average volume of 10-minute growth using L-Middle:")
        print("====================================================")
#--------------------------------- Base ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height.
        One_Pulse_Volume_LM = AVERAGE_BaseArea_XY_1P*AVERAGE_Zero_Data_L_Middle_1P
        print("Full growth Average volume (Mid):","      ",One_Pulse_Volume_LM,"nm^3")
#--------------------------------- Converted ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height. 
        Five_Pulse_Volume_LM= AVERAGE_BaseArea_XY_5P*AVERAGE_Zero_Data_L_Middle_5P
        print("ATM growth Average volume (Mid):","       ",Five_Pulse_Volume_LM,"nm^3")
    
#------------------------------------------------------Volume (X*Y)*Z W-Mid----------------------------------------------------
        print("====================================================")
        print("Average volume of 10-minute growth using W-Middle:")
        print("====================================================")
#--------------------------------- Base ---------------------------------  
        One_Pulse_Volume_WM = AVERAGE_BaseArea_XY_1P*AVERAGE_Zero_Data_W_Middle_1P
        print("Full growth Average volume (Mid):","      ",One_Pulse_Volume_WM,"nm^3")
#--------------------------------- Converted --------------------------------- 
        Five_Pulse_Volume_WM= AVERAGE_BaseArea_XY_5P*AVERAGE_Zero_Data_W_Middle_5P
        print("ATM growth Average volume (Mid):","       ",Five_Pulse_Volume_WM,"nm^3")
#------------------------------------------------------Volume (X*Y)*Z L-Dip----------------------------------------------------
        print("====================================================")
        print("Average volume of 10-minute growth using L-Dip:")
        print("====================================================")
#--------------------------------- Base ---------------------------------  
        One_Pulse_Volume_LD = AVERAGE_BaseArea_XY_1P*AVERAGE_Zero_Data_L_Dip_1P #LD = Length Dip
        print("Full growth Average volume (Dip):","      ",One_Pulse_Volume_LD,"nm^3")
#--------------------------------- Converted --------------------------------- 
        Five_Pulse_Volume_LD= AVERAGE_BaseArea_XY_5P*AVERAGE_Zero_Data_L_Dip_5P
        print("ATM growth Average volume (Dip):","       ",Five_Pulse_Volume_LD,"nm^3")
        
        
#------------------------------------------------------Volume (X*Y)*Z W-Dip----------------------------------------------------
        print("====================================================")
        print("Average volume of 10-minute growth using W-Dip:")
        print("====================================================")
#--------------------------------- Base ---------------------------------  
        One_Pulse_Volume_WD = AVERAGE_BaseArea_XY_1P*AVERAGE_Zero_Data_W_Dip_1P
        print("Full growth Average volume (Dip):","      ",One_Pulse_Volume_WD,"nm^3")
#--------------------------------- Converted --------------------------------- 
        Five_Pulse_Volume_WD= AVERAGE_BaseArea_XY_5P*AVERAGE_Zero_Data_W_Dip_5P
        print("ATM growth Average volume (Dip):","       ",Five_Pulse_Volume_WD,"nm^3")
    
#------------------------------------------------------Micelle Length X----------------------------------------------------
        print("====================================================")
        print("Average micelle length X:")
        print("====================================================")
#--------------------------------- Base ---------------------------------  
        print("Average bare micelle length:",((X1P_1[-1]+X1P_2[-1]+X1P_3[-1]+X1P_4[-1]+X1P_5[-1]+X1P_6[-1])/6))
        print("Average converted micelle length:",((X5P_1[-1]+X5P_2[-1]+X5P_3[-1]+X5P_4[-1]+X5P_5[-1]+X5P_6[-1])/6))

#------------------------------------------------------Micelle Length Y----------------------------------------------------
        print("====================================================")
        print("Average micelle length Y:")
        print("====================================================")
#--------------------------------- Base ---------------------------------  
        print("Average bare micelle length:",((Y1P_1_NOT_NAN[-1]+Y1P_2_NOT_NAN[-1]+Y1P_3_NOT_NAN[-1]+Y1P_4_NOT_NAN[-1]+Y1P_5_NOT_NAN[-1]+Y1P_6_NOT_NAN[-1])/6))
        print("Average converted micelle length:",((Y5P_1_NOT_NAN[-1]+Y5P_2_NOT_NAN[-1]+Y5P_3_NOT_NAN[-1]+Y5P_4_NOT_NAN[-1]+Y5P_5_NOT_NAN[-1]+Y5P_6_NOT_NAN[-1])/6))
#=================================================FOR LOOPING DATA FOR EXPORT================================================= 
    
        
        DataSet_1_FULL_RIDGE_ZX.append(AVERAGE_Zero_Data_L_Ridge_1P) #Lists for Z-data (X-axis)
        DataSet_1_ATM_RIDGE_ZX.append(AVERAGE_Zero_Data_L_Ridge_5P)
        DataSet_1_FULL_MID_ZX.append(AVERAGE_Zero_Data_L_Middle_1P)
        DataSet_1_ATM_MID_ZX.append(AVERAGE_Zero_Data_L_Middle_5P)
        DataSet_1_FULL_DIP_ZX.append(AVERAGE_Zero_Data_L_Dip_1P)#
        DataSet_1_ATM_DIP_ZX.append(AVERAGE_Zero_Data_L_Dip_5P)#
        DataSet_1_FULL_RIDGE_ZY.append(AVERAGE_Zero_Data_W_Ridge_1P) #For loops for Z-Height using Y-axis
        DataSet_1_ATM_RIDGE_ZY.append(AVERAGE_Zero_Data_W_Ridge_5P)
        DataSet_1_FULL_MID_ZY.append(AVERAGE_Zero_Data_W_Middle_1P)
        DataSet_1_ATM_MID_ZY.append(AVERAGE_Zero_Data_W_Middle_5P)
        DataSet_1_FULL_DIP_ZY.append(AVERAGE_Zero_Data_W_Dip_1P)#
        DataSet_1_ATM_DIP_ZY.append(AVERAGE_Zero_Data_W_Dip_5P)#
        DataSet_1_FULL_BASE.append(AVERAGE_BaseArea_XY_1P)#For loops for Base Area (X*Y)
        DataSet_1_ATM_BASE.append(AVERAGE_BaseArea_XY_5P)
        DataSet_1_FULL_VOL_RIDGE_X.append(One_Pulse_Volume_LR)#Lists for Volume using X-axis Ridge
        DataSet_1_ATM_VOL_RIDGE_X.append(Five_Pulse_Volume_LR)
        DataSet_1_FULL_VOL_RIDGE_Y.append(One_Pulse_Volume_WR)#Lists for Volume using Y-axis Ridge
        DataSet_1_ATM_VOL_RIDGE_Y.append(Five_Pulse_Volume_WR)
        DataSet_1_FULL_VOL_MID_X.append(One_Pulse_Volume_LM)#Lists for Volume using X-axis Mid
        DataSet_1_ATM_VOL_MID_X.append(Five_Pulse_Volume_LM)
        DataSet_1_FULL_VOL_MID_Y.append(One_Pulse_Volume_WM)#Lists for Volume using Y-axis Mid
        DataSet_1_ATM_VOL_MID_Y.append(Five_Pulse_Volume_WM)
        DataSet_1_FULL_VOL_DIP_X.append(One_Pulse_Volume_LD)#Lists for Volume using X-axis Dip
        DataSet_1_ATM_VOL_DIP_X.append(Five_Pulse_Volume_LD)
        DataSet_1_FULL_VOL_DIP_Y.append(One_Pulse_Volume_WD)#Lists for Volume using Y-axis Dip
        DataSet_1_ATM_VOL_DIP_Y.append(Five_Pulse_Volume_WD)
    
    
    
    
        #print(DataSet_1_FULL_RIDGE_ZX)
        #print(DataSet_1_FULL_MID_ZX)
        #print(DataSet_1_FULL_RIDGE_ZY)
        #print(DataSet_1_FULL_MID_ZY)
        #print(DataSet_1_FULL_BASE)
        #print(DataSet_1_FULL_VOL_RIDGE_X)
        #print(DataSet_1_FULL_VOL_RIDGE_Y)
        #print(DataSet_1_FULL_VOL_MID_X)
        #print(DataSet_1_FULL_VOL_MID_Y)
        
       
    Area_Volume_XDATA()



DataSet_1()
# Out:
# ====================================================
# Average height of 10-minute using L-Data:
# ====================================================
# Full growth Average Height (Ridge):      11.4707851958046 nm
# Full growth Average Height (Mid):        4.377472730977012 nm
# Full growth Average Height (Dip):        7.145278033827584 nm
# ATM growth Average Height (Ridge):       14.05160656355748 nm
# ATM growth Average Height (Mid):         6.633777925591958 nm
# ATM growth Average Height (Dip):         12.815268277103446 nm
# ====================================================
# Average height of 10-minute using W-Data:
# ====================================================
# Full growth Average Height (Ridge):      10.922557936904763 nm
# Full growth Average Height (Mid):        4.8138647188095245 nm
# Full growth Average Height (Dip):        8.913078676428572 nm
# ATM growth Average Height (Ridge):       14.24464681589286 nm
# ATM growth Average Height (Mid):         6.844746550000002 nm
# Full growth Average Height (Dip):        12.942980333630953 nm
# ====================================================
# Average base area of 10-minute growth:
# ====================================================
# Full growth Average base area (XY):      0.0015482294991105733 nm^2
# ATM growth Average base area (XY):       0.0015132994234956856 nm^2
# ====================================================
# Average volume of 10-minute growth using L-Ridge:
# ====================================================
# Full growth Average volume (Ridge):      0.017759408018105535 nm^3
# ATM growth Average volume (Ridge):       0.021264288111819726 nm^3
# ====================================================
# Average volume of 10-minute growth using W-Ridge:
# ====================================================
# Full growth Average volume (Ridge):      0.016910626403660277 nm^3
# ATM growth Average volume (Ridge):       0.021556415814390318 nm^3
# ====================================================
# Average volume of 10-minute growth using L-Middle:
# ====================================================
# Full growth Average volume (Mid):        0.006777332413650733 nm^3
# ATM growth Average volume (Mid):         0.010038892310396716 nm^3
# ====================================================
# Average volume of 10-minute growth using W-Middle:
# ====================================================
# Full growth Average volume (Mid):        0.007452967362388531 nm^3
# ATM growth Average volume (Mid):         0.010358151008089086 nm^3
# ====================================================
# Average volume of 10-minute growth using L-Dip:
# ====================================================
# Full growth Average volume (Dip):        0.011062530231318661 nm^3
# ATM growth Average volume (Dip):         0.019393338095683194 nm^3
# ====================================================
# Average volume of 10-minute growth using W-Dip:
# ====================================================
# Full growth Average volume (Dip):        0.01379949133474014 nm^3
# ATM growth Average volume (Dip):         0.019586604677199717 nm^3
# ====================================================
# Average micelle length X:
# ====================================================
# Average bare micelle length: 2329.3613666666665
# Average converted micelle length: 2356.1392
# ====================================================
# Average micelle length Y:
# ====================================================
# Average bare micelle length: 664.98375
# Average converted micelle length: 642.5015466666667

# %%
def Compare_DataSet_1(): #FULL = BARE, ATM = CONVERTED.
    
    for i in DataSet_1_FULL_RIDGE_ZX:
        DIFF_RIDGE_ZX = np.float_ (DataSet_1_ATM_RIDGE_ZX) - np.float_ (DataSet_1_FULL_RIDGE_ZX)

    for i in DataSet_1_FULL_MID_ZX:
        DIFF_MID_ZX = np.float_ (DataSet_1_ATM_MID_ZX) - np.float_ (DataSet_1_FULL_MID_ZX)
    
    for i in DataSet_1_FULL_DIP_ZX:
        DIFF_DIP_ZX = np.float_ (DataSet_1_ATM_DIP_ZX) - np.float_ (DataSet_1_FULL_DIP_ZX)
    
    for i in DataSet_1_FULL_RIDGE_ZY:
        DIFF_RIDGE_ZY = np.float_ (DataSet_1_ATM_RIDGE_ZY) - np.float_ (DataSet_1_FULL_RIDGE_ZY) 
    
    for i in DataSet_1_FULL_MID_ZY:
        DIFF_MID_ZY = np.float_ (DataSet_1_ATM_MID_ZY) - np.float_ (DataSet_1_FULL_MID_ZY) 
    
    for i in DataSet_1_FULL_DIP_ZY:
        DIFF_DIP_ZY = np.float_ (DataSet_1_ATM_DIP_ZY) - np.float_ (DataSet_1_FULL_DIP_ZY) 
    
    for i in DataSet_1_FULL_BASE:
        DIFF_BASE = np.float_ (DataSet_1_ATM_BASE) - np.float_ (DataSet_1_FULL_BASE) 
    
    for i in DataSet_1_FULL_VOL_RIDGE_X:
        DIFF_VOL_RIDGE_X = np.float_ (DataSet_1_ATM_VOL_RIDGE_X) - np.float_ (DataSet_1_FULL_VOL_RIDGE_X) 
    
    for i in DataSet_1_FULL_VOL_RIDGE_Y:
        DIFF_VOL_RIDGE_Y = np.float_ (DataSet_1_ATM_VOL_RIDGE_Y) - np.float_ (DataSet_1_FULL_VOL_RIDGE_Y) 
    
    for i in DataSet_1_FULL_VOL_MID_X:
        DIFF_VOL_MID_X = np.float_ (DataSet_1_ATM_VOL_MID_X) - np.float_ (DataSet_1_FULL_VOL_MID_X) 
    
    for i in DataSet_1_FULL_VOL_MID_Y:
        DIFF_VOL_MID_Y = np.float_ (DataSet_1_ATM_VOL_MID_Y) - np.float_ (DataSet_1_FULL_VOL_MID_Y) 
    
    for i in DataSet_1_FULL_VOL_DIP_X:
        DIFF_VOL_DIP_X = np.float_ (DataSet_1_ATM_VOL_DIP_X) - np.float_ (DataSet_1_FULL_VOL_DIP_X) 
    
    for i in DataSet_1_FULL_VOL_DIP_Y:
        DIFF_VOL_DIP_Y = np.float_ (DataSet_1_ATM_VOL_DIP_Y) - np.float_ (DataSet_1_FULL_VOL_DIP_Y) 
    
    
    
    
#============================================================PRINT=============================================================
    def calc():
        print("====================================================")
        print("Comparison of Converted - Bare micelles")
        print("====================================================")
    
#------------------------------------------------------Average Z (X-DATA)------------------------------------------------------
        print("====================================================")
        print("Average height L-Data:")
        print("====================================================")
#--------------------------------- Full Growth ---------------------------------
        print("Growth Diff Height (Ridge):","    ",DIFF_RIDGE_ZX,"nm")
        print("Growth Diff Height (Mid):","      ",DIFF_MID_ZX,"nm")    
        print("Growth Diff Height (Dip):","      ",DIFF_DIP_ZX,"nm") 
#------------------------------------------------------Average Z (Y-DATA)------------------------------------------------------
        print("====================================================")
        print("Average height W-Data:")
        print("====================================================")
#--------------------------------- Full Growth  ---------------------------------
        print("Growth Diff Height (Ridge):","    ",DIFF_RIDGE_ZY,"nm")
        print("Growth Diff Height (Mid):","      ",DIFF_MID_ZY,"nm")    
        print("Growth Diff Height (Dip):","      ",DIFF_DIP_ZY,"nm")   
#------------------------------------------------------Base Area (X*Y)------------------------------------------------------
        print("====================================================")
        print("Average base area:")
        print("====================================================")
#Removing "nan" from list and then minusing MAX X/Y from MIN X/Y from same list to give X and Y distance for each micelle.
#--------------------------------- Full Growth ---------------------------------
        print("Growth Diff base area (XY):","    ",DIFF_BASE,"nm^2")
#------------------------------------------------------Volume (X*Y)*Z L-Ridge -------------------------------------------------
        print("====================================================")
        print("Average volume using L-Ridge:")
        print("====================================================")
#--------------------------------- Full growth ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height.
        print("Growth Diff volume (Ridge):","    ",DIFF_VOL_RIDGE_X,"nm^3")
#------------------------------------------------------Volume (X*Y)*Z W-Ridge--------------------------------------------------
        print("====================================================")
        print("Average volume using W-Ridge:")
        print("====================================================")
#--------------------------------- Full Growth ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height.
        print("Growth Diff volume (Ridge):","    ",DIFF_VOL_RIDGE_Y,"nm^3")
#------------------------------------------------------Volume (X*Y)*Z L-Mid----------------------------------------------------
        print("====================================================")
        print("Average volume using L-Middle:")
        print("====================================================")
#--------------------------------- Full Growth ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height.
        print("Growth Diff volume (Mid):","      ",DIFF_VOL_MID_X,"nm^3")
#------------------------------------------------------Volume (X*Y)*Z W-Mid----------------------------------------------------
        print("====================================================")
        print("Average volume using W-Middle:")
        print("====================================================")
#--------------------------------- Full Growth ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height.
        print("Growth Diff volume (Mid):","      ",DIFF_VOL_MID_Y,"nm^3")
#------------------------------------------------------Volume (X*Y)*Z W-Mid----------------------------------------------------
        print("====================================================")
        print("Average volume using L-Dip:")
        print("====================================================")
#--------------------------------- Full Growth ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height.
        print("Growth Diff volume (Dip):","      ",DIFF_VOL_DIP_X,"nm^3")
#------------------------------------------------------Volume (X*Y)*Z W-Mid----------------------------------------------------
        print("====================================================")
        print("Average volume using W-Dip:")
        print("====================================================")       
#--------------------------------- Full Growth ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height.
        print("Growth Diff volume (Dip):","      ",DIFF_VOL_DIP_Y,"nm^3")

    
#=================================================EXPORT TO EXCEL================================================= 
        
    ExportData= [DIFF_RIDGE_ZX,DIFF_MID_ZX,DIFF_DIP_ZX,DIFF_RIDGE_ZY,DIFF_MID_ZY,DIFF_DIP_ZY,
                 DIFF_BASE,DIFF_VOL_RIDGE_X,DIFF_VOL_RIDGE_Y,DIFF_VOL_MID_X,DIFF_VOL_MID_Y,DIFF_VOL_DIP_X,DIFF_VOL_DIP_Y]
    Title= ['X-Ridge','X-Mid','X-Dip','Y-Ridge','Y-Mid','Y-Dip',
            'Base','Volume X-Ridge','Volume Y-Ridge','Volume X-Mid','Volume Y-Mid',
            'Volume X-Dip','Volume Y-Dip']
#=================================================EXPORT PROGRAM================================================= 
    df = pd.DataFrame({
        'Title':Title,
        'Data (nm)':ExportData})
    print(df)
    df.to_excel('C:/Users/Harry/OneDrive/Documents/University of bristol/AFM Images/Python - Micelle topography data/Exported Micelle Data/Bare_Convered_Micelles.xlsx')
    
    
    
    
    
    
    
    
Compare_DataSet_1()
# Out:
#              Title                 Data (nm)
# 0          X-Ridge       [2.580821367752879]
# 1            X-Mid      [2.2563051946149457]
# 2            X-Dip       [5.669990243275862]
# 3          Y-Ridge      [3.3220888789880973]
# 4            Y-Mid      [2.0308818311904773]
# 5            Y-Dip        [4.02990165720238]
# 6             Base  [-3.493007561488769e-05]
# 7   Volume X-Ridge    [0.003504880093714191]
# 8   Volume Y-Ridge    [0.004645789410730041]
# 9     Volume X-Mid    [0.003261559896745983]
# 10    Volume Y-Mid    [0.002905183645700555]
# 11    Volume X-Dip    [0.008330807864364532]
# 12    Volume Y-Dip    [0.005787113342459576]

# %%
#FULL = BARE 
#ATM = CONVERTED
DataSet_2_FULL_RIDGE_ZX = [] #Lists for Z-data (X-axis)
DataSet_2_ATM_RIDGE_ZX = []
DataSet_2_FULL_MID_ZX = []
DataSet_2_ATM_MID_ZX = []
DataSet_2_FULL_DIP_ZX = []
DataSet_2_ATM_DIP_ZX = []
DataSet_2_FULL_RIDGE_ZY = [] #Lists for Z-data (Y-axis)
DataSet_2_ATM_RIDGE_ZY = []
DataSet_2_FULL_MID_ZY = []
DataSet_2_ATM_MID_ZY = []
DataSet_2_FULL_DIP_ZY = []
DataSet_2_ATM_DIP_ZY = []
DataSet_2_FULL_BASE = [] #Lists for Base Area (X*Y)
DataSet_2_ATM_BASE = [] 
DataSet_2_FULL_VOL_RIDGE_X = [] #Lists for Volume using X-axis Ridge
DataSet_2_ATM_VOL_RIDGE_X = []
DataSet_2_FULL_VOL_RIDGE_Y = [] #Lists for Volume using Y-axis Ridge
DataSet_2_ATM_VOL_RIDGE_Y = []
DataSet_2_FULL_VOL_MID_X = [] #Lists for Volume using X-axis Mid
DataSet_2_ATM_VOL_MID_X = []
DataSet_2_FULL_VOL_MID_Y = [] #Lists for Volume using Y-axis Mid
DataSet_2_ATM_VOL_MID_Y = []
DataSet_2_FULL_VOL_DIP_X = [] #Lists for Volumes using X-axis Dip
DataSet_2_ATM_VOL_DIP_X = []
DataSet_2_FULL_VOL_DIP_Y = [] #Lists for Volumes using Y-axis Dip
DataSet_2_ATM_VOL_DIP_Y = []

#Copy file directory into pandas reader to remote access. ALSO replace "\" with "/". KEEP ENCODING.

def DataSet_2():
#====================================================DATA IMPORT====================================================
    Data_1P_1 = pd.read_csv("C:/Users/Harry/OneDrive/Documents/University of bristol/Final Sample AFM/Data/General Height/IA_1/IA_3_Bare.csv",encoding = 'ISO-8859-1') #BARE
    Data_1P_2 = pd.read_csv("C:/Users/Harry/OneDrive/Documents/University of bristol/Final Sample AFM/Data/General Height/OA_3/OA_3_Bare.csv",encoding = 'ISO-8859-1')
    #Data_1P_3 = pd.read_csv("10minFull_ATM3.csv",encoding = 'ISO-8859-1')
    #Data_1P_4 = pd.read_csv("10minFull_ATM4.csv",encoding = 'ISO-8859-1')
    #Data_1P_5 = pd.read_csv("10minFull_ATM5.csv",encoding = 'ISO-8859-1')
    #Data_1P_6 = pd.read_csv("10minFull_ATM6.csv",encoding = 'ISO-8859-1')

    Data_5P_1 = pd.read_csv("C:/Users/Harry/OneDrive/Documents/University of bristol/Final Sample AFM/Data/General Height/IA_1/IA_3_Conv.csv",encoding = 'ISO-8859-1') #CONVERTED
    Data_5P_2 = pd.read_csv("C:/Users/Harry/OneDrive/Documents/University of bristol/Final Sample AFM/Data/General Height/OA_3/OA_3_Conv.csv",encoding = 'ISO-8859-1')
    #Data_5P_3 = pd.read_csv("10minATM_3.csv",encoding = 'ISO-8859-1')
    #Data_5P_4 = pd.read_csv("10minATM_4.csv",encoding = 'ISO-8859-1')
    #Data_5P_5 = pd.read_csv("10minATM_5.csv",encoding = 'ISO-8859-1')
    #Data_5P_6 = pd.read_csv("10minATM_6.csv",encoding = 'ISO-8859-1')
    
#---------------------------------------------------X-Axis------------------------------------------------------
    Data_X1P_1 = (Data_1P_1['X-axis']*(10**3)) #FULL growth
    Data_X1P_2 = (Data_1P_2['X-axis']*(10**3))
    #Data_X1P_3 = (Data_1P_3['X-axis']*(10**3))
    #Data_X1P_4 = (Data_1P_4['X-axis']*(10**3))
    #Data_X1P_5 = (Data_1P_5['X-axis']*(10**3))
    #Data_X1P_6 = (Data_1P_6['X-axis']*(10**3))

    Data_X5P_1 = (Data_5P_1['X-axis']*(10**3)) #ATM growth
    Data_X5P_2 = (Data_5P_2['X-axis']*(10**3))
    #Data_X5P_3 = (Data_5P_3['X-axis']*(10**3))
    #Data_X5P_4 = (Data_5P_4['X-axis']*(10**3))
    #Data_X5P_5 = (Data_5P_5['X-axis']*(10**3))
    #Data_X5P_6 = (Data_5P_6['X-axis']*(10**3))
    
#---------------------------------------------------Y-Axis------------------------------------------------------
    Data_Y1P_1 = (Data_1P_1['Y-axis']*(10**3)) #FULL growth
    Data_Y1P_2 = (Data_1P_2['Y-axis']*(10**3))
    #Data_Y1P_3 = (Data_1P_3['Y-axis']*(10**3))
    #Data_Y1P_4 = (Data_1P_4['Y-axis']*(10**3))
    #Data_Y1P_5 = (Data_1P_5['Y-axis']*(10**3))
    #Data_Y1P_6 = (Data_1P_6['Y-axis']*(10**3))

    Data_Y5P_1 = (Data_5P_1['Y-axis']*(10**3)) #ATM growth
    Data_Y5P_2 = (Data_5P_2['Y-axis']*(10**3))
    #Data_Y5P_3 = (Data_5P_3['Y-axis']*(10**3))
    #Data_Y5P_4 = (Data_5P_4['Y-axis']*(10**3))
    #Data_Y5P_5 = (Data_5P_5['Y-axis']*(10**3))
    #Data_Y5P_6 = (Data_5P_6['Y-axis']*(10**3))
    

#---------------------------------------------------Ridge X------------------------------------------------------
    Data_L_RidgeX1P_1 = list(map (add,Data_1P_1['L-Ridge1'], Data_1P_1['L-Ridge2'] )) #Averaging Ridges' across individual micelles
    Data_L_RidgeX1P_2 = list(map (add,Data_1P_2['L-Ridge1'], Data_1P_2['L-Ridge2'] )) #FULL growth
    #Data_L_RidgeX1P_3 = list(map (add,Data_1P_3['L-Ridge1'], Data_1P_3['L-Ridge2'] ))
    #Data_L_RidgeX1P_4 = list(map (add,Data_1P_4['L-Ridge1'], Data_1P_4['L-Ridge2'] ))
    #Data_L_RidgeX1P_5 = list(map (add,Data_1P_5['L-Ridge1'], Data_1P_5['L-Ridge2'] ))
    #Data_L_RidgeX1P_6 = list(map (add,Data_1P_6['L-Ridge1'], Data_1P_6['L-Ridge2'] ))

    Data_L_RidgeX5P_1 = list(map (add,Data_5P_1['L-Ridge1'], Data_5P_1['L-Ridge2'] )) #ATM growth
    Data_L_RidgeX5P_2 = list(map (add,Data_5P_2['L-Ridge1'], Data_5P_2['L-Ridge2'] )) 
    #Data_L_RidgeX5P_3 = list(map (add,Data_5P_3['L-Ridge1'], Data_5P_3['L-Ridge2'] ))
    #Data_L_RidgeX5P_4 = list(map (add,Data_5P_4['L-Ridge1'], Data_5P_4['L-Ridge2'] ))
    #Data_L_RidgeX5P_5 = list(map (add,Data_5P_5['L-Ridge1'], Data_5P_5['L-Ridge2'] ))
    #Data_L_RidgeX5P_6 = list(map (add,Data_5P_6['L-Ridge1'], Data_5P_6['L-Ridge2'] ))

#---------------------------------------------------Ridge Y------------------------------------------------------
    Data_L_RidgeY1P_1 = list(map (add,Data_1P_1['W-Ridge1'], Data_1P_1['W-Ridge2'] )) #Averaging Ridges' across individual micelles
    Data_L_RidgeY1P_2 = list(map (add,Data_1P_2['W-Ridge1'], Data_1P_2['W-Ridge2'] )) #FULL growth
    #Data_L_RidgeY1P_3 = list(map (add,Data_1P_3['W-Ridge1'], Data_1P_3['W-Ridge2'] ))
    #Data_L_RidgeY1P_4 = list(map (add,Data_1P_4['W-Ridge1'], Data_1P_4['W-Ridge2'] ))
    #Data_L_RidgeY1P_5 = list(map (add,Data_1P_5['W-Ridge1'], Data_1P_5['W-Ridge2'] ))
    #Data_L_RidgeY1P_6 = list(map (add,Data_1P_6['W-Ridge1'], Data_1P_6['W-Ridge2'] ))

    Data_L_RidgeY5P_1 = list(map (add,Data_5P_1['W-Ridge1'], Data_5P_1['W-Ridge2'] )) #ATM growth
    Data_L_RidgeY5P_2 = list(map (add,Data_5P_2['W-Ridge1'], Data_5P_2['W-Ridge2'] )) 
    #Data_L_RidgeY5P_3 = list(map (add,Data_5P_3['W-Ridge1'], Data_5P_3['W-Ridge2'] ))
    #Data_L_RidgeY5P_4 = list(map (add,Data_5P_4['W-Ridge1'], Data_5P_4['W-Ridge2'] ))
    #Data_L_RidgeY5P_5 = list(map (add,Data_5P_5['W-Ridge1'], Data_5P_5['W-Ridge2'] ))
    #Data_L_RidgeY5P_6 = list(map (add,Data_5P_6['W-Ridge1'], Data_5P_6['W-Ridge2'] ))
    
#---------------------------------------------------MIDDLE X------------------------------------------------------
    Data_L_MidX1P_1 = Data_1P_1['L-Middle'] #FULL growth
    Data_L_MidX1P_2 = Data_1P_2['L-Middle']
    #Data_L_MidX1P_3 = Data_1P_3['L-Middle']
    #Data_L_MidX1P_4 = Data_1P_4['L-Middle']
    #Data_L_MidX1P_5 = Data_1P_5['L-Middle']
    #Data_L_MidX1P_6 = Data_1P_6['L-Middle']

    Data_L_MidX5P_1 = Data_5P_1['L-Middle'] #ATM growth
    Data_L_MidX5P_2 = Data_5P_2['L-Middle']
    #Data_L_MidX5P_3 = Data_5P_3['L-Middle']
    #Data_L_MidX5P_4 = Data_5P_4['L-Middle']
    #Data_L_MidX5P_5 = Data_5P_5['L-Middle']
    #Data_L_MidX5P_6 = Data_5P_6['L-Middle']

#---------------------------------------------------MIDDLE Y------------------------------------------------------
    Data_L_MidY1P_1 = Data_1P_1['W-Middle'] #FULL growth
    Data_L_MidY1P_2 = Data_1P_2['W-Middle']
    #Data_L_MidY1P_3 = Data_1P_3['W-Middle']
    #Data_L_MidY1P_4 = Data_1P_4['W-Middle']
    #Data_L_MidY1P_5 = Data_1P_5['W-Middle']
    #Data_L_MidY1P_6 = Data_1P_6['W-Middle']

    Data_L_MidY5P_1 = Data_5P_1['W-Middle'] #ATM growth
    Data_L_MidY5P_2 = Data_5P_2['W-Middle']
    #Data_L_MidY5P_3 = Data_5P_3['W-Middle']
    #Data_L_MidY5P_4 = Data_5P_4['W-Middle']
    #Data_L_MidY5P_5 = Data_5P_5['W-Middle']
    #Data_L_MidY5P_6 = Data_5P_6['W-Middle']

#-----------------------------------------------------DIP X-------------------------------------------------------
    Data_L_DipX1P_1 = list(map (add,Data_1P_1['L-Dip1'], Data_1P_1['L-Dip2'] )) #Averaging Ridges' across individual micelles
    Data_L_DipX1P_2 = list(map (add,Data_1P_2['L-Dip1'], Data_1P_2['L-Dip2'] )) #FULL growth
    #Data_L_DipX1P_3 = list(map (add,Data_1P_3['L-Dip1'], Data_1P_3['L-Dip2'] ))
    #Data_L_DipX1P_4 = list(map (add,Data_1P_4['L-Dip1'], Data_1P_4['L-Dip2'] ))
    #Data_L_DipX1P_5 = list(map (add,Data_1P_5['L-Dip1'], Data_1P_5['L-Dip2'] ))
    #Data_L_DipX1P_6 = list(map (add,Data_1P_6['L-Dip1'], Data_1P_6['L-Dip2'] ))

    Data_L_DipX5P_1 = list(map (add,Data_5P_1['L-Dip1'], Data_5P_1['L-Dip2'] )) #ATM growth
    Data_L_DipX5P_2 = list(map (add,Data_5P_2['L-Dip1'], Data_5P_2['L-Dip2'] )) 
    #Data_L_DipX5P_3 = list(map (add,Data_5P_3['L-Dip1'], Data_5P_3['L-Dip2'] ))
    #Data_L_DipX5P_4 = list(map (add,Data_5P_4['L-Dip1'], Data_5P_4['L-Dip2'] ))
    #Data_L_DipX5P_5 = list(map (add,Data_5P_5['L-Dip1'], Data_5P_5['L-Dip2'] ))
    #Data_L_DipX5P_6 = list(map (add,Data_5P_6['L-Dip1'], Data_5P_6['L-Dip2'] ))
    
#-----------------------------------------------------DIP Y-------------------------------------------------------
    Data_L_DipY1P_1 = list(map (add,Data_1P_1['W-Dip1'], Data_1P_1['W-Dip2'] )) #Averaging Ridges' across individual micelles
    Data_L_DipY1P_2 = list(map (add,Data_1P_2['W-Dip1'], Data_1P_2['W-Dip2'] )) #FULL growth
    #Data_L_DipY1P_3 = list(map (add,Data_1P_3['W-Dip1'], Data_1P_3['W-Dip2'] ))
    #Data_L_DipY1P_4 = list(map (add,Data_1P_4['W-Dip1'], Data_1P_4['W-Dip2'] ))
    #Data_L_DipY1P_5 = list(map (add,Data_1P_5['W-Dip1'], Data_1P_5['W-Dip2'] ))
    #Data_L_DipY1P_6 = list(map (add,Data_1P_6['W-Dip1'], Data_1P_6['W-Dip2'] ))

    Data_L_DipY5P_1 = list(map (add,Data_5P_1['W-Dip1'], Data_5P_1['W-Dip2'] )) #ATM growth
    Data_L_DipY5P_2 = list(map (add,Data_5P_2['W-Dip1'], Data_5P_2['W-Dip2'] )) 
    #Data_L_DipY5P_3 = list(map (add,Data_5P_3['W-Dip1'], Data_5P_3['W-Dip2'] ))
    #Data_L_DipY5P_4 = list(map (add,Data_5P_4['W-Dip1'], Data_5P_4['W-Dip2'] ))
    #Data_L_DipY5P_5 = list(map (add,Data_5P_5['W-Dip1'], Data_5P_5['W-Dip2'] ))
    #Data_L_DipY5P_6 = list(map (add,Data_5P_6['W-Dip1'], Data_5P_6['W-Dip2'] ))
    
#------------------------------------------------------ZERO DATA X------------------------------------------------------
#------------------------------------------------------BARE MICELLE------------------------------------------------------
#--------------------------------- RIDGE ---------------------------------
    Av_Data_L_RidgeX1P_1 = [] 
    Zero_Data_L_RidgeX1P_1 = [] 
    Av_Data_L_RidgeX1P_2 = []
    Zero_Data_L_RidgeX1P_2 = []
    #Av_Data_L_RidgeX1P_3 = []
    #Zero_Data_L_RidgeX1P_3 = []
    #Av_Data_L_RidgeX1P_4 = []
    #Zero_Data_L_RidgeX1P_4 = []
    #Av_Data_L_RidgeX1P_5 = []
    #Zero_Data_L_RidgeX1P_5 = []
    #Av_Data_L_RidgeX1P_6 = []
    #Zero_Data_L_RidgeX1P_6 = []

    for x in Data_L_RidgeX1P_1: #~
        a = x/2
        Av_Data_L_RidgeX1P_1.append(float(a))
    for x in Av_Data_L_RidgeX1P_1:
        a = x - ((abs(Av_Data_L_RidgeX1P_1[-1])-abs(Av_Data_L_RidgeX1P_1[0]))/2)
        Zero_Data_L_RidgeX1P_1.append(float(a))
    for x in Data_L_RidgeX1P_2: #~
        a = x/2
        Av_Data_L_RidgeX1P_2.append(float(a))
    for x in Av_Data_L_RidgeX1P_2:
        a = x - ((abs(Av_Data_L_RidgeX1P_2[-1])-abs(Av_Data_L_RidgeX1P_2[0]))/2)
        Zero_Data_L_RidgeX1P_2.append(float(a))
#    for x in Data_L_RidgeX1P_3: #~
#        a = x/2
#        Av_Data_L_RidgeX1P_3.append(float(a))
#    for x in Av_Data_L_RidgeX1P_3:
#        a = x - ((abs(Av_Data_L_RidgeX1P_3[-1])-abs(Av_Data_L_RidgeX1P_3[0]))/2)
#        Zero_Data_L_RidgeX1P_3.append(float(a))
#    for x in Data_L_RidgeX1P_4: #~
#        a = x/2
#        Av_Data_L_RidgeX1P_4.append(float(a))
#    for x in Av_Data_L_RidgeX1P_4:
#        a = x - ((abs(Av_Data_L_RidgeX1P_4[-1])-abs(Av_Data_L_RidgeX1P_4[0]))/2)
#        Zero_Data_L_RidgeX1P_4.append(float(a))
#    for x in Data_L_RidgeX1P_5: #~
#        a = x/2
#        Av_Data_L_RidgeX1P_5.append(float(a))
#    for x in Av_Data_L_RidgeX1P_5:
#        a = x - ((abs(Av_Data_L_RidgeX1P_5[-1])-abs(Av_Data_L_RidgeX1P_5[0]))/2)
#        Zero_Data_L_RidgeX1P_5.append(float(a))
#    for x in Data_L_RidgeX1P_6: #~
#        a = x/2
#        Av_Data_L_RidgeX1P_6.append(float(a))
#    for x in Av_Data_L_RidgeX1P_6:
#        a = x - ((abs(Av_Data_L_RidgeX1P_6[-1])-abs(Av_Data_L_RidgeX1P_6[0]))/2)
#        Zero_Data_L_RidgeX1P_6.append(float(a)) 

#--------------------------------- MID ---------------------------------
    Av_Data_L_MidX1P_1 = [] 
    Zero_Data_L_MidX1P_1 = [] 
    Av_Data_L_MidX1P_2 = []
    Zero_Data_L_MidX1P_2 = []
#    Av_Data_L_MidX1P_3 = []
#    Zero_Data_L_MidX1P_3 = []
#    Av_Data_L_MidX1P_4 = []
#    Zero_Data_L_MidX1P_4 = []
#    Av_Data_L_MidX1P_5 = []
#    Zero_Data_L_MidX1P_5 = []
#    Av_Data_L_MidX1P_6 = []
#    Zero_Data_L_MidX1P_6 = []

    for x in Data_L_MidX1P_1: #~
        a = x/2
        Av_Data_L_MidX1P_1.append(float(a))
    for x in Av_Data_L_MidX1P_1:
        a = x - ((abs(Av_Data_L_MidX1P_1[-1])-abs(Av_Data_L_MidX1P_1[0]))/2)
        Zero_Data_L_MidX1P_1.append(float(a))
    for x in Data_L_MidX1P_2: #~
        a = x/2
        Av_Data_L_MidX1P_2.append(float(a))
    for x in Av_Data_L_MidX1P_2:
        a = x - ((abs(Av_Data_L_MidX1P_2[-1])-abs(Av_Data_L_MidX1P_2[0]))/2)
        Zero_Data_L_MidX1P_2.append(float(a))
#    for x in Data_L_MidX1P_3: #~
#        a = x/2
#        Av_Data_L_MidX1P_3.append(float(a))
#    for x in Av_Data_L_MidX1P_3:
#        a = x - ((abs(Av_Data_L_MidX1P_3[-1])-abs(Av_Data_L_MidX1P_3[0]))/2)
#        Zero_Data_L_MidX1P_3.append(float(a))#
#    for x in Data_L_MidX1P_4: #~
#        a = x/2
#        Av_Data_L_MidX1P_4.append(float(a))
#    for x in Av_Data_L_MidX1P_4:
#        a = x - ((abs(Av_Data_L_MidX1P_4[-1])-abs(Av_Data_L_MidX1P_4[0]))/2)
#        Zero_Data_L_MidX1P_4.append(float(a))
#    for x in Data_L_MidX1P_5: #~
#        a = x/2
#        Av_Data_L_MidX1P_5.append(float(a))
#    for x in Av_Data_L_MidX1P_5:
#        a = x - ((abs(Av_Data_L_MidX1P_5[-1])-abs(Av_Data_L_MidX1P_5[0]))/2)
#        Zero_Data_L_MidX1P_5.append(float(a))
#    for x in Data_L_MidX1P_6: #~
#        a = x/2
#        Av_Data_L_MidX1P_6.append(float(a))
#    for x in Av_Data_L_MidX1P_6:
#        a = x - ((abs(Av_Data_L_MidX1P_6[-1])-abs(Av_Data_L_MidX1P_6[0]))/2)
#        Zero_Data_L_MidX1P_6.append(float(a)) 
        
#--------------------------------- DIP ---------------------------------
    Av_Data_L_DipX1P_1 = [] 
    Zero_Data_L_DipX1P_1 = [] 
    Av_Data_L_DipX1P_2 = []
    Zero_Data_L_DipX1P_2 = []
#    Av_Data_L_DipX1P_3 = []
#    Zero_Data_L_DipX1P_3 = []
#    Av_Data_L_DipX1P_4 = []
#    Zero_Data_L_DipX1P_4 = []
#    Av_Data_L_DipX1P_5 = []
#    Zero_Data_L_DipX1P_5 = []
#    Av_Data_L_DipX1P_6 = []
#    Zero_Data_L_DipX1P_6 = []

    for x in Data_L_DipX1P_1: #~
        a = x/2
        Av_Data_L_DipX1P_1.append(float(a))
    for x in Av_Data_L_DipX1P_1:
        a = x - ((abs(Av_Data_L_DipX1P_1[-1])-abs(Av_Data_L_DipX1P_1[0]))/2)
        Zero_Data_L_DipX1P_1.append(float(a))
    for x in Data_L_DipX1P_2: #~
        a = x/2
        Av_Data_L_DipX1P_2.append(float(a))
    for x in Av_Data_L_DipX1P_2:
        a = x - ((abs(Av_Data_L_DipX1P_2[-1])-abs(Av_Data_L_DipX1P_2[0]))/2)
        Zero_Data_L_DipX1P_2.append(float(a))
#    for x in Data_L_DipX1P_3: #~
#        a = x/2
#        Av_Data_L_DipX1P_3.append(float(a))
#    for x in Av_Data_L_DipX1P_3:
#        a = x - ((abs(Av_Data_L_DipX1P_3[-1])-abs(Av_Data_L_DipX1P_3[0]))/2)
#        Zero_Data_L_DipX1P_3.append(float(a))
#    for x in Data_L_DipX1P_4: #~
#        a = x/2
#        Av_Data_L_DipX1P_4.append(float(a))
#    for x in Av_Data_L_DipX1P_4:
#        a = x - ((abs(Av_Data_L_DipX1P_4[-1])-abs(Av_Data_L_DipX1P_4[0]))/2)
#        Zero_Data_L_DipX1P_4.append(float(a))
#    for x in Data_L_DipX1P_5: #~
#        a = x/2
#        Av_Data_L_DipX1P_5.append(float(a))
#    for x in Av_Data_L_DipX1P_5:
#        a = x - ((abs(Av_Data_L_DipX1P_5[-1])-abs(Av_Data_L_DipX1P_5[0]))/2)
#        Zero_Data_L_DipX1P_5.append(float(a))
#    for x in Data_L_DipX1P_6: #~
#        a = x/2
#        Av_Data_L_DipX1P_6.append(float(a))
#    for x in Av_Data_L_DipX1P_6:
#        a = x - ((abs(Av_Data_L_DipX1P_6[-1])-abs(Av_Data_L_DipX1P_6[0]))/2)
#        Zero_Data_L_DipX1P_6.append(float(a)) 
        
#------------------------------------------------------CONVERTED------------------------------------------------------
#--------------------------------- RIDGE ---------------------------------
    Av_Data_L_RidgeX5P_1 = [] 
    Zero_Data_L_RidgeX5P_1 = [] 
    Av_Data_L_RidgeX5P_2 = []
    Zero_Data_L_RidgeX5P_2 = []
#    Av_Data_L_RidgeX5P_3 = []
#    Zero_Data_L_RidgeX5P_3 = []
#    Av_Data_L_RidgeX5P_4 = []
#    Zero_Data_L_RidgeX5P_4 = []
#    Av_Data_L_RidgeX5P_5 = []
#    Zero_Data_L_RidgeX5P_5 = []
#    Av_Data_L_RidgeX5P_6 = []
#    Zero_Data_L_RidgeX5P_6 = []

    for x in Data_L_RidgeX5P_1: #~
        a = x/2
        Av_Data_L_RidgeX5P_1.append(float(a))
    for x in Av_Data_L_RidgeX5P_1:
        a = x - ((abs(Av_Data_L_RidgeX5P_1[-1])-abs(Av_Data_L_RidgeX5P_1[0]))/2)
        Zero_Data_L_RidgeX5P_1.append(float(a))
    for x in Data_L_RidgeX5P_2: #~
        a = x/2
        Av_Data_L_RidgeX5P_2.append(float(a))
    for x in Av_Data_L_RidgeX5P_2:
        a = x - ((abs(Av_Data_L_RidgeX5P_2[-1])-abs(Av_Data_L_RidgeX5P_2[0]))/2)
        Zero_Data_L_RidgeX5P_2.append(float(a))
#    for x in Data_L_RidgeX5P_3: #~
#        a = x/2
#        Av_Data_L_RidgeX5P_3.append(float(a))
#    for x in Av_Data_L_RidgeX5P_3:
#        a = x - ((abs(Av_Data_L_RidgeX5P_3[-1])-abs(Av_Data_L_RidgeX5P_3[0]))/2)
#        Zero_Data_L_RidgeX5P_3.append(float(a))
#    for x in Data_L_RidgeX5P_4: #~
#        a = x/2
#        Av_Data_L_RidgeX5P_4.append(float(a))
#    for x in Av_Data_L_RidgeX5P_4:
#        a = x - ((abs(Av_Data_L_RidgeX5P_4[-1])-abs(Av_Data_L_RidgeX5P_4[0]))/2)
#        Zero_Data_L_RidgeX5P_4.append(float(a))
#    for x in Data_L_RidgeX5P_5: #~
#        a = x/2
#        Av_Data_L_RidgeX5P_5.append(float(a))
#    for x in Av_Data_L_RidgeX5P_5:
#        a = x - ((abs(Av_Data_L_RidgeX5P_5[-1])-abs(Av_Data_L_RidgeX5P_5[0]))/2)
#        Zero_Data_L_RidgeX5P_5.append(float(a))
#    for x in Data_L_RidgeX5P_6: #~
#        a = x/2
#        Av_Data_L_RidgeX5P_6.append(float(a))
##    for x in Av_Data_L_RidgeX5P_6:
#        a = x - ((abs(Av_Data_L_RidgeX5P_6[-1])-abs(Av_Data_L_RidgeX5P_6[0]))/2)
#        Zero_Data_L_RidgeX5P_6.append(float(a)) 

#--------------------------------- MID ---------------------------------
    Av_Data_L_MidX5P_1 = [] 
    Zero_Data_L_MidX5P_1 = [] 
    Av_Data_L_MidX5P_2 = []
    Zero_Data_L_MidX5P_2 = []
#    Av_Data_L_MidX5P_3 = []
#    Zero_Data_L_MidX5P_3 = []
#    Av_Data_L_MidX5P_4 = []
#    Zero_Data_L_MidX5P_4 = []
#    Av_Data_L_MidX5P_5 = []
#    Zero_Data_L_MidX5P_5 = []
#    Av_Data_L_MidX5P_6 = []
#    Zero_Data_L_MidX5P_6 = []

    for x in Data_L_MidX5P_1: #~
        a = x/2
        Av_Data_L_MidX5P_1.append(float(a))
    for x in Av_Data_L_MidX5P_1:
        a = x - ((abs(Av_Data_L_MidX5P_1[-1])-abs(Av_Data_L_MidX5P_1[0]))/2)
        Zero_Data_L_MidX5P_1.append(float(a))
    for x in Data_L_MidX5P_2: #~
        a = x/2
        Av_Data_L_MidX5P_2.append(float(a))
    for x in Av_Data_L_MidX5P_2:
        a = x - ((abs(Av_Data_L_MidX5P_2[-1])-abs(Av_Data_L_MidX5P_2[0]))/2)
        Zero_Data_L_MidX5P_2.append(float(a))
#    for x in Data_L_MidX5P_3: #~
#        a = x/2
#        Av_Data_L_MidX5P_3.append(float(a))
#    for x in Av_Data_L_MidX5P_3:
#        a = x - ((abs(Av_Data_L_MidX5P_3[-1])-abs(Av_Data_L_MidX5P_3[0]))/2)
#        Zero_Data_L_MidX5P_3.append(float(a))
#    for x in Data_L_MidX5P_4: #~
#        a = x/2
#        Av_Data_L_MidX5P_4.append(float(a))
#    for x in Av_Data_L_MidX5P_4:
#        a = x - ((abs(Av_Data_L_MidX5P_4[-1])-abs(Av_Data_L_MidX5P_4[0]))/2)
#        Zero_Data_L_MidX5P_4.append(float(a))
#    for x in Data_L_MidX5P_5: #~
#        a = x/2
#        Av_Data_L_MidX5P_5.append(float(a))
#    for x in Av_Data_L_MidX5P_5:
#        a = x - ((abs(Av_Data_L_MidX5P_5[-1])-abs(Av_Data_L_MidX5P_5[0]))/2)
#        Zero_Data_L_MidX5P_5.append(float(a))
#    for x in Data_L_MidX5P_6: #~
#        a = x/2
#        Av_Data_L_MidX5P_6.append(float(a))
#    for x in Av_Data_L_MidX5P_6:
#        a = x - ((abs(Av_Data_L_MidX5P_6[-1])-abs(Av_Data_L_MidX5P_6[0]))/2)
#        Zero_Data_L_MidX5P_6.append(float(a)) 
        
#--------------------------------- DIP ---------------------------------
    Av_Data_L_DipX5P_1 = [] 
    Zero_Data_L_DipX5P_1 = [] 
    Av_Data_L_DipX5P_2 = []
    Zero_Data_L_DipX5P_2 = []
#    Av_Data_L_DipX5P_3 = []
#    Zero_Data_L_DipX5P_3 = []
#    Av_Data_L_DipX5P_4 = []
#    Zero_Data_L_DipX5P_4 = []
#    Av_Data_L_DipX5P_5 = []
#    Zero_Data_L_DipX5P_5 = []
#    Av_Data_L_DipX5P_6 = []
#    Zero_Data_L_DipX5P_6 = []

    for x in Data_L_DipX5P_1: #~
        a = x/2
        Av_Data_L_DipX5P_1.append(float(a))
    for x in Av_Data_L_DipX5P_1:
        a = x - ((abs(Av_Data_L_DipX5P_1[-1])-abs(Av_Data_L_DipX5P_1[0]))/2)
        Zero_Data_L_DipX5P_1.append(float(a))
    for x in Data_L_DipX5P_2: #~
        a = x/2
        Av_Data_L_DipX5P_2.append(float(a))
    for x in Av_Data_L_DipX5P_2:
        a = x - ((abs(Av_Data_L_DipX5P_2[-1])-abs(Av_Data_L_DipX5P_2[0]))/2)
        Zero_Data_L_DipX5P_2.append(float(a))
#    for x in Data_L_DipX5P_3: #~
#        a = x/2
#        Av_Data_L_DipX5P_3.append(float(a))
#    for x in Av_Data_L_DipX5P_3:
#        a = x - ((abs(Av_Data_L_DipX5P_3[-1])-abs(Av_Data_L_DipX5P_3[0]))/2)
#        Zero_Data_L_DipX5P_3.append(float(a))
#    for x in Data_L_DipX5P_4: #~
#        a = x/2
#        Av_Data_L_DipX5P_4.append(float(a))
#    for x in Av_Data_L_DipX5P_4:
#        a = x - ((abs(Av_Data_L_DipX5P_4[-1])-abs(Av_Data_L_DipX5P_4[0]))/2)
#        Zero_Data_L_DipX5P_4.append(float(a))
#    for x in Data_L_DipX5P_5: #~
#        a = x/2
#        Av_Data_L_DipX5P_5.append(float(a))
#    for x in Av_Data_L_DipX5P_5:
#        a = x - ((abs(Av_Data_L_DipX5P_5[-1])-abs(Av_Data_L_DipX5P_5[0]))/2)
#        Zero_Data_L_DipX5P_5.append(float(a))
#    for x in Data_L_DipX5P_6: #~
#        a = x/2
#        Av_Data_L_DipX5P_6.append(float(a))
#    for x in Av_Data_L_DipX5P_6:
#        a = x - ((abs(Av_Data_L_DipX5P_6[-1])-abs(Av_Data_L_DipX5P_6[0]))/2)
#        Zero_Data_L_DipX5P_6.append(float(a)) 
        
#------------------------------------------------------ZERO DATA Y------------------------------------------------------
#------------------------------------------------------BARE MICELLE------------------------------------------------------
#--------------------------------- RIDGE ---------------------------------
    Av_Data_L_RidgeY1P_1 = [] 
    Zero_Data_L_RidgeY1P_1 = [] 
    Av_Data_L_RidgeY1P_2 = []
    Zero_Data_L_RidgeY1P_2 = []
#    Av_Data_L_RidgeY1P_3 = []
#    Zero_Data_L_RidgeY1P_3 = []
#    Av_Data_L_RidgeY1P_4 = []
#    Zero_Data_L_RidgeY1P_4 = []
#    Av_Data_L_RidgeY1P_5 = []
#    Zero_Data_L_RidgeY1P_5 = []
#    Av_Data_L_RidgeY1P_6 = []
#    Zero_Data_L_RidgeY1P_6 = []

    
    for x in Data_L_RidgeY1P_1: #~
        a = x/2
        Av_Data_L_RidgeY1P_1.append(float(a))
    Av_W_Ridge1P_1_NOT_NAN = [item for item in Av_Data_L_RidgeY1P_1 if not(math.isnan(item)) == True]  
    for x in Av_W_Ridge1P_1_NOT_NAN:
        a = x - ((abs(Av_W_Ridge1P_1_NOT_NAN[-1])-abs(Av_W_Ridge1P_1_NOT_NAN[0]))/2)
        Zero_Data_L_RidgeY1P_1.append(float(a))
    
    for x in Data_L_RidgeY1P_2: #~
        a = x/2
        Av_Data_L_RidgeY1P_2.append(float(a))
    Av_W_Ridge1P_2_NOT_NAN = [item for item in Av_Data_L_RidgeY1P_2 if not(math.isnan(item)) == True]  
    for x in Av_W_Ridge1P_2_NOT_NAN:
        a = x - ((abs(Av_W_Ridge1P_2_NOT_NAN[-1])-abs(Av_W_Ridge1P_2_NOT_NAN[0]))/2)
        Zero_Data_L_RidgeY1P_2.append(float(a))

    
#    for x in Data_L_RidgeY1P_3: #~
#        a = x/2
#        Av_Data_L_RidgeY1P_3.append(float(a))
#    Av_W_Ridge1P_3_NOT_NAN = [item for item in Av_Data_L_RidgeY1P_3 if not(math.isnan(item)) == True]  
#    for x in Av_W_Ridge1P_3_NOT_NAN:
#        a = x - ((abs(Av_W_Ridge1P_3_NOT_NAN[-1])-abs(Av_W_Ridge1P_3_NOT_NAN[0]))/2)
#        Zero_Data_L_RidgeY1P_3.append(float(a))

    
#    for x in Data_L_RidgeY1P_4: #~
#        a = x/2
#        Av_Data_L_RidgeY1P_4.append(float(a))
#    Av_W_Ridge1P_4_NOT_NAN = [item for item in Av_Data_L_RidgeY1P_4 if not(math.isnan(item)) == True]  
#    for x in Av_W_Ridge1P_4_NOT_NAN:
#        a = x - ((abs(Av_W_Ridge1P_4_NOT_NAN[-1])-abs(Av_W_Ridge1P_4_NOT_NAN[0]))/2)
#        Zero_Data_L_RidgeY1P_4.append(float(a))

    
#    for x in Data_L_RidgeY1P_5: #~
#        a = x/2
#        Av_Data_L_RidgeY1P_5.append(float(a))
#    Av_W_Ridge1P_5_NOT_NAN = [item for item in Av_Data_L_RidgeY1P_5 if not(math.isnan(item)) == True]  
#    for x in Av_W_Ridge1P_5_NOT_NAN:
#        a = x - ((abs(Av_W_Ridge1P_5_NOT_NAN[-1])-abs(Av_W_Ridge1P_5_NOT_NAN[0]))/2)
#        Zero_Data_L_RidgeY1P_5.append(float(a))
    
    
#    for x in Data_L_RidgeY1P_6: #~
#        a = x/2
#        Av_Data_L_RidgeY1P_6.append(float(a))
#    Av_W_Ridge1P_6_NOT_NAN = [item for item in Av_Data_L_RidgeY1P_6 if not(math.isnan(item)) == True]  
#    for x in Av_W_Ridge1P_6_NOT_NAN:
#        a = x - ((abs(Av_W_Ridge1P_6_NOT_NAN[-1])-abs(Av_W_Ridge1P_6_NOT_NAN[0]))/2)
#        Zero_Data_L_RidgeY1P_6.append(float(a)) 

#W_Ridge1P_1_NOT_NAN = [item for item in Zero_Data_L_RidgeY1P_1 if not(math.isnan(item)) == True] #Removing "nan" from W data.
#--------------------------------- MID ---------------------------------
    Av_Data_L_MidY1P_1 = [] 
    Zero_Data_L_MidY1P_1 = [] 
    Av_Data_L_MidY1P_2 = []
    Zero_Data_L_MidY1P_2 = []
#    Av_Data_L_MidY1P_3 = []
#    Zero_Data_L_MidY1P_3 = []
#    Av_Data_L_MidY1P_4 = []
#    Zero_Data_L_MidY1P_4 = []
#    Av_Data_L_MidY1P_5 = []
#    Zero_Data_L_MidY1P_5 = []
#    Av_Data_L_MidY1P_6 = []
#    Zero_Data_L_MidY1P_6 = []

    for x in Data_L_MidY1P_1: #~
        a = x/2
        Av_Data_L_MidY1P_1.append(float(a))
    Av_W_Mid1P_1_NOT_NAN = [item for item in Av_Data_L_MidY1P_1 if not(math.isnan(item)) == True]  
    for x in Av_W_Mid1P_1_NOT_NAN:
        a = x - ((abs(Av_W_Mid1P_1_NOT_NAN[-1])-abs(Av_W_Mid1P_1_NOT_NAN[0]))/2)
        Zero_Data_L_MidY1P_1.append(float(a))
        
    for x in Data_L_MidY1P_2: #~
        a = x/2
        Av_Data_L_MidY1P_2.append(float(a))
    Av_W_Mid1P_2_NOT_NAN = [item for item in Av_Data_L_MidY1P_2 if not(math.isnan(item)) == True]  
    for x in Av_W_Mid1P_2_NOT_NAN:
        a = x - ((abs(Av_W_Mid1P_2_NOT_NAN[-1])-abs(Av_W_Mid1P_2_NOT_NAN[0]))/2)
        Zero_Data_L_MidY1P_2.append(float(a))
        
#    for x in Data_L_MidY1P_3: #~
#        a = x/2
#        Av_Data_L_MidY1P_3.append(float(a))
#    Av_W_Mid1P_3_NOT_NAN = [item for item in Av_Data_L_MidY1P_3 if not(math.isnan(item)) == True]  
#    for x in Av_W_Mid1P_3_NOT_NAN:
#        a = x - ((abs(Av_W_Mid1P_3_NOT_NAN[-1])-abs(Av_W_Mid1P_3_NOT_NAN[0]))/2)
#        Zero_Data_L_MidY1P_3.append(float(a))
#    
#    for x in Data_L_MidY1P_4: #~
##        a = x/2
 #       Av_Data_L_MidY1P_4.append(float(a))
 #   Av_W_Mid1P_4_NOT_NAN = [item for item in Av_Data_L_MidY1P_4 if not(math.isnan(item)) == True]  
 #   for x in Av_W_Mid1P_4_NOT_NAN:
 #       a = x - ((abs(Av_W_Mid1P_4_NOT_NAN[-1])-abs(Av_W_Mid1P_4_NOT_NAN[0]))/2)
 #       Zero_Data_L_MidY1P_4.append(float(a))
        
#    for x in Data_L_MidY1P_5: #~
#        a = x/2
#        Av_Data_L_MidY1P_5.append(float(a))
#    Av_W_Mid1P_5_NOT_NAN = [item for item in Av_Data_L_MidY1P_5 if not(math.isnan(item)) == True]  
#    for x in Av_W_Mid1P_5_NOT_NAN:
#        a = x - ((abs(Av_W_Mid1P_5_NOT_NAN[-1])-abs(Av_W_Mid1P_5_NOT_NAN[0]))/2)
#        Zero_Data_L_MidY1P_5.append(float(a))
    
#    for x in Data_L_MidY1P_6: #~
#        a = x/2
#        Av_Data_L_MidY1P_6.append(float(a))
#    Av_W_Mid1P_6_NOT_NAN = [item for item in Av_Data_L_MidY1P_6 if not(math.isnan(item)) == True]  
#    for x in Av_W_Mid1P_6_NOT_NAN:
#        a = x - ((abs(Av_W_Mid1P_6_NOT_NAN[-1])-abs(Av_W_Mid1P_6_NOT_NAN[0]))/2)
#        Zero_Data_L_MidY1P_6.append(float(a)) 
        
#--------------------------------- DIP ---------------------------------
    Av_Data_L_DipY1P_1 = [] 
    Zero_Data_L_DipY1P_1 = [] 
    Av_Data_L_DipY1P_2 = []
    Zero_Data_L_DipY1P_2 = []
#    Av_Data_L_DipY1P_3 = []
#    Zero_Data_L_DipY1P_3 = []
#    Av_Data_L_DipY1P_4 = []
#    Zero_Data_L_DipY1P_4 = []
 #   Av_Data_L_DipY1P_5 = []
#    Zero_Data_L_DipY1P_5 = []
#    Av_Data_L_DipY1P_6 = []
#    Zero_Data_L_DipY1P_6 = []

    for x in Data_L_DipY1P_1: #~
        a = x/2
        Av_Data_L_DipY1P_1.append(float(a))
    Av_W_Dip1P_1_NOT_NAN = [item for item in Av_Data_L_DipY1P_1 if not(math.isnan(item)) == True]  
    for x in Av_W_Dip1P_1_NOT_NAN:
        a = x - ((abs(Av_W_Dip1P_1_NOT_NAN[-1])-abs(Av_W_Dip1P_1_NOT_NAN[0]))/2)
        Zero_Data_L_DipY1P_1.append(float(a))
        
    for x in Data_L_DipY1P_2: #~
        a = x/2
        Av_Data_L_DipY1P_2.append(float(a))
    Av_W_Dip1P_2_NOT_NAN = [item for item in Av_Data_L_DipY1P_2 if not(math.isnan(item)) == True]  
    for x in Av_W_Dip1P_2_NOT_NAN:
        a = x - ((abs(Av_W_Dip1P_2_NOT_NAN[-1])-abs(Av_W_Dip1P_2_NOT_NAN[0]))/2)
        Zero_Data_L_DipY1P_2.append(float(a))
        
#    for x in Data_L_DipY1P_3: #~
#        a = x/2
#        Av_Data_L_DipY1P_3.append(float(a))
#    Av_W_Dip1P_3_NOT_NAN = [item for item in Av_Data_L_DipY1P_3 if not(math.isnan(item)) == True]  
#    for x in Av_W_Dip1P_3_NOT_NAN:
#        a = x - ((abs(Av_W_Dip1P_3_NOT_NAN[-1])-abs(Av_W_Dip1P_3_NOT_NAN[0]))/2)
#        Zero_Data_L_DipY1P_3.append(float(a))
#    
#    for x in Data_L_DipY1P_4: #~
#        a = x/2
#        Av_Data_L_DipY1P_4.append(float(a))
#    Av_W_Dip1P_4_NOT_NAN = [item for item in Av_Data_L_DipY1P_4 if not(math.isnan(item)) == True]  
#    for x in Av_W_Dip1P_4_NOT_NAN:
#        a = x - ((abs(Av_W_Dip1P_4_NOT_NAN[-1])-abs(Av_W_Dip1P_4_NOT_NAN[0]))/2)
#        Zero_Data_L_DipY1P_4.append(float(a))
        
#    for x in Data_L_DipY1P_5: #~
#        a = x/2
#        Av_Data_L_DipY1P_5.append(float(a))
#    Av_W_Dip1P_5_NOT_NAN = [item for item in Av_Data_L_DipY1P_5 if not(math.isnan(item)) == True]  
#    for x in Av_W_Dip1P_5_NOT_NAN:
#        a = x - ((abs(Av_W_Dip1P_5_NOT_NAN[-1])-abs(Av_W_Dip1P_5_NOT_NAN[0]))/2)
#        Zero_Data_L_DipY1P_5.append(float(a))
    
#    for x in Data_L_DipY1P_6: #~
#        a = x/2
#        Av_Data_L_DipY1P_6.append(float(a))
#    Av_W_Dip1P_6_NOT_NAN = [item for item in Av_Data_L_DipY1P_6 if not(math.isnan(item)) == True]  
#    for x in Av_W_Dip1P_6_NOT_NAN:
#        a = x - ((abs(Av_W_Dip1P_6_NOT_NAN[-1])-abs(Av_W_Dip1P_6_NOT_NAN[0]))/2)
#        Zero_Data_L_DipY1P_6.append(float(a)) 
        
#------------------------------------------------------ATM cooling------------------------------------------------------
#--------------------------------- RIDGE ---------------------------------
    Av_Data_L_RidgeY5P_1 = [] 
    Zero_Data_L_RidgeY5P_1 = [] 
    Av_Data_L_RidgeY5P_2 = []
    Zero_Data_L_RidgeY5P_2 = []
#    Av_Data_L_RidgeY5P_3 = []
#    Zero_Data_L_RidgeY5P_3 = []
#    Av_Data_L_RidgeY5P_4 = []
#    Zero_Data_L_RidgeY5P_4 = []
#    Av_Data_L_RidgeY5P_5 = []
#    Zero_Data_L_RidgeY5P_5 = []
#    Av_Data_L_RidgeY5P_6 = []
#    Zero_Data_L_RidgeY5P_6 = []

    for x in Data_L_RidgeY5P_1: #~
        a = x/2
        Av_Data_L_RidgeY5P_1.append(float(a))
    Av_W_Ridge5P_1_NOT_NAN = [item for item in Av_Data_L_RidgeY5P_1 if not(math.isnan(item)) == True]
    for x in Av_W_Ridge5P_1_NOT_NAN:
        a = x - ((abs(Av_W_Ridge5P_1_NOT_NAN[-1])-abs(Av_W_Ridge5P_1_NOT_NAN[0]))/2)
        Zero_Data_L_RidgeY5P_1.append(float(a))

    for x in Data_L_RidgeY5P_2: #~
        a = x/2
        Av_Data_L_RidgeY5P_2.append(float(a))
    Av_W_Ridge5P_2_NOT_NAN = [item for item in Av_Data_L_RidgeY5P_2 if not(math.isnan(item)) == True]
    for x in Av_W_Ridge5P_2_NOT_NAN:
        a = x - ((abs(Av_W_Ridge5P_2_NOT_NAN[-1])-abs(Av_W_Ridge5P_2_NOT_NAN[0]))/2)
        Zero_Data_L_RidgeY5P_2.append(float(a))

#    for x in Data_L_RidgeY5P_3: #~
#        a = x/2
#        Av_Data_L_RidgeY5P_3.append(float(a))
#    Av_W_Ridge5P_3_NOT_NAN = [item for item in Av_Data_L_RidgeY5P_3 if not(math.isnan(item)) == True]
#    for x in Av_W_Ridge5P_3_NOT_NAN:
#        a = x - ((abs(Av_W_Ridge5P_3_NOT_NAN[-1])-abs(Av_W_Ridge5P_3_NOT_NAN[0]))/2)
#        Zero_Data_L_RidgeY5P_3.append(float(a))
#
#    for x in Data_L_RidgeY5P_4: #~
#        a = x/2
#        Av_Data_L_RidgeY5P_4.append(float(a))
#    Av_W_Ridge5P_4_NOT_NAN = [item for item in Av_Data_L_RidgeY5P_4 if not(math.isnan(item)) == True]
#    for x in Av_W_Ridge5P_4_NOT_NAN:
#        a = x - ((abs(Av_W_Ridge5P_4_NOT_NAN[-1])-abs(Av_W_Ridge5P_4_NOT_NAN[0]))/2)
#        Zero_Data_L_RidgeY5P_4.append(float(a))

#    for x in Data_L_RidgeY5P_5: #~
#        a = x/2
#        Av_Data_L_RidgeY5P_5.append(float(a))
#    Av_W_Ridge5P_5_NOT_NAN = [item for item in Av_Data_L_RidgeY5P_5 if not(math.isnan(item)) == True]
#    for x in Av_W_Ridge5P_5_NOT_NAN:
#        a = x - ((abs(Av_W_Ridge5P_5_NOT_NAN[-1])-abs(Av_W_Ridge5P_5_NOT_NAN[0]))/2)
#        Zero_Data_L_RidgeY5P_5.append(float(a))

#    for x in Data_L_RidgeY5P_6: #~
#        a = x/2
#        Av_Data_L_RidgeY5P_6.append(float(a))
#    Av_W_Ridge5P_6_NOT_NAN = [item for item in Av_Data_L_RidgeY5P_6 if not(math.isnan(item)) == True]
#    for x in Av_W_Ridge5P_6_NOT_NAN:
#        a = x - ((abs(Av_W_Ridge5P_6_NOT_NAN[-1])-abs(Av_W_Ridge5P_6_NOT_NAN[0]))/2)
#        Zero_Data_L_RidgeY5P_6.append(float(a)) 

#--------------------------------- MID ---------------------------------
    Av_Data_L_MidY5P_1 = [] 
    Zero_Data_L_MidY5P_1 = [] 
    Av_Data_L_MidY5P_2 = []
    Zero_Data_L_MidY5P_2 = []
#    Av_Data_L_MidY5P_3 = []
#    Zero_Data_L_MidY5P_3 = []
#    Av_Data_L_MidY5P_4 = []
#    Zero_Data_L_MidY5P_4 = []
#    Av_Data_L_MidY5P_5 = []
#    Zero_Data_L_MidY5P_5 = []
#    Av_Data_L_MidY5P_6 = []
#    Zero_Data_L_MidY5P_6 = []

    for x in Data_L_MidY5P_1: #~
        a = x/2
        Av_Data_L_MidY5P_1.append(float(a))
    Av_W_Mid5P_1_NOT_NAN = [item for item in Av_Data_L_MidY5P_1 if not(math.isnan(item)) == True]  
    for x in Av_W_Mid5P_1_NOT_NAN:
        a = x - ((abs(Av_W_Mid5P_1_NOT_NAN[-1])-abs(Av_W_Mid5P_1_NOT_NAN[0]))/2)
        Zero_Data_L_MidY5P_1.append(float(a))

    for x in Data_L_MidY5P_2: #~
        a = x/2
        Av_Data_L_MidY5P_2.append(float(a))
    Av_W_Mid5P_2_NOT_NAN = [item for item in Av_Data_L_MidY5P_2 if not(math.isnan(item)) == True]  
    for x in Av_W_Mid5P_2_NOT_NAN:
        a = x - ((abs(Av_W_Mid5P_2_NOT_NAN[-1])-abs(Av_W_Mid5P_2_NOT_NAN[0]))/2)
        Zero_Data_L_MidY5P_2.append(float(a))

#    for x in Data_L_MidY5P_3: #~
#        a = x/2
#        Av_Data_L_MidY5P_3.append(float(a))
#    Av_W_Mid5P_3_NOT_NAN = [item for item in Av_Data_L_MidY5P_3 if not(math.isnan(item)) == True]  
#    for x in Av_W_Mid5P_3_NOT_NAN:
#        a = x - ((abs(Av_W_Mid5P_3_NOT_NAN[-1])-abs(Av_W_Mid5P_3_NOT_NAN[0]))/2)
#        Zero_Data_L_MidY5P_3.append(float(a))
#
#    for x in Data_L_MidY5P_4: #~
#        a = x/2
#        Av_Data_L_MidY5P_4.append(float(a))
#    Av_W_Mid5P_4_NOT_NAN = [item for item in Av_Data_L_MidY5P_4 if not(math.isnan(item)) == True]  
#    for x in Av_W_Mid5P_4_NOT_NAN:
#        a = x - ((abs(Av_W_Mid5P_4_NOT_NAN[-1])-abs(Av_W_Mid5P_4_NOT_NAN[0]))/2)
#        Zero_Data_L_MidY5P_4.append(float(a))

#    for x in Data_L_MidY5P_5: #~
#        a = x/2
#        Av_Data_L_MidY5P_5.append(float(a))
#    Av_W_Mid5P_5_NOT_NAN = [item for item in Av_Data_L_MidY5P_5 if not(math.isnan(item)) == True]  
#    for x in Av_W_Mid5P_5_NOT_NAN:
#        a = x - ((abs(Av_W_Mid5P_5_NOT_NAN[-1])-abs(Av_W_Mid5P_5_NOT_NAN[0]))/2)
#        Zero_Data_L_MidY5P_5.append(float(a))
#
#    for x in Data_L_MidY5P_6: #~
#        a = x/2
#        Av_Data_L_MidY5P_6.append(float(a))
#    Av_W_Mid5P_6_NOT_NAN = [item for item in Av_Data_L_MidY5P_6 if not(math.isnan(item)) == True]  
#    for x in Av_W_Mid5P_6_NOT_NAN:
#        a = x - ((abs(Av_W_Mid5P_6_NOT_NAN[-1])-abs(Av_W_Mid5P_6_NOT_NAN[0]))/2)
#        Zero_Data_L_MidY5P_6.append(float(a)) 
    
#--------------------------------- DIP ---------------------------------
    Av_Data_L_DipY5P_1 = [] 
    Zero_Data_L_DipY5P_1 = [] 
    Av_Data_L_DipY5P_2 = []
    Zero_Data_L_DipY5P_2 = []
#    Av_Data_L_DipY5P_3 = []
#    Zero_Data_L_DipY5P_3 = []
#    Av_Data_L_DipY5P_4 = []
#    Zero_Data_L_DipY5P_4 = []
#    Av_Data_L_DipY5P_5 = []
#    Zero_Data_L_DipY5P_5 = []
#    Av_Data_L_DipY5P_6 = []
#    Zero_Data_L_DipY5P_6 = []

    for x in Data_L_DipY5P_1: #~
        a = x/2
        Av_Data_L_DipY5P_1.append(float(a))
    Av_W_Dip5P_1_NOT_NAN = [item for item in Av_Data_L_DipY5P_1 if not(math.isnan(item)) == True]  
    for x in Av_W_Dip5P_1_NOT_NAN:
        a = x - ((abs(Av_W_Dip5P_1_NOT_NAN[-1])-abs(Av_W_Dip5P_1_NOT_NAN[0]))/2)
        Zero_Data_L_DipY5P_1.append(float(a))

    for x in Data_L_DipY5P_2: #~
        a = x/2
        Av_Data_L_DipY5P_2.append(float(a))
    Av_W_Dip5P_2_NOT_NAN = [item for item in Av_Data_L_DipY5P_2 if not(math.isnan(item)) == True]  
    for x in Av_W_Dip5P_2_NOT_NAN:
        a = x - ((abs(Av_W_Dip5P_2_NOT_NAN[-1])-abs(Av_W_Dip5P_2_NOT_NAN[0]))/2)
        Zero_Data_L_DipY5P_2.append(float(a))

#    for x in Data_L_DipY5P_3: #~
#        a = x/2
#        Av_Data_L_DipY5P_3.append(float(a))
#    Av_W_Dip5P_3_NOT_NAN = [item for item in Av_Data_L_DipY5P_3 if not(math.isnan(item)) == True]  
#    for x in Av_W_Dip5P_3_NOT_NAN:
#        a = x - ((abs(Av_W_Dip5P_3_NOT_NAN[-1])-abs(Av_W_Dip5P_3_NOT_NAN[0]))/2)
#        Zero_Data_L_DipY5P_3.append(float(a))
#
#    for x in Data_L_DipY5P_4: #~
#        a = x/2
#        Av_Data_L_DipY5P_4.append(float(a))
#    Av_W_Dip5P_4_NOT_NAN = [item for item in Av_Data_L_DipY5P_4 if not(math.isnan(item)) == True]  
#    for x in Av_W_Dip5P_4_NOT_NAN:
#        a = x - ((abs(Av_W_Dip5P_4_NOT_NAN[-1])-abs(Av_W_Dip5P_4_NOT_NAN[0]))/2)
#        Zero_Data_L_DipY5P_4.append(float(a))

#    for x in Data_L_DipY5P_5: #~
#        a = x/2
#        Av_Data_L_DipY5P_5.append(float(a))
#    Av_W_Dip5P_5_NOT_NAN = [item for item in Av_Data_L_DipY5P_5 if not(math.isnan(item)) == True]  
#    for x in Av_W_Dip5P_5_NOT_NAN:
#        a = x - ((abs(Av_W_Dip5P_5_NOT_NAN[-1])-abs(Av_W_Dip5P_5_NOT_NAN[0]))/2)
#        Zero_Data_L_DipY5P_5.append(float(a))

#    for x in Data_L_DipY5P_6: #~
#        a = x/2
#        Av_Data_L_DipY5P_6.append(float(a))
#    Av_W_Dip5P_6_NOT_NAN = [item for item in Av_Data_L_DipY5P_6 if not(math.isnan(item)) == True]  
#    for x in Av_W_Dip5P_6_NOT_NAN:
#        a = x - ((abs(Av_W_Dip5P_6_NOT_NAN[-1])-abs(Av_W_Dip5P_6_NOT_NAN[0]))/2)
#        Zero_Data_L_DipY5P_6.append(float(a)) 
        
#------------------------------------------------------Cleaning X------------------------------------------------------
#Removing "noise" data (copy of X and Y to saturate length requirements)
#--------------------------------- Full Growth ---------------------------------
    X1P_1 = []                                       #Micelle 1
    Data_X_list1 = Data_X1P_1.values.tolist()
    def X1P_1_value(Data_X_list1):
        for i in (range(len(Data_X_list1)-1)):
            if Data_X_list1[i] != Data_X_list1[i+1]:
                X1P_1.append(Data_X_list1[i])
            if Data_X_list1[i] == Data_X_list1[i+1]:
                pass
    X1P_1_value(Data_X_list1)

    X1P_2 = []                                       #Micelle 2
    Data_X_list6 = Data_X1P_2.values.tolist()
    def X1P_2_value(Data_X_list6):
        for i in (range(len(Data_X_list6)-1)):
            if Data_X_list6[i] != Data_X_list6[i+1]:
                X1P_2.append(Data_X_list6[i])
            if Data_X_list6[i] == Data_X_list6[i+1]:
                pass
    X1P_2_value(Data_X_list6)

#    X1P_3 = []                                       #Micelle 3
#    Data_X_list10 = Data_X1P_3.values.tolist()
#    def X1P_3_value(Data_X_list10):
#        for i in (range(len(Data_X_list10)-1)):
#            if Data_X_list10[i] != Data_X_list10[i+1]:
#                X1P_3.append(Data_X_list10[i])
#            if Data_X_list10[i] == Data_X_list10[i+1]:
#                pass
#    X1P_3_value(Data_X_list10)
#
#    X1P_4 = []                                       #Micelle 4
#    Data_X_list11 = Data_X1P_4.values.tolist()
#    def X1P_4_value(Data_X_list11):
#        for i in (range(len(Data_X_list11)-1)):
#            if Data_X_list11[i] != Data_X_list11[i+1]:
#                X1P_4.append(Data_X_list11[i])
#            if Data_X_list11[i] == Data_X_list11[i+1]:
#                pass
#    X1P_4_value(Data_X_list11)

#    X1P_5 = []                                       #Micelle 5
#    Data_X_list22 = Data_X1P_5.values.tolist()
#    def X1P_5_value(Data_X_list22):
#        for i in (range(len(Data_X_list22)-1)):
#            if Data_X_list22[i] != Data_X_list22[i+1]:
#                X1P_5.append(Data_X_list22[i])
#            if Data_X_list22[i] == Data_X_list22[i+1]:
#                pass
#    X1P_5_value(Data_X_list22)
#
#    X1P_6 = []                                       #Micelle 6
#    Data_X_list33 = Data_X1P_6.values.tolist()
#    def X1P_6_value(Data_X_list33):
#        for i in (range(len(Data_X_list33)-1)):
#            if Data_X_list33[i] != Data_X_list33[i+1]:
#                X1P_6.append(Data_X_list33[i])
#            if Data_X_list33[i] == Data_X_list33[i+1]:
#                pass
#    X1P_6_value(Data_X_list33)

#--------------------------------- ATM cooling ---------------------------------
    X5P_1 = []                                       #Micelle 1
    Data_X_list1 = Data_X5P_1.values.tolist()
    def X5P_1_value(Data_X_list1):
        for i in (range(len(Data_X_list1)-1)):
            if Data_X_list1[i] != Data_X_list1[i+1]:
                X5P_1.append(Data_X_list1[i])
            if Data_X_list1[i] == Data_X_list1[i+1]:
                pass
    X5P_1_value(Data_X_list1)

    X5P_2 = []                                       #Micelle 2
    Data_X_list6 = Data_X5P_2.values.tolist()
    def X5P_2_value(Data_X_list6):
        for i in (range(len(Data_X_list6)-1)):
            if Data_X_list6[i] != Data_X_list6[i+1]:
                X5P_2.append(Data_X_list6[i])
            if Data_X_list6[i] == Data_X_list6[i+1]:
                pass
    X5P_2_value(Data_X_list6)

#    X5P_3 = []                                       #Micelle 3
#    Data_X_list10 = Data_X5P_3.values.tolist()
#    def X5P_3_value(Data_X_list10):
#        for i in (range(len(Data_X_list10)-1)):
#            if Data_X_list10[i] != Data_X_list10[i+1]:
#                X5P_3.append(Data_X_list10[i])
#            if Data_X_list10[i] == Data_X_list10[i+1]:
#                pass
#    X5P_3_value(Data_X_list10)
#
#    X5P_4 = []                                       #Micelle 4
#    Data_X_list11 = Data_X5P_4.values.tolist()
#    def X5P_4_value(Data_X_list11):
#        for i in (range(len(Data_X_list11)-1)):
#            if Data_X_list11[i] != Data_X_list11[i+1]:
#                X5P_4.append(Data_X_list11[i])
#            if Data_X_list11[i] == Data_X_list11[i+1]:
#                pass
#    X5P_4_value(Data_X_list11)

#    X5P_5 = []                                       #Micelle 5
#    Data_X_list22 = Data_X5P_5.values.tolist()
#    def X5P_5_value(Data_X_list22):
#        for i in (range(len(Data_X_list22)-1)):
#            if Data_X_list22[i] != Data_X_list22[i+1]:
#                X5P_5.append(Data_X_list22[i])
#            if Data_X_list22[i] == Data_X_list22[i+1]:
#                pass
#    X5P_5_value(Data_X_list22)
#
#    X5P_6 = []                                       #Micelle 6
#    Data_X_list33 = Data_X5P_6.values.tolist()
#    def X5P_6_value(Data_X_list33):
#        for i in (range(len(Data_X_list33)-1)):
#            if Data_X_list33[i] != Data_X_list33[i+1]:
#                X5P_6.append(Data_X_list33[i])
#            if Data_X_list33[i] == Data_X_list33[i+1]:
#                pass
#    X5P_6_value(Data_X_list33)

#------------------------------------------------------Cleaning Y------------------------------------------------------
#Removing "noise" data (copy of X and Y to saturate length requirements)
#--------------------------------- Full Growth ---------------------------------
    Y1P_1 = []                                       #Micelle 1
    Data_Y_list1 = Data_Y1P_1.values.tolist()
    def Y1P_1_value(Data_Y_list1):
        for i in (range(len(Data_Y_list1)-1)):
            if Data_Y_list1[i] != Data_Y_list1[i+1]:
                Y1P_1.append(Data_Y_list1[i])
            if Data_Y_list1[i] == Data_Y_list1[i+1]:
                pass
    Y1P_1_value(Data_Y_list1)
    
    Y1P_2 = []                                       #Micelle 2
    Data_Y_list6 = Data_Y1P_2.values.tolist()
    def Y1P_2_value(Data_Y_list6):
        for i in (range(len(Data_Y_list6)-1)):
            if Data_Y_list6[i] != Data_Y_list6[i+1]:
                Y1P_2.append(Data_Y_list6[i])
            if Data_Y_list6[i] == Data_Y_list6[i+1]:
                pass
    Y1P_2_value(Data_Y_list6)
    
#    Y1P_3 = []                                       #Micelle 3
#    Data_Y_list10 = Data_Y1P_3.values.tolist()
#    def Y1P_3_value(Data_Y_list10):
#        for i in (range(len(Data_Y_list10)-1)):
#            if Data_Y_list10[i] != Data_Y_list10[i+1]:
#                Y1P_3.append(Data_Y_list10[i])
#            if Data_Y_list10[i] == Data_Y_list10[i+1]:
#                pass
#    Y1P_3_value(Data_Y_list10)
#    
#    Y1P_4 = []                                       #Micelle 4
#    Data_Y_list11 = Data_Y1P_4.values.tolist()
#    def Y1P_4_value(Data_Y_list11):
#        for i in (range(len(Data_Y_list11)-1)):
#            if Data_Y_list11[i] != Data_Y_list11[i+1]:
#                Y1P_4.append(Data_Y_list11[i])
#            if Data_Y_list11[i] == Data_Y_list11[i+1]:
#                pass
#    Y1P_4_value(Data_Y_list11)
    
#    Y1P_5 = []                                       #Micelle 5
#    Data_Y_list22 = Data_Y1P_5.values.tolist()
#    def Y1P_5_value(Data_Y_list22):
#        for i in (range(len(Data_Y_list22)-1)):
#            if Data_Y_list22[i] != Data_Y_list22[i+1]:
#                Y1P_5.append(Data_Y_list22[i])
#            if Data_Y_list22[i] == Data_Y_list22[i+1]:
#                pass
#    Y1P_5_value(Data_Y_list22)
#    
#    Y1P_6 = []                                       #Micelle 6
#    Data_Y_list33 = Data_Y1P_6.values.tolist()
#    def Y1P_6_value(Data_Y_list33):
#        for i in (range(len(Data_Y_list33)-1)):
#            if Data_Y_list33[i] != Data_Y_list33[i+1]:
#                Y1P_6.append(Data_Y_list33[i])
#            if Data_Y_list33[i] == Data_Y_list33[i+1]:
#                pass
#    Y1P_6_value(Data_Y_list33)

#--------------------------------- ATM cooling ---------------------------------
    Y5P_1 = []                                       #Micelle 1
    Data_Y_list1 = Data_Y5P_1.values.tolist()
    def Y5P_1_value(Data_Y_list1):
        for i in (range(len(Data_Y_list1)-1)):
            if Data_Y_list1[i] != Data_Y_list1[i+1]:
                Y5P_1.append(Data_Y_list1[i])
            if Data_Y_list1[i] == Data_Y_list1[i+1]:
                pass
    Y5P_1_value(Data_Y_list1)
    
    Y5P_2 = []                                       #Micelle 2
    Data_Y_list6 = Data_Y5P_2.values.tolist()
    def Y5P_2_value(Data_Y_list6):
        for i in (range(len(Data_Y_list6)-1)):
            if Data_Y_list6[i] != Data_Y_list6[i+1]:
                Y5P_2.append(Data_Y_list6[i])
            if Data_Y_list6[i] == Data_Y_list6[i+1]:
                pass
    Y5P_2_value(Data_Y_list6)
    
#    Y5P_3 = []                                       #Micelle 3
#    Data_Y_list10 = Data_Y5P_3.values.tolist()
#    def Y5P_3_value(Data_Y_list10):
#        for i in (range(len(Data_Y_list10)-1)):
#            if Data_Y_list10[i] != Data_Y_list10[i+1]:
#                Y5P_3.append(Data_Y_list10[i])
#            if Data_Y_list10[i] == Data_Y_list10[i+1]:
#                pass
#    Y5P_3_value(Data_Y_list10)
#    
#    Y5P_4 = []                                       #Micelle 4
#    Data_Y_list11 = Data_Y5P_4.values.tolist()
#    def Y5P_4_value(Data_Y_list11):
#        for i in (range(len(Data_Y_list11)-1)):
#            if Data_Y_list11[i] != Data_Y_list11[i+1]:
#                Y5P_4.append(Data_Y_list11[i])
#            if Data_Y_list11[i] == Data_Y_list11[i+1]:
#                pass
#    Y5P_4_value(Data_Y_list11)
    
#    Y5P_5 = []                                       #Micelle 5
#    Data_Y_list22 = Data_Y5P_5.values.tolist()
#    def Y5P_5_value(Data_Y_list22):
#        for i in (range(len(Data_Y_list22)-1)):
#            if Data_Y_list22[i] != Data_Y_list22[i+1]:
#                Y5P_5.append(Data_Y_list22[i])
#            if Data_Y_list22[i] == Data_Y_list22[i+1]:
#                pass
#    Y5P_5_value(Data_Y_list22)
#    
#    Y5P_6 = []                                       #Micelle 6
#    Data_Y_list33 = Data_Y5P_6.values.tolist()
#    def Y5P_6_value(Data_Y_list33):
#        for i in (range(len(Data_Y_list33)-1)):
#            if Data_Y_list33[i] != Data_Y_list33[i+1]:
#                Y5P_6.append(Data_Y_list33[i])
#            if Data_Y_list33[i] == Data_Y_list33[i+1]:
#                pass
#    Y5P_6_value(Data_Y_list33)
    
    
    def Area_Volume_XDATA():
#------------------------------------------------------Average Z (X-DATA)------------------------------------------------------
        print("====================================================")
        print("Average height of 10-minute using L-Data:")
        print("====================================================")
#--------------------------------- Base ---------------------------------
    
        sum_Data_L_Ridge1P1_2 = list(map (add,Zero_Data_L_RidgeX1P_1[5:360], Zero_Data_L_RidgeX1P_2[5:360])) 
        #sum_Data_L_Ridge1P3_4 = list(map (add,Zero_Data_L_RidgeX1P_3[5:360], Zero_Data_L_RidgeX1P_4[5:360]))
        #sum_Data_L_Ridge1P5_6 = list(map (add,Zero_Data_L_RidgeX1P_5[5:60], Zero_Data_L_RidgeX1P_6[5:60]))
        #sum_Data_L_Ridge1P1_2_3_4 = list(map (add,sum_Data_L_Ridge1P1_2, sum_Data_L_Ridge1P3_4))
        #SUMTOT_Data_L_Ridge1P = sum(list(map (add,sum_Data_L_Ridge1P1_2_3_4, sum_Data_L_Ridge1P5_6)))
        SUMTOT_Data_L_Ridge1P = sum(sum_Data_L_Ridge1P1_2)
        AVERAGE_Zero_Data_L_Ridge_1P= SUMTOT_Data_L_Ridge1P/(len(sum_Data_L_Ridge1P1_2*2)) #Data range * inputs (4)
        print("Full growth Average Height (Ridge):","    ",AVERAGE_Zero_Data_L_Ridge_1P,"nm")
    
        sum_Data_L_Middle1P1_2 = list(map (add,Zero_Data_L_MidX1P_1[5:360], Zero_Data_L_MidX1P_2[5:360]))
        #sum_Data_L_Middle1P3_4= list(map (add,Zero_Data_L_MidX1P_3[5:360], Zero_Data_L_MidX1P_4[5:360]))
        #sum_Data_L_Middle1P5_6 = list(map (add,Zero_Data_L_MidX1P_5[5:60], Zero_Data_L_MidX1P_6[5:60]))
        #sum_Data_L_Middle1P1_2_3_4 = list(map (add,sum_Data_L_Middle1P1_2, sum_Data_L_Middle1P3_4))
        #SUMTOT_Data_L_Middle1P = sum(list(map (add,sum_Data_L_Middle1P1_2_3_4, sum_Data_L_Middle1P5_6)))
        SUMTOT_Data_L_Middle1P = sum(sum_Data_L_Middle1P1_2)
        AVERAGE_Zero_Data_L_Middle_1P= SUMTOT_Data_L_Middle1P/(len(sum_Data_L_Middle1P1_2*2)) #Data range * inputs (6)
        print("Full growth Average Height (Mid):","      ",AVERAGE_Zero_Data_L_Middle_1P,"nm")    
        
        sum_Data_L_Dip1P1_2 = list(map (add,Zero_Data_L_DipX1P_1[5:360], Zero_Data_L_DipX1P_2[5:360]))
        #sum_Data_L_Dip1P3_4= list(map (add,Zero_Data_L_DipX1P_3[5:360], Zero_Data_L_DipX1P_4[5:360]))
        #sum_Data_L_Dip1P5_6 = list(map (add,Zero_Data_L_DipX1P_5[5:60], Zero_Data_L_DipX1P_6[5:60]))
        #sum_Data_L_Dip1P1_2_3_4 = list(map (add,sum_Data_L_Dip1P1_2, sum_Data_L_Dip1P3_4))
        #SUMTOT_Data_L_Dip1P = sum(list(map (add,sum_Data_L_Dip1P1_2_3_4, sum_Data_L_Dip1P5_6)))
        SUMTOT_Data_L_Dip1P = sum(sum_Data_L_Dip1P1_2)
        AVERAGE_Zero_Data_L_Dip_1P= SUMTOT_Data_L_Dip1P/(len(sum_Data_L_Dip1P1_2*2)) #Data range * inputs (6)
        print("Full growth Average Height (Dip):","      ",AVERAGE_Zero_Data_L_Dip_1P,"nm")    
        
        
    
#--------------------------------- Converted ---------------------------------

        sum_Data_L_Ridge5P1_2 = list(map (add,Zero_Data_L_RidgeX5P_1[5:360], Zero_Data_L_RidgeX5P_2[5:360])) 
        #sum_Data_L_Ridge5P3_4 = list(map (add,Zero_Data_L_RidgeX5P_3[5:360], Zero_Data_L_RidgeX5P_4[5:360]))
        #sum_Data_L_Ridge5P5_6 = list(map (add,Zero_Data_L_RidgeX5P_5[5:60], Zero_Data_L_RidgeX5P_6[5:60]))
        #sum_Data_L_Ridge5P1_2_3_4 = list(map (add,sum_Data_L_Ridge5P1_2, sum_Data_L_Ridge5P3_4))
        #SUMTOT_Data_L_Ridge5P = sum(list(map (add,sum_Data_L_Ridge5P1_2_3_4, sum_Data_L_Ridge5P5_6)))
        SUMTOT_Data_L_Ridge5P = sum(sum_Data_L_Ridge5P1_2)
        AVERAGE_Zero_Data_L_Ridge_5P= SUMTOT_Data_L_Ridge5P/(len(sum_Data_L_Ridge5P1_2*2)) #Data range * inputs (6)
        print("ATM growth Average Height (Ridge):","     ",AVERAGE_Zero_Data_L_Ridge_5P,"nm")
    
        sum_Data_L_Middle5P1_2 = list(map (add,Zero_Data_L_MidX5P_1[5:360], Zero_Data_L_MidX5P_2[5:360]))
        #sum_Data_L_Middle5P3_4= list(map (add,Zero_Data_L_MidX5P_3[5:360], Zero_Data_L_MidX5P_4[5:360]))
        #sum_Data_L_Middle5P5_6 = list(map (add,Zero_Data_L_MidX5P_5[5:60], Zero_Data_L_MidX5P_6[5:60]))
        #sum_Data_L_Middle5P1_2_3_4 = list(map (add,sum_Data_L_Middle5P1_2, sum_Data_L_Middle5P3_4))
        #SUMTOT_Data_L_Middle5P = sum(list(map (add,sum_Data_L_Middle5P1_2_3_4, sum_Data_L_Middle5P5_6)))
        SUMTOT_Data_L_Middle5P = sum(sum_Data_L_Middle5P1_2)
        AVERAGE_Zero_Data_L_Middle_5P= SUMTOT_Data_L_Middle5P/(len(sum_Data_L_Middle5P1_2*2)) #Data range * inputs (6)
        print("ATM growth Average Height (Mid):","       ",AVERAGE_Zero_Data_L_Middle_5P,"nm")
        
        sum_Data_L_Dip5P1_2 = list(map (add,Zero_Data_L_DipX5P_1[5:360], Zero_Data_L_DipX5P_2[5:360]))
        #sum_Data_L_Dip5P3_4= list(map (add,Zero_Data_L_DipX5P_3[5:360], Zero_Data_L_DipX5P_4[5:360]))
        #sum_Data_L_Dip5P5_6 = list(map (add,Zero_Data_L_DipX5P_5[5:60], Zero_Data_L_DipX5P_6[5:60]))
        #sum_Data_L_Dip5P1_2_3_4 = list(map (add,sum_Data_L_Dip5P1_2, sum_Data_L_Dip5P3_4))
        #SUMTOT_Data_L_Dip5P = sum(list(map (add,sum_Data_L_Dip5P1_2_3_4, sum_Data_L_Dip5P5_6)))
        SUMTOT_Data_L_Dip5P = sum(sum_Data_L_Dip5P1_2)
        AVERAGE_Zero_Data_L_Dip_5P= SUMTOT_Data_L_Dip5P/(len(sum_Data_L_Dip5P1_2*2)) #Data range * inputs (6)
        print("ATM growth Average Height (Dip):","       ",AVERAGE_Zero_Data_L_Dip_5P,"nm")
        
        
        
        
#------------------------------------------------------Average Z (Y-DATA)------------------------------------------------------
        print("====================================================")
        print("Average height of 10-minute using W-Data:")
        print("====================================================")
#--------------------------------- Base  ---------------------------------
    
        sum_Data_W_Ridge1P1_2 = list(map (add,Zero_Data_L_RidgeY1P_1[5:110], Zero_Data_L_RidgeY1P_2[5:110])) 
        #sum_Data_W_Ridge1P3_4 = list(map (add,Zero_Data_L_RidgeY1P_3[5:110], Zero_Data_L_RidgeY1P_4[5:110]))
        #sum_Data_W_Ridge1P5_6 = list(map (add,Zero_Data_L_RidgeY1P_5[5:40], Zero_Data_L_RidgeY1P_6[5:40]))
        #sum_Data_W_Ridge1P1_2_3_4 = list(map (add,sum_Data_W_Ridge1P1_2, sum_Data_W_Ridge1P3_4))
        #SUMTOT_Data_W_Ridge1P = sum(list(map (add,sum_Data_W_Ridge1P1_2_3_4, sum_Data_W_Ridge1P5_6)))
        SUMTOT_Data_W_Ridge1P = sum(sum_Data_W_Ridge1P1_2)
        AVERAGE_Zero_Data_W_Ridge_1P= SUMTOT_Data_W_Ridge1P/(len(sum_Data_W_Ridge1P1_2*2)) #Data range * inputs (6)
        print("Full growth Average Height (Ridge):","    ",AVERAGE_Zero_Data_W_Ridge_1P,"nm")
    
        sum_Data_W_Middle1P1_2 = list(map (add,Zero_Data_L_MidY1P_1[5:110], Zero_Data_L_MidY1P_2[5:110]))
        #sum_Data_W_Middle1P3_4= list(map (add,Zero_Data_L_MidY1P_3[5:110], Zero_Data_L_MidY1P_4[5:110]))
        #sum_Data_W_Middle1P5_6 = list(map (add,Zero_Data_L_MidY1P_5[5:40], Zero_Data_L_MidY1P_6[5:110]))
        #sum_Data_W_Middle1P1_2_3_4 = list(map (add,sum_Data_W_Middle1P1_2, sum_Data_W_Middle1P3_4))
        #SUMTOT_Data_W_Middle1P = sum(list(map (add,sum_Data_W_Middle1P1_2_3_4, sum_Data_W_Middle1P5_6)))
        SUMTOT_Data_W_Middle1P = sum(sum_Data_W_Middle1P1_2)
        AVERAGE_Zero_Data_W_Middle_1P= SUMTOT_Data_W_Middle1P/(len(sum_Data_W_Middle1P1_2*2)) #Data range * inputs (6)
        print("Full growth Average Height (Mid):","      ",AVERAGE_Zero_Data_W_Middle_1P,"nm")    
        
        
        sum_Data_W_Dip1P1_2 = list(map (add,Zero_Data_L_DipY1P_1[5:110], Zero_Data_L_DipY1P_2[5:110]))
        #sum_Data_W_Dip1P3_4= list(map (add,Zero_Data_L_DipY1P_3[5:110], Zero_Data_L_DipY1P_4[5:110]))
        #sum_Data_W_Dip1P5_6 = list(map (add,Zero_Data_L_DipY1P_5[5:40], Zero_Data_L_DipY1P_6[5:40]))
        #sum_Data_W_Dip1P1_2_3_4 = list(map (add,sum_Data_W_Dip1P1_2, sum_Data_W_Dip1P3_4))
        #SUMTOT_Data_W_Dip1P = sum(list(map (add,sum_Data_W_Dip1P1_2_3_4, sum_Data_W_Dip1P5_6)))
        SUMTOT_Data_W_Dip1P = sum(sum_Data_W_Dip1P1_2)
        AVERAGE_Zero_Data_W_Dip_1P= SUMTOT_Data_W_Dip1P/(len(sum_Data_W_Dip1P1_2*2)) #Data range * inputs (6)
        print("Full growth Average Height (Dip):","      ",AVERAGE_Zero_Data_W_Dip_1P,"nm")    
        
        
    
#--------------------------------- Converted ---------------------------------

        sum_Data_W_Ridge5P1_2 = list(map (add,Zero_Data_L_RidgeY5P_1[5:110], Zero_Data_L_RidgeY5P_2[5:110])) 
        #sum_Data_W_Ridge5P3_4 = list(map (add,Zero_Data_L_RidgeY5P_3[5:110], Zero_Data_L_RidgeY5P_4[5:110]))
        #sum_Data_W_Ridge5P5_6 = list(map (add,Zero_Data_L_RidgeY5P_5[5:40], Zero_Data_L_RidgeY5P_6[5:40]))
        #sum_Data_W_Ridge5P1_2_3_4 = list(map (add,sum_Data_W_Ridge5P1_2, sum_Data_W_Ridge5P3_4))
        #SUMTOT_Data_W_Ridge5P = sum(list(map (add,sum_Data_W_Ridge5P1_2_3_4, sum_Data_W_Ridge5P5_6)))
        SUMTOT_Data_W_Ridge5P = sum(sum_Data_W_Ridge5P1_2)
        AVERAGE_Zero_Data_W_Ridge_5P= SUMTOT_Data_W_Ridge5P/(len(sum_Data_W_Ridge5P1_2*2)) #Data range * inputs (6)
        print("ATM growth Average Height (Ridge):","     ",AVERAGE_Zero_Data_W_Ridge_5P,"nm")
    
        sum_Data_W_Middle5P1_2 = list(map (add,Zero_Data_L_MidY5P_1[5:110], Zero_Data_L_MidY5P_2[5:110]))
        #sum_Data_W_Middle5P3_4= list(map (add,Zero_Data_L_MidY5P_3[5:110], Zero_Data_L_MidY5P_4[5:110]))
        #sum_Data_W_Middle5P5_6 = list(map (add,Zero_Data_L_MidY5P_5[5:40], Zero_Data_L_MidY5P_6[5:40]))
        #sum_Data_W_Middle5P1_2_3_4 = list(map (add,sum_Data_W_Middle5P1_2, sum_Data_W_Middle5P3_4))
        #SUMTOT_Data_W_Middle5P = sum(list(map (add,sum_Data_W_Middle5P1_2_3_4, sum_Data_W_Middle5P5_6)))
        SUMTOT_Data_W_Middle5P = sum(sum_Data_W_Middle5P1_2)
        AVERAGE_Zero_Data_W_Middle_5P= SUMTOT_Data_W_Middle5P/(len(sum_Data_W_Middle5P1_2*2)) #Data range * inputs (6)
        print("ATM growth Average Height (Mid):","       ",AVERAGE_Zero_Data_W_Middle_5P,"nm")  
        
        
        sum_Data_W_Dip1P1_2 = list(map (add,Zero_Data_L_DipY1P_1[5:110], Zero_Data_L_DipY1P_2[5:110]))
        #sum_Data_W_Dip1P3_4= list(map (add,Zero_Data_L_DipY1P_3[5:110], Zero_Data_L_DipY1P_4[5:110]))
        #sum_Data_W_Dip1P5_6 = list(map (add,Zero_Data_L_DipY1P_5[5:40], Zero_Data_L_DipY1P_6[5:40]))
        #sum_Data_W_Dip1P1_2_3_4 = list(map (add,sum_Data_W_Dip1P1_2, sum_Data_W_Dip1P3_4))
        #SUMTOT_Data_W_Dip1P = sum(list(map (add,sum_Data_W_Dip1P1_2_3_4, sum_Data_W_Dip1P5_6)))
        SUMTOT_Data_W_Dip1P = sum(sum_Data_W_Dip1P1_2)
        AVERAGE_Zero_Data_W_Dip_5P= SUMTOT_Data_W_Dip1P/(len(sum_Data_W_Dip1P1_2*2)) #Data range * inputs (6)
        print("Full growth Average Height (Dip):","      ",AVERAGE_Zero_Data_W_Dip_1P,"nm") 
        
#------------------------------------------------------Base Area (X*Y)------------------------------------------------------
        print("====================================================")
        print("Average base area of 10-minute growth:")
        print("====================================================")
#Removing "nan" from list and then minusing MAX X/Y from MIN X/Y from same list to give X and Y distance for each micelle.
#--------------------------------- Base ---------------------------------

        Y1P_1_NOT_NAN = [item for item in Y1P_1 if not(math.isnan(item)) == True]
        BaseArea_XY_1P1 = X1P_1[-1]*Y1P_1_NOT_NAN[-1]
        #print(BaseArea_XY_1)
        Y1P_2_NOT_NAN = [item for item in Y1P_2 if not(math.isnan(item)) == True]
        BaseArea_XY_1P2 = X1P_2[-1]*Y1P_2_NOT_NAN[-1]
#        Y1P_3_NOT_NAN = [item for item in Y1P_3 if not(math.isnan(item)) == True]
#        BaseArea_XY_1P3 = X1P_3[-1]*Y1P_3_NOT_NAN[-1]
#        Y1P_4_NOT_NAN = [item for item in Y1P_4 if not(math.isnan(item)) == True]
#        BaseArea_XY_1P4 = X1P_4[-1]*Y1P_4_NOT_NAN[-1]
#        Y1P_5_NOT_NAN = [item for item in Y1P_5 if not(math.isnan(item)) == True]
#        BaseArea_XY_1P5 = X1P_5[-1]*Y1P_5_NOT_NAN[-1]
#        Y1P_6_NOT_NAN = [item for item in Y1P_6 if not(math.isnan(item)) == True]
#        BaseArea_XY_1P6 = X1P_6[-1]*Y1P_6_NOT_NAN[-1]
        AVERAGE_BaseArea_XY_1P = ((BaseArea_XY_1P1+BaseArea_XY_1P2)/6)*(10**-9)#+BaseArea_XY_1P3+BaseArea_XY_1P4)#+BaseArea_XY_1P5+BaseArea_XY_1P6)/6)*(10**-9)
        print("Full growth Average base area (XY):","    ",AVERAGE_BaseArea_XY_1P,"nm^2")
    
#--------------------------------- Converted ---------------------------------

        Y5P_1_NOT_NAN = [item for item in Y5P_1 if not(math.isnan(item)) == True]
        BaseArea_XY_5P1 = X5P_1[-1]*Y5P_1_NOT_NAN[-1]
        #print(BaseArea_XY_1)
        Y5P_2_NOT_NAN = [item for item in Y5P_2 if not(math.isnan(item)) == True]
        BaseArea_XY_5P2 = X5P_2[-1]*Y5P_2_NOT_NAN[-1]
#        Y5P_3_NOT_NAN = [item for item in Y5P_3 if not(math.isnan(item)) == True]
#        BaseArea_XY_5P3 = X5P_3[-1]*Y5P_3_NOT_NAN[-1]
#        Y5P_4_NOT_NAN = [item for item in Y5P_4 if not(math.isnan(item)) == True]
#        BaseArea_XY_5P4 = X5P_4[-1]*Y5P_4_NOT_NAN[-1]
#        Y5P_5_NOT_NAN = [item for item in Y5P_5 if not(math.isnan(item)) == True]
#        BaseArea_XY_5P5 = X5P_5[-1]*Y5P_5_NOT_NAN[-1]
#        Y5P_6_NOT_NAN = [item for item in Y5P_6 if not(math.isnan(item)) == True]
#        BaseArea_XY_5P6 = X5P_6[-1]*Y5P_6_NOT_NAN[-1]
        AVERAGE_BaseArea_XY_5P = ((BaseArea_XY_5P1+BaseArea_XY_5P2)/6)*(10**-9)#+BaseArea_XY_5P3+BaseArea_XY_5P4)#+BaseArea_XY_5P5+BaseArea_XY_5P6)/6)*(10**-9)
        print("ATM growth Average base area (XY):","     ",AVERAGE_BaseArea_XY_5P,"nm^2")
        
#------------------------------------------------------Volume (X*Y)*Z L-Ridge -------------------------------------------------
        print("====================================================")
        print("Average volume of 10-minute growth using L-Ridge:")
        print("====================================================")
#--------------------------------- Base ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height.
        One_Pulse_Volume_LR = AVERAGE_BaseArea_XY_1P*AVERAGE_Zero_Data_L_Ridge_1P #"LR" = Length Ridge
        print("Full growth Average volume (Ridge):","    ",One_Pulse_Volume_LR,"nm^3")
#--------------------------------- Converted ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height. 
        Five_Pulse_Volume_LR= AVERAGE_BaseArea_XY_5P*AVERAGE_Zero_Data_L_Ridge_5P
        print("ATM growth Average volume (Ridge):","     ",Five_Pulse_Volume_LR,"nm^3")
        
#------------------------------------------------------Volume (X*Y)*Z W-Ridge--------------------------------------------------
        print("====================================================")
        print("Average volume of 10-minute growth using W-Ridge:")
        print("====================================================")
#--------------------------------- Base ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height.
        One_Pulse_Volume_WR = AVERAGE_BaseArea_XY_1P*AVERAGE_Zero_Data_W_Ridge_1P #"WR" - Width Ridge
        print("Full growth Average volume (Ridge):","    ",One_Pulse_Volume_WR,"nm^3")
#--------------------------------- Converted ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height. 
        Five_Pulse_Volume_WR= AVERAGE_BaseArea_XY_5P*AVERAGE_Zero_Data_W_Ridge_5P
        print("ATM growth Average volume (Ridge):","     ",Five_Pulse_Volume_WR,"nm^3")
        
#------------------------------------------------------Volume (X*Y)*Z L-Mid----------------------------------------------------
        print("====================================================")
        print("Average volume of 10-minute growth using L-Middle:")
        print("====================================================")
#--------------------------------- Base ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height.
        One_Pulse_Volume_LM = AVERAGE_BaseArea_XY_1P*AVERAGE_Zero_Data_L_Middle_1P
        print("Full growth Average volume (Mid):","      ",One_Pulse_Volume_LM,"nm^3")
#--------------------------------- Converted ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height. 
        Five_Pulse_Volume_LM= AVERAGE_BaseArea_XY_5P*AVERAGE_Zero_Data_L_Middle_5P
        print("ATM growth Average volume (Mid):","       ",Five_Pulse_Volume_LM,"nm^3")
    
#------------------------------------------------------Volume (X*Y)*Z W-Mid----------------------------------------------------
        print("====================================================")
        print("Average volume of 10-minute growth using W-Middle:")
        print("====================================================")
#--------------------------------- Base ---------------------------------  
        One_Pulse_Volume_WM = AVERAGE_BaseArea_XY_1P*AVERAGE_Zero_Data_W_Middle_1P
        print("Full growth Average volume (Mid):","      ",One_Pulse_Volume_WM,"nm^3")
#--------------------------------- Converted --------------------------------- 
        Five_Pulse_Volume_WM= AVERAGE_BaseArea_XY_5P*AVERAGE_Zero_Data_W_Middle_5P
        print("ATM growth Average volume (Mid):","       ",Five_Pulse_Volume_WM,"nm^3")
        
#------------------------------------------------------Volume (X*Y)*Z L-Dip----------------------------------------------------
#--------------------------------- Base ---------------------------------  
        One_Pulse_Volume_LD = AVERAGE_BaseArea_XY_1P*AVERAGE_Zero_Data_L_Dip_1P #LD = Length Dip
        print("Full growth Average volume (Mid):","      ",One_Pulse_Volume_LD,"nm^3")
#--------------------------------- Converted --------------------------------- 
        Five_Pulse_Volume_LD= AVERAGE_BaseArea_XY_5P*AVERAGE_Zero_Data_L_Dip_5P
        print("ATM growth Average volume (Mid):","       ",Five_Pulse_Volume_LD,"nm^3")
        
        
#------------------------------------------------------Volume (X*Y)*Z W-Dip----------------------------------------------------
#--------------------------------- Base ---------------------------------  
        One_Pulse_Volume_WD = AVERAGE_BaseArea_XY_1P*AVERAGE_Zero_Data_W_Dip_1P
        print("Full growth Average volume (Mid):","      ",One_Pulse_Volume_WD,"nm^3")
#--------------------------------- Converted --------------------------------- 
        Five_Pulse_Volume_WD= AVERAGE_BaseArea_XY_5P*AVERAGE_Zero_Data_W_Dip_5P
        print("ATM growth Average volume (Mid):","       ",Five_Pulse_Volume_WD,"nm^3")
    
    
        
#=================================================FOR LOOPING DATA FOR EXPORT================================================= 
    
        
        DataSet_2_FULL_RIDGE_ZX.append(AVERAGE_Zero_Data_L_Ridge_1P) #Lists for Z-data (X-axis)
        DataSet_2_ATM_RIDGE_ZX.append(AVERAGE_Zero_Data_L_Ridge_5P)
        DataSet_2_FULL_MID_ZX.append(AVERAGE_Zero_Data_L_Middle_1P)
        DataSet_2_ATM_MID_ZX.append(AVERAGE_Zero_Data_L_Middle_5P)
        DataSet_2_FULL_DIP_ZX.append(AVERAGE_Zero_Data_L_Dip_1P)#
        DataSet_2_ATM_DIP_ZX.append(AVERAGE_Zero_Data_L_Dip_5P)#
        DataSet_2_FULL_RIDGE_ZY.append(AVERAGE_Zero_Data_W_Ridge_1P) #For loops for Z-Height using Y-axis
        DataSet_2_ATM_RIDGE_ZY.append(AVERAGE_Zero_Data_W_Ridge_5P)
        DataSet_2_FULL_MID_ZY.append(AVERAGE_Zero_Data_W_Middle_1P)
        DataSet_2_ATM_MID_ZY.append(AVERAGE_Zero_Data_W_Middle_5P)
        DataSet_2_FULL_DIP_ZY.append(AVERAGE_Zero_Data_W_Dip_1P)#
        DataSet_2_ATM_DIP_ZY.append(AVERAGE_Zero_Data_W_Dip_5P)#
        DataSet_2_FULL_BASE.append(AVERAGE_BaseArea_XY_1P)#For loops for Base Area (X*Y)
        DataSet_2_ATM_BASE.append(AVERAGE_BaseArea_XY_5P)
        DataSet_2_FULL_VOL_RIDGE_X.append(One_Pulse_Volume_LR)#Lists for Volume using X-axis Ridge
        DataSet_2_ATM_VOL_RIDGE_X.append(Five_Pulse_Volume_LR)
        DataSet_2_FULL_VOL_RIDGE_Y.append(One_Pulse_Volume_WR)#Lists for Volume using Y-axis Ridge
        DataSet_2_ATM_VOL_RIDGE_Y.append(Five_Pulse_Volume_WR)
        DataSet_2_FULL_VOL_MID_X.append(One_Pulse_Volume_LM)#Lists for Volume using X-axis Mid
        DataSet_2_ATM_VOL_MID_X.append(Five_Pulse_Volume_LM)
        DataSet_2_FULL_VOL_MID_Y.append(One_Pulse_Volume_WM)#Lists for Volume using Y-axis Mid
        DataSet_2_ATM_VOL_MID_Y.append(Five_Pulse_Volume_WM)
        DataSet_2_FULL_VOL_DIP_X.append(One_Pulse_Volume_LD)#Lists for Volume using X-axis Dip
        DataSet_2_ATM_VOL_DIP_X.append(Five_Pulse_Volume_LD)
        DataSet_2_FULL_VOL_DIP_Y.append(One_Pulse_Volume_WD)#Lists for Volume using Y-axis Dip
        DataSet_2_ATM_VOL_DIP_Y.append(Five_Pulse_Volume_WD)
    
    
    print(np.average(Zero_Data_L_RidgeX5P_2[5:360]))
    print(np.average(Zero_Data_L_MidX5P_2[5:360]))
    print(np.average(Zero_Data_L_DipX5P_2[5:360]))
    
    
    
    
    
    Area_Volume_XDATA()



DataSet_2()
# Out:
# 13.151993610140844
# 7.017836315880283
# 13.152777828873239
# ====================================================
# Average height of 10-minute using L-Data:
# ====================================================
# Full growth Average Height (Ridge):      20.087923795012344 nm
# Full growth Average Height (Mid):        9.722460568098596 nm
# Full growth Average Height (Dip):        17.17817975295775 nm
# ATM growth Average Height (Ridge):       14.7715051365845 nm
# ATM growth Average Height (Mid):         7.68715928945423 nm
# ATM growth Average Height (Dip):         14.566917569823955 nm
# ====================================================
# Average height of 10-minute using W-Data:
# ====================================================
# Full growth Average Height (Ridge):      20.154231653214296 nm
# Full growth Average Height (Mid):        8.784552797619046 nm
# Full growth Average Height (Dip):        19.91145232369048 nm
# ATM growth Average Height (Ridge):       14.745492215714286 nm
# ATM growth Average Height (Mid):         7.240577632738091 nm
# Full growth Average Height (Dip):        19.91145232369048 nm
# ====================================================
# Average base area of 10-minute growth:
# ====================================================
# Full growth Average base area (XY):      0.0009618439656387401 nm^2
# ATM growth Average base area (XY):       0.0010117544928115948 nm^2
# ====================================================
# Average volume of 10-minute growth using L-Ridge:
# ====================================================
# Full growth Average volume (Ridge):      0.01932144828444348 nm^3
# ATM growth Average volume (Ridge):       0.014945136687528919 nm^3
# ====================================================
# Average volume of 10-minute growth using W-Ridge:
# ====================================================
# Full growth Average volume (Ridge):      0.01938522609772946 nm^3
# ATM growth Average volume (Ridge):       0.014918817997967328 nm^3
# ====================================================
# Average volume of 10-minute growth using L-Middle:
# ====================================================
# Full growth Average volume (Mid):        0.009351490028586231 nm^3
# ATM growth Average volume (Mid):         0.007777517948063704 nm^3
# ====================================================
# Average volume of 10-minute growth using W-Middle:
# ====================================================
# Full growth Average volume (Mid):        0.008449369099224792 nm^3
# ATM growth Average volume (Mid):         0.007325686950473906 nm^3
# Full growth Average volume (Mid):        0.016522728536039994 nm^3
# ATM growth Average volume (Mid):         0.014738144297685545 nm^3
# Full growth Average volume (Mid):        0.019151710264645155 nm^3
# ATM growth Average volume (Mid):         0.02014550134689771 nm^3

# %%
#Data2-Data1 here. 
def Compare():
    
    for i in DataSet_2_FULL_RIDGE_ZX:
        DIFF_FULL_RIDGE_ZX = np.float_ (DataSet_2_FULL_RIDGE_ZX) - np.float_ (DataSet_1_FULL_RIDGE_ZX)
    for i in DataSet_2_ATM_RIDGE_ZX:
        DIFF_ATM_RIDGE_ZX = np.float_ (DataSet_2_ATM_RIDGE_ZX) - np.float_ (DataSet_1_ATM_RIDGE_ZX)
    for i in DataSet_2_FULL_MID_ZX:
        DIFF_FULL_MID_ZX = np.float_ (DataSet_2_FULL_MID_ZX) - np.float_ (DataSet_1_FULL_MID_ZX)
    for i in DataSet_2_ATM_MID_ZX:
        DIFF_ATM_MID_ZX = np.float_ (DataSet_2_ATM_MID_ZX) - np.float_ (DataSet_1_ATM_MID_ZX)
    for i in DataSet_2_FULL_DIP_ZX:
        DIFF_FULL_DIP_ZX = np.float_ (DataSet_2_FULL_DIP_ZX) - np.float_ (DataSet_1_FULL_DIP_ZX)
    for i in DataSet_2_ATM_DIP_ZX:
        DIFF_ATM_DIP_ZX = np.float_ (DataSet_2_ATM_DIP_ZX) - np.float_ (DataSet_1_ATM_DIP_ZX)
    for i in DataSet_2_FULL_RIDGE_ZY:
        DIFF_FULL_RIDGE_ZY = np.float_ (DataSet_2_FULL_RIDGE_ZY) - np.float_ (DataSet_1_FULL_RIDGE_ZY) 
    for i in DataSet_2_ATM_RIDGE_ZY:
        DIFF_ATM_RIDGE_ZY = np.float_ (DataSet_2_ATM_RIDGE_ZY) - np.float_ (DataSet_1_ATM_RIDGE_ZY) 
    for i in DataSet_2_FULL_MID_ZY:
        DIFF_FULL_MID_ZY = np.float_ (DataSet_2_FULL_MID_ZY) - np.float_ (DataSet_1_FULL_MID_ZY) 
    for i in DataSet_2_ATM_MID_ZY:
        DIFF_ATM_MID_ZY = np.float_ (DataSet_2_ATM_MID_ZY) - np.float_ (DataSet_1_ATM_MID_ZY) 
    for i in DataSet_2_FULL_DIP_ZY:
        DIFF_FULL_DIP_ZY = np.float_ (DataSet_2_FULL_DIP_ZY) - np.float_ (DataSet_1_FULL_DIP_ZY) 
    for i in DataSet_2_ATM_DIP_ZY:
        DIFF_ATM_DIP_ZY = np.float_ (DataSet_2_ATM_DIP_ZY) - np.float_ (DataSet_1_ATM_DIP_ZY) 
    for i in DataSet_2_FULL_BASE:
        DIFF_FULL_BASE = np.float_ (DataSet_2_FULL_BASE) - np.float_ (DataSet_1_FULL_BASE) 
    for i in DataSet_2_ATM_BASE:
        DIFF_ATM_BASE = np.float_ (DataSet_2_ATM_BASE) - np.float_ (DataSet_1_ATM_BASE) 
    for i in DataSet_2_FULL_VOL_RIDGE_X:
        DIFF_FULL_VOL_RIDGE_X = np.float_ (DataSet_2_FULL_VOL_RIDGE_X) - np.float_ (DataSet_1_FULL_VOL_RIDGE_X) 
    for i in DataSet_2_ATM_VOL_RIDGE_X:
        DIFF_ATM_VOL_RIDGE_X = np.float_ (DataSet_2_ATM_VOL_RIDGE_X) - np.float_ (DataSet_1_ATM_VOL_RIDGE_X) 
    for i in DataSet_2_FULL_VOL_RIDGE_Y:
        DIFF_FULL_VOL_RIDGE_Y = np.float_ (DataSet_2_FULL_VOL_RIDGE_Y) - np.float_ (DataSet_1_FULL_VOL_RIDGE_Y) 
    for i in DataSet_2_ATM_VOL_RIDGE_Y:
        DIFF_ATM_VOL_RIDGE_Y = np.float_ (DataSet_2_ATM_VOL_RIDGE_Y) - np.float_ (DataSet_1_ATM_VOL_RIDGE_Y) 
    for i in DataSet_2_FULL_VOL_MID_X:
        DIFF_FULL_VOL_MID_X = np.float_ (DataSet_2_FULL_VOL_MID_X) - np.float_ (DataSet_1_FULL_VOL_MID_X) 
    for i in DataSet_2_ATM_VOL_MID_X:
        DIFF_ATM_VOL_MID_X = np.float_ (DataSet_2_ATM_VOL_MID_X) - np.float_ (DataSet_1_ATM_VOL_MID_X) 
    for i in DataSet_2_FULL_VOL_MID_Y:
        DIFF_FULL_VOL_MID_Y = np.float_ (DataSet_2_FULL_VOL_MID_Y) - np.float_ (DataSet_1_FULL_VOL_MID_Y) 
    for i in DataSet_2_ATM_VOL_MID_Y:
        DIFF_ATM_VOL_MID_Y = np.float_ (DataSet_2_ATM_VOL_MID_Y) - np.float_ (DataSet_1_ATM_VOL_MID_Y) 
    for i in DataSet_2_FULL_VOL_DIP_X:
        DIFF_FULL_VOL_DIP_X = np.float_ (DataSet_2_FULL_VOL_DIP_X) - np.float_ (DataSet_1_FULL_VOL_DIP_X) 
    for i in DataSet_2_ATM_VOL_DIP_X:
        DIFF_ATM_VOL_DIP_X = np.float_ (DataSet_2_ATM_VOL_DIP_X) - np.float_ (DataSet_1_ATM_VOL_DIP_X) 
    for i in DataSet_2_FULL_VOL_DIP_Y:
        DIFF_FULL_VOL_DIP_Y = np.float_ (DataSet_2_FULL_VOL_DIP_Y) - np.float_ (DataSet_1_FULL_VOL_DIP_Y) 
    for i in DataSet_2_ATM_VOL_DIP_Y:
        DIFF_ATM_VOL_DIP_Y = np.float_ (DataSet_2_ATM_VOL_DIP_Y) - np.float_ (DataSet_1_ATM_VOL_DIP_Y) 
        
        
#============================================================PRINT=============================================================
    def calc():
        print("====================================================")
        print("Comparison of Converted - Bare micelles")
        print("====================================================")
    
#------------------------------------------------------Average Z (X-DATA)------------------------------------------------------
        print("====================================================")
        print("Average height L-Data:")
        print("====================================================")
#--------------------------------- Full Growth ---------------------------------
        print("Full growth Diff Height (Ridge):","    ",DIFF_FULL_RIDGE_ZX,"nm")
        print("Full growth Diff Height (Mid):","      ",DIFF_FULL_MID_ZX,"nm")    
        print("Full growth Diff Height (Dip):","      ",DIFF_FULL_DIP_ZX,"nm") 
#--------------------------------- ATM cooling ---------------------------------
        print("ATM growth Diff Height (Ridge):","     ",DIFF_ATM_RIDGE_ZX,"nm")
        print("ATM growth Diff Height (Mid):","       ",DIFF_ATM_MID_ZX,"nm")
        print("ATM growth Diff Height (Dip):","       ",DIFF_ATM_DIP_ZX,"nm")
#------------------------------------------------------Average Z (Y-DATA)------------------------------------------------------
        print("====================================================")
        print("Average height W-Data:")
        print("====================================================")
#--------------------------------- Full Growth  ---------------------------------
        print("Full growth Diff Height (Ridge):","    ",DIFF_FULL_RIDGE_ZY,"nm")
        print("Full growth Diff Height (Mid):","      ",DIFF_FULL_MID_ZY,"nm")    
        print("Full growth Diff Height (Dip):","      ",DIFF_FULL_DIP_ZY,"nm")   
#--------------------------------- ATM cooling ---------------------------------
        print("ATM growth Diff Height (Ridge):","     ",DIFF_ATM_RIDGE_ZY,"nm")
        print("ATM growth Diff Height (Mid):","       ",DIFF_ATM_MID_ZY,"nm")  
        print("ATM growth Diff Height (Dip):","       ",DIFF_ATM_DIP_ZY,"nm")  
#------------------------------------------------------Base Area (X*Y)------------------------------------------------------
        print("====================================================")
        print("Average base area:")
        print("====================================================")
#Removing "nan" from list and then minusing MAX X/Y from MIN X/Y from same list to give X and Y distance for each micelle.
#--------------------------------- Full Growth ---------------------------------
        print("Full growth Diff base area (XY):","    ",DIFF_FULL_BASE,"nm^2")
#--------------------------------- ATM cooling ---------------------------------
        print("ATM growth Diff base area (XY):","     ",DIFF_ATM_BASE,"nm^2")
#------------------------------------------------------Volume (X*Y)*Z L-Ridge -------------------------------------------------
        print("====================================================")
        print("Average volume using L-Ridge:")
        print("====================================================")
#--------------------------------- Full growth ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height.
        print("Full growth Diff volume (Ridge):","    ",DIFF_FULL_VOL_RIDGE_X,"nm^3")
#--------------------------------- ATM cooling ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height. 
        print("ATM growth Diff volume (Ridge):","     ",DIFF_ATM_VOL_RIDGE_X,"nm^3")
#------------------------------------------------------Volume (X*Y)*Z W-Ridge--------------------------------------------------
        print("====================================================")
        print("Average volume using W-Ridge:")
        print("====================================================")
#--------------------------------- Full Growth ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height.
        print("Full growth Diff volume (Ridge):","    ",DIFF_FULL_VOL_RIDGE_Y,"nm^3")
#--------------------------------- ATM cooling ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height. 
        print("ATM growth Diff volume (Ridge):","     ",DIFF_ATM_VOL_RIDGE_Y,"nm^3")
#------------------------------------------------------Volume (X*Y)*Z L-Mid----------------------------------------------------
        print("====================================================")
        print("Average volume using L-Middle:")
        print("====================================================")
#--------------------------------- Full Growth ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height.
        print("Full growth Diff volume (Mid):","      ",DIFF_FULL_VOL_MID_X,"nm^3")
#--------------------------------- ATM cooling ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height. 
        print("ATM growth Diff volume (Mid):","       ",DIFF_ATM_VOL_MID_X,"nm^3")
#------------------------------------------------------Volume (X*Y)*Z W-Mid----------------------------------------------------
        print("====================================================")
        print("Average volume using W-Middle:")
        print("====================================================")
#--------------------------------- Full Growth ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height.
        print("Full growth Diff volume (Mid):","      ",DIFF_FULL_VOL_MID_Y,"nm^3")
#--------------------------------- ATM cooling ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height. 
        print("ATM growth Diff volume (Mid):","       ",DIFF_ATM_VOL_MID_Y,"nm^3")
#------------------------------------------------------Volume (X*Y)*Z W-Mid----------------------------------------------------
        print("====================================================")
        print("Average volume using L-Dip:")
        print("====================================================")
#--------------------------------- Full Growth ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height.
        print("Full growth Diff volume (Dip):","      ",DIFF_FULL_VOL_DIP_X,"nm^3")
#--------------------------------- ATM cooling ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height. 
        print("ATM growth Diff volume (Dip):","       ",DIFF_ATM_VOL_DIP_X,"nm^3")
        
#------------------------------------------------------Volume (X*Y)*Z W-Mid----------------------------------------------------
        print("====================================================")
        print("Average volume using W-Dip:")
        print("====================================================")       
#--------------------------------- Full Growth ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height.
        print("Full growth Diff volume (Dip):","      ",DIFF_FULL_VOL_DIP_Y,"nm^3")
#--------------------------------- ATM cooling ---------------------------------  
    #Using L-Ridge for volume as it is the most consistent as a model of average height. 
        print("ATM growth Diff volume (Dip):","       ",DIFF_ATM_VOL_DIP_Y,"nm^3")
        
#================================================= GRAPHING ================================================= 

    #def graphing():
        #plt.xlabel("Measure type")
        #plt.ylabel("30min - 10min Data (nm)")
        #x_values = ["FULL X-Ridge","FULL X-Mid","ATM X-Ridge"]
        #y_axis = [DIFF_FULL_RIDGE_ZX,DIFF_FULL_MID_ZX,DIFF_ATM_RIDGE_ZX]

        #plt.scatter(x_values,y_axis)








    #graphing()

          
#=================================================EXPORT TO EXCEL================================================= 
        
    ExportData= [DIFF_FULL_RIDGE_ZX,DIFF_FULL_MID_ZX,DIFF_FULL_DIP_ZX,DIFF_ATM_RIDGE_ZX,DIFF_ATM_MID_ZX,DIFF_ATM_DIP_ZX,
                 DIFF_FULL_RIDGE_ZY,DIFF_FULL_MID_ZY,DIFF_FULL_DIP_ZY,DIFF_ATM_RIDGE_ZY,DIFF_ATM_MID_ZY,DIFF_ATM_DIP_ZY,
                 DIFF_FULL_BASE,DIFF_ATM_BASE,DIFF_FULL_VOL_RIDGE_X,DIFF_ATM_VOL_RIDGE_X,
                 DIFF_FULL_VOL_RIDGE_Y,DIFF_ATM_VOL_RIDGE_Y,DIFF_FULL_VOL_MID_X,DIFF_ATM_VOL_MID_X,
                 DIFF_FULL_VOL_MID_Y,DIFF_ATM_VOL_MID_Y,DIFF_FULL_VOL_DIP_X,DIFF_ATM_VOL_DIP_X,DIFF_FULL_VOL_DIP_Y,DIFF_ATM_VOL_DIP_Y]
    Title= ['FULL X-Ridge','FULL X-Mid','FULL X-Dip','ATM X-Ridge','ATM X-Mid','ATM X-Dip',
           'FULL Y-Ridge','FULL Y-Mid','FULL Y-Dip','ATM Y-Ridge','ATM Y-Mid','ATM Y-Dip',
            'FULL Base','ATM Base','FULL Volume X-Ridge','ATM Volume X-Ridge',
           'FULL Volume Y-Ridge','ATM Volume Y-Ridge','FULL Volume X-Mid','ATM Volume X-Mid',
            'FULL Volume Y-Mid','ATM Volume Y-Mid','FULL Volume X-Dip','ATM Volume X-Dip','FULL Volume Y-Dip','ATM Volume Y-Dip']
    
    
#=================================================EXPORT PROGRAM================================================= 
    #df = pd.DataFrame({
        #'Title':Title,
        #'Data (nm)':ExportData})
    #print(df)
    #df.to_excel('C:/Users/Harry/OneDrive/Documents/University of bristol/AFM Images/Python - Micelle topography data/Exported Micelle Data/_Micelle_Data_10min_30min.xlsx')
        

    
    calc()
    
Compare()
